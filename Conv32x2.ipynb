# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pydot
import visualkeras
from keras.optimizers import Adam
from keras.models import Sequential, model_from_json
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import model_selection
from math import ceil
from PIL import ImageFont
from collections import defaultdict

import os
os.chdir('F:\Другое\PythonFiles\Facial-emotion-recognition-master')

print(os.getcwd())

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# f:\Другое\PythonFiles\Facial-emotion-recognition-master
# 1 Physical GPUs, 1 Logical GPUs

# %%
def preprocess_data():
    data = pd.read_csv('fer2013.csv')
    labels = pd.read_csv('fer2013new.csv')

    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    n_samples = len(data)
    w = 48
    h = 48

    y = np.array(labels[orig_class_names])
    X = np.zeros((n_samples, w, h, 1))
    for i in range(n_samples):
        X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((h, w, 1))

    return X, y

# %%
def clean_data_and_normalize(X, y):
    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

  
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('unknown')
    X = X[mask]
    y = y[mask]

  
    y = y[:, :-2] * 0.1

   
    y[:, 0] += y[:, 7]
    y = y[:, :7]

 
    X = X / 255.0

    return X, y

# %%
def split_data(X, y):
    test_size = ceil(len(X) * 0.1)

 
    x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x_train, y_train, test_size=test_size,
                                                                      random_state=42)
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def data_good(x_train):
    datagood = ImageDataGenerator()
    datagood.fit(x_train)
    return datagood

# %%
def data_augmentation(x_train):
    shift = 0.1
    datagen = ImageDataGenerator(
        rotation_range=20,
        horizontal_flip=True,
        height_shift_range=shift,
        width_shift_range=shift)
    datagen.fit(x_train)
    return datagen

# %%
def show_images(datagood, x_train, y_train):
    it = datagood.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def show_augmented_images(datagen, x_train, y_train):
    it = datagen.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def define_model(input_shape=(48, 48, 1), classes=7):
   

    model = tf.keras.models.Sequential()

   
    model.add(Conv2D(32, kernel_size=(1, 1), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(64, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.5))

    
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

   
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

   
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

   
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

    model.add(Flatten())

   
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    
    model.add(Dense(classes, activation='softmax'))

    return model

# %%
def plot_acc_loss(history):
    
    plt.plot(history.history['accuracy'], label='Тренировочный набор')
    plt.plot(history.history['val_accuracy'], label='Валидационный набор')
    plt.xlabel('Количество эпох')
    plt.ylabel('Точность')
    plt.ylim([0, 1.0])
    plt.legend(loc='upper left')
    plt.show()

    
    plt.plot(history.history['loss'], label='Отклонение тр. набора')
    plt.plot(history.history['val_loss'], label='Отклонение влд. набора')
    plt.xlabel('Количество эпох')
    plt.ylabel('Отклонение')
    # plt.ylim([0, 3.5])
    plt.legend(loc='upper right')
    plt.show()

# %%
def save_model_and_weights(model, test_acc):
   
    test_acc = int(test_acc * 10000)
    model_json = model.to_json()
    with open('models\\model' + str(test_acc) + '.json', 'w') as json_file:
        json_file.write(model_json)
    
    model.save_weights('models\\model' + str(test_acc) + '.h5')
    color_map = defaultdict(dict)
    color_map[Flatten]['fill'] = 'black'
    color_map[Dense]['fill'] = 'green'
    font = ImageFont.truetype("arial.ttf", 28)
    visualkeras.layered_view(model, legend=True, font=font, to_file='output.png')
    print('Модель и весы сохранены.')

# %%
def load_model_and_weights(model_path, weights_path):
   
    json_file = open(model_path, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)

 
    model.load_weights(weights_path)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    print('Модель и весы загружены.')

# %%
def run_model():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagen = data_augmentation(x_train)

    epochs = 100
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))


   
    model = define_model(input_shape=x_train[0].shape, classes=len(fer_classes))
    model.summary()

    tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

   
    visualkeras.layered_view(model, legend=True)
    visualkeras.layered_view(model, legend=True, to_file='output.png')

    model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
                        steps_per_epoch=len(x_train) // batch_size,
                        validation_data=(x_val, y_val), verbose=2)
    test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=batch_size)

    plot_acc_loss(history)
    save_model_and_weights(model, test_acc)

# %%
run_model()
# Out:
# X_train shape: (28390, 48, 48, 1)
# Y_train shape: (28390, 7)
# X_test shape: (3549, 48, 48, 1)
# Y_test shape: (3549, 7)
# X_val shape: (3549, 48, 48, 1)
# Y_val shape: (3549, 7)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        64
#
#  batch_normalization (BatchN  (None, 48, 48, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_1 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 48, 48, 32)        0
#
#  dropout (Dropout)           (None, 48, 48, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 46, 46, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 46, 46, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 44, 44, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 44, 44, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 44, 44, 64)        0
#
#  dropout_1 (Dropout)         (None, 44, 44, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 42, 42, 64)        36928
#
#  conv2d_5 (Conv2D)           (None, 40, 40, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 20, 20, 64)       0
#  )
#
#  conv2d_6 (Conv2D)           (None, 18, 18, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 18, 18, 128)      512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 18, 18, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_5 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_5 (Activation)   (None, 16, 16, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 14, 14, 128)       147584
#
#  conv2d_9 (Conv2D)           (None, 12, 12, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 4, 4, 256)         295168
#
#  batch_normalization_6 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 4, 4, 256)         0
#
#  conv2d_11 (Conv2D)          (None, 2, 2, 256)         590080
#
#  batch_normalization_7 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 2,064,487
# Trainable params: 2,062,567
# Non-trainable params: 1,920
# _________________________________________________________________
# Epoch 1/100
# C:\Users\nikit\AppData\Roaming\Python\Python310\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 443/443 - 33s - loss: 0.3590 - accuracy: 0.3620 - val_loss: 0.3537 - val_accuracy: 0.3841 - 33s/epoch - 75ms/step
# Epoch 2/100
# 443/443 - 25s - loss: 0.3372 - accuracy: 0.4345 - val_loss: 0.3404 - val_accuracy: 0.4376 - 25s/epoch - 56ms/step
# Epoch 3/100
# 443/443 - 23s - loss: 0.3235 - accuracy: 0.4893 - val_loss: 0.3594 - val_accuracy: 0.4176 - 23s/epoch - 52ms/step
# Epoch 4/100
# 443/443 - 23s - loss: 0.3082 - accuracy: 0.5316 - val_loss: 0.3153 - val_accuracy: 0.5325 - 23s/epoch - 51ms/step
# Epoch 5/100
# 443/443 - 23s - loss: 0.2947 - accuracy: 0.5726 - val_loss: 0.2940 - val_accuracy: 0.5897 - 23s/epoch - 52ms/step
# Epoch 6/100
# 443/443 - 23s - loss: 0.2818 - accuracy: 0.6005 - val_loss: 0.2884 - val_accuracy: 0.6044 - 23s/epoch - 51ms/step
# Epoch 7/100
# 443/443 - 23s - loss: 0.2712 - accuracy: 0.6270 - val_loss: 0.2624 - val_accuracy: 0.6613 - 23s/epoch - 51ms/step
# Epoch 8/100
# 443/443 - 23s - loss: 0.2620 - accuracy: 0.6500 - val_loss: 0.2551 - val_accuracy: 0.6791 - 23s/epoch - 51ms/step
# Epoch 9/100
# 443/443 - 23s - loss: 0.2547 - accuracy: 0.6631 - val_loss: 0.2560 - val_accuracy: 0.6805 - 23s/epoch - 51ms/step
# Epoch 10/100
# 443/443 - 23s - loss: 0.2493 - accuracy: 0.6780 - val_loss: 0.2383 - val_accuracy: 0.7027 - 23s/epoch - 51ms/step
# Epoch 11/100
# 443/443 - 23s - loss: 0.2437 - accuracy: 0.6893 - val_loss: 0.2426 - val_accuracy: 0.7239 - 23s/epoch - 51ms/step
# Epoch 12/100
# 443/443 - 25s - loss: 0.2390 - accuracy: 0.7021 - val_loss: 0.2373 - val_accuracy: 0.7112 - 25s/epoch - 56ms/step
# Epoch 13/100
# 443/443 - 24s - loss: 0.2358 - accuracy: 0.7113 - val_loss: 0.2326 - val_accuracy: 0.7168 - 24s/epoch - 55ms/step
# Epoch 14/100
# 443/443 - 24s - loss: 0.2318 - accuracy: 0.7194 - val_loss: 0.2249 - val_accuracy: 0.7346 - 24s/epoch - 54ms/step
# Epoch 15/100
# 443/443 - 24s - loss: 0.2292 - accuracy: 0.7232 - val_loss: 0.2246 - val_accuracy: 0.7278 - 24s/epoch - 54ms/step
# Epoch 16/100
# 443/443 - 24s - loss: 0.2260 - accuracy: 0.7339 - val_loss: 0.2180 - val_accuracy: 0.7413 - 24s/epoch - 55ms/step
# Epoch 89/100
# 443/443 - 24s - loss: 0.1804 - accuracy: 0.8533 - val_loss: 0.1878 - val_accuracy: 0.8309 - 24s/epoch - 55ms/step
# Epoch 90/100
# 443/443 - 25s - loss: 0.1801 - accuracy: 0.8525 - val_loss: 0.1889 - val_accuracy: 0.8335 - 25s/epoch - 55ms/step
# Epoch 91/100
# 443/443 - 25s - loss: 0.1803 - accuracy: 0.8531 - val_loss: 0.1888 - val_accuracy: 0.8307 - 25s/epoch - 55ms/step
# Epoch 92/100
# 443/443 - 25s - loss: 0.1804 - accuracy: 0.8508 - val_loss: 0.1907 - val_accuracy: 0.8301 - 25s/epoch - 56ms/step
# Epoch 93/100
# 443/443 - 24s - loss: 0.1792 - accuracy: 0.8577 - val_loss: 0.1895 - val_accuracy: 0.8290 - 24s/epoch - 53ms/step
# Epoch 94/100
# 443/443 - 25s - loss: 0.1790 - accuracy: 0.8579 - val_loss: 0.1889 - val_accuracy: 0.8281 - 25s/epoch - 57ms/step
# Epoch 95/100
# 443/443 - 23s - loss: 0.1792 - accuracy: 0.8582 - val_loss: 0.1899 - val_accuracy: 0.8301 - 23s/epoch - 52ms/step
# Epoch 96/100
# 443/443 - 23s - loss: 0.1790 - accuracy: 0.8577 - val_loss: 0.1922 - val_accuracy: 0.8219 - 23s/epoch - 52ms/step
# Epoch 97/100
# 443/443 - 23s - loss: 0.1787 - accuracy: 0.8586 - val_loss: 0.1888 - val_accuracy: 0.8315 - 23s/epoch - 52ms/step
# Epoch 98/100
# 443/443 - 23s - loss: 0.1790 - accuracy: 0.8579 - val_loss: 0.1895 - val_accuracy: 0.8250 - 23s/epoch - 53ms/step
# Epoch 99/100
# 443/443 - 23s - loss: 0.1786 - accuracy: 0.8598 - val_loss: 0.1921 - val_accuracy: 0.8202 - 23s/epoch - 52ms/step
# Epoch 100/100
# 443/443 - 23s - loss: 0.1782 - accuracy: 0.8615 - val_loss: 0.1874 - val_accuracy: 0.8360 - 23s/epoch - 52ms/step
# 56/56 [==============================] - 1s 14ms/step - loss: 0.1873 - accuracy: 0.8307
# Модель и весы сохранены.

# %%
'''def test():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagood = data_good(x_train)
    show_images(datagood, x_train, y_train)
    datagen = data_augmentation(x_train)
    show_augmented_images(datagen, x_train, y_train)

    epochs = 2
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))'''
# Out:
# 'def test():\n    fer_classes = [\'neutral\', \'happiness\', \'surprise\', \'sadness\', \'anger\', \'disgust\', \'fear\', \'contempt\']\n\n    X, y = preprocess_data()\n    X, y = clean_data_and_normalize(X, y)\n    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)\n    datagood = data_good(x_train)\n    show_images(datagood, x_train, y_train)\n    datagen = data_augmentation(x_train)\n    show_augmented_images(datagen, x_train, y_train)\n\n    epochs = 2\n    batch_size = 64\n\n    print("X_train shape: " + str(x_train.shape))\n    print("Y_train shape: " + str(y_train.shape))\n    print("X_test shape: " + str(x_test.shape))\n    print("Y_test shape: " + str(y_test.shape))\n    print("X_val shape: " + str(x_val.shape))\n    print("Y_val shape: " + str(y_val.shape))'

# %%
#test()
