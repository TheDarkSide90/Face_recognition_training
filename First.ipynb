# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pydot
from keras.optimizers import Adam
from keras.models import Sequential, model_from_json
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import model_selection
from math import ceil

import os
os.chdir('F:\Другое\PythonFiles\Facial-emotion-recognition-master')

print(os.getcwd())

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# f:\Другое\PythonFiles\Facial-emotion-recognition-master
# 1 Physical GPUs, 1 Logical GPUs

# %%
def preprocess_data():
    data = pd.read_csv('fer2013.csv')
    labels = pd.read_csv('fer2013new.csv')

    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    n_samples = len(data)
    w = 48
    h = 48

    y = np.array(labels[orig_class_names])
    X = np.zeros((n_samples, w, h, 1))
    for i in range(n_samples):
        X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((h, w, 1))

    return X, y

# %%
def clean_data_and_normalize(X, y):
    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

   
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('unknown')
    X = X[mask]
    y = y[mask]

    
    y = y[:, :-2] * 0.1

   
    y[:, 0] += y[:, 7]
    y = y[:, :7]

    
    X = X / 255.0

    return X, y

# %%
def split_data(X, y):
    test_size = ceil(len(X) * 0.1)

  
    x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x_train, y_train, test_size=test_size,
                                                                      random_state=42)
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def data_good(x_train):
    datagood = ImageDataGenerator()
    datagood.fit(x_train)
    return datagood

# %%
def data_augmentation(x_train):
    shift = 0.1
    datagen = ImageDataGenerator(
        rotation_range=20,
        horizontal_flip=True,
        height_shift_range=shift,
        width_shift_range=shift)
    datagen.fit(x_train)
    return datagen

# %%
def show_images(datagood, x_train, y_train):
    it = datagood.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def show_augmented_images(datagen, x_train, y_train):
    it = datagen.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def define_model(input_shape=(48, 48, 1), classes=7):
    

    model = tf.keras.models.Sequential()

    
    model.add(Conv2D(64, kernel_size=(3, 3), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(64, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.5))

    
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

    
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

    model.add(Flatten())

    
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.2))

    model.add(Dense(classes, activation='softmax'))

    return model

# %%
def plot_acc_loss(history):
    
    plt.plot(history.history['accuracy'], label='Тренировочный набор')
    plt.plot(history.history['val_accuracy'], label='Валидационный набор')
    plt.xlabel('Количество эпох')
    plt.ylabel('Точность')
    plt.ylim([0, 1.0])
    plt.legend(loc='upper left')
    plt.show()

    
    plt.plot(history.history['loss'], label='Отклонение тр. набора')
    plt.plot(history.history['val_loss'], label='Отклонение влд. набора')
    plt.xlabel('Количество эпох')
    plt.ylabel('Отклонение')
    # plt.ylim([0, 3.5])
    plt.legend(loc='upper right')
    plt.show()

# %%
def save_model_and_weights(model, test_acc):
    
    test_acc = int(test_acc * 10000)
    model_json = model.to_json()
    with open('models\\model' + str(test_acc) + '.json', 'w') as json_file:
        json_file.write(model_json)
    
    model.save_weights('models\\model' + str(test_acc) + '.h5')
    print('Модель и весы сохранены.')

# %%
def load_model_and_weights(model_path, weights_path):
    
    json_file = open(model_path, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)

    
    model.load_weights(weights_path)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    print('Модель и весы загружены.')

# %%
def run_model():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagen = data_augmentation(x_train)

    epochs = 100
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))


    
    model = define_model(input_shape=x_train[0].shape, classes=len(fer_classes))
    model.summary()

    tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

    model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
                        steps_per_epoch=len(x_train) // batch_size,
                        validation_data=(x_val, y_val), verbose=2)
    test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=batch_size)

    plot_acc_loss(history)
    save_model_and_weights(model, test_acc)

# %%
run_model()
# Out:
# X_train shape: (28390, 48, 48, 1)
# Y_train shape: (28390, 7)
# X_test shape: (3549, 48, 48, 1)
# Y_test shape: (3549, 7)
# X_val shape: (3549, 48, 48, 1)
# Y_val shape: (3549, 7)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  batch_normalization (BatchN  (None, 46, 46, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 46, 46, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 44, 44, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 44, 44, 64)        0
#
#  dropout (Dropout)           (None, 44, 44, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 42, 42, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 40, 40, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 20, 20, 64)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 18, 18, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 18, 18, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 18, 18, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 128)       147584
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 4, 4, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 3,623,239
# Trainable params: 3,621,447
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/100
# C:\Users\nikit\AppData\Roaming\Python\Python310\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 443/443 - 30s - loss: 0.3456 - accuracy: 0.4173 - val_loss: 0.3885 - val_accuracy: 0.3801 - 30s/epoch - 67ms/step
# Epoch 2/100
# 443/443 - 22s - loss: 0.3085 - accuracy: 0.5326 - val_loss: 0.2976 - val_accuracy: 0.5700 - 22s/epoch - 50ms/step
# Epoch 3/100
# 443/443 - 22s - loss: 0.2844 - accuracy: 0.5915 - val_loss: 0.2741 - val_accuracy: 0.6298 - 22s/epoch - 49ms/step
# Epoch 4/100
# 443/443 - 20s - loss: 0.2674 - accuracy: 0.6332 - val_loss: 0.2593 - val_accuracy: 0.6602 - 20s/epoch - 46ms/step
# Epoch 5/100
# 443/443 - 19s - loss: 0.2563 - accuracy: 0.6584 - val_loss: 0.2436 - val_accuracy: 0.7030 - 19s/epoch - 43ms/step
# Epoch 6/100
# 443/443 - 19s - loss: 0.2481 - accuracy: 0.6810 - val_loss: 0.2368 - val_accuracy: 0.7185 - 19s/epoch - 43ms/step
# Epoch 7/100
# 443/443 - 19s - loss: 0.2414 - accuracy: 0.6952 - val_loss: 0.2490 - val_accuracy: 0.6872 - 19s/epoch - 44ms/step
# Epoch 8/100
# 443/443 - 19s - loss: 0.2357 - accuracy: 0.7071 - val_loss: 0.2316 - val_accuracy: 0.7137 - 19s/epoch - 43ms/step
# Epoch 9/100
# 443/443 - 20s - loss: 0.2313 - accuracy: 0.7182 - val_loss: 0.2213 - val_accuracy: 0.7402 - 20s/epoch - 45ms/step
# Epoch 10/100
# 443/443 - 20s - loss: 0.2272 - accuracy: 0.7322 - val_loss: 0.2152 - val_accuracy: 0.7681 - 20s/epoch - 45ms/step
# Epoch 11/100
# 443/443 - 20s - loss: 0.2240 - accuracy: 0.7387 - val_loss: 0.2145 - val_accuracy: 0.7740 - 20s/epoch - 45ms/step
# Epoch 12/100
# 443/443 - 19s - loss: 0.2209 - accuracy: 0.7462 - val_loss: 0.2175 - val_accuracy: 0.7580 - 19s/epoch - 44ms/step
# Epoch 13/100
# 443/443 - 19s - loss: 0.2176 - accuracy: 0.7537 - val_loss: 0.2135 - val_accuracy: 0.7675 - 19s/epoch - 43ms/step
# Epoch 14/100
# 443/443 - 19s - loss: 0.2155 - accuracy: 0.7597 - val_loss: 0.2177 - val_accuracy: 0.7582 - 19s/epoch - 43ms/step
# Epoch 15/100
# 443/443 - 19s - loss: 0.2132 - accuracy: 0.7638 - val_loss: 0.2074 - val_accuracy: 0.7791 - 19s/epoch - 42ms/step
# Epoch 16/100
# 443/443 - 19s - loss: 0.2115 - accuracy: 0.7699 - val_loss: 0.2065 - val_accuracy: 0.7861 - 19s/epoch - 42ms/step
# Epoch 17/100
# 443/443 - 19s - loss: 0.2096 - accuracy: 0.7735 - val_loss: 0.2043 - val_accuracy: 0.7921 - 19s/epoch - 42ms/step
# Epoch 18/100
# 443/443 - 19s - loss: 0.2081 - accuracy: 0.7789 - val_loss: 0.2069 - val_accuracy: 0.7670 - 19s/epoch - 42ms/step
# Epoch 19/100
# 443/443 - 19s - loss: 0.2068 - accuracy: 0.7802 - val_loss: 0.2017 - val_accuracy: 0.7918 - 19s/epoch - 43ms/step
# Epoch 20/100
# 443/443 - 20s - loss: 0.2051 - accuracy: 0.7852 - val_loss: 0.2026 - val_accuracy: 0.7929 - 20s/epoch - 45ms/step
# Epoch 21/100
# 443/443 - 19s - loss: 0.2041 - accuracy: 0.7878 - val_loss: 0.2077 - val_accuracy: 0.7830 - 19s/epoch - 42ms/step
# Epoch 22/100
# 443/443 - 19s - loss: 0.2031 - accuracy: 0.7893 - val_loss: 0.2015 - val_accuracy: 0.7937 - 19s/epoch - 42ms/step
# Epoch 23/100
# 443/443 - 19s - loss: 0.2016 - accuracy: 0.7953 - val_loss: 0.2008 - val_accuracy: 0.8025 - 19s/epoch - 42ms/step
# Epoch 24/100
# 443/443 - 19s - loss: 0.2007 - accuracy: 0.7967 - val_loss: 0.1989 - val_accuracy: 0.8019 - 19s/epoch - 42ms/step
# Epoch 25/100
# 443/443 - 22s - loss: 0.1994 - accuracy: 0.7976 - val_loss: 0.1988 - val_accuracy: 0.8087 - 22s/epoch - 50ms/step
# Epoch 26/100
# 443/443 - 20s - loss: 0.1989 - accuracy: 0.7987 - val_loss: 0.1957 - val_accuracy: 0.8157 - 20s/epoch - 46ms/step
# Epoch 27/100
# 443/443 - 20s - loss: 0.1980 - accuracy: 0.8035 - val_loss: 0.2006 - val_accuracy: 0.8061 - 20s/epoch - 44ms/step
# Epoch 28/100
# 443/443 - 20s - loss: 0.1971 - accuracy: 0.8059 - val_loss: 0.2004 - val_accuracy: 0.7873 - 20s/epoch - 44ms/step
# Epoch 29/100
# 443/443 - 19s - loss: 0.1966 - accuracy: 0.8078 - val_loss: 0.1947 - val_accuracy: 0.8242 - 19s/epoch - 42ms/step
# Epoch 30/100
# 443/443 - 19s - loss: 0.1959 - accuracy: 0.8105 - val_loss: 0.1989 - val_accuracy: 0.8005 - 19s/epoch - 42ms/step
# Epoch 31/100
# 443/443 - 19s - loss: 0.1950 - accuracy: 0.8107 - val_loss: 0.1971 - val_accuracy: 0.7994 - 19s/epoch - 42ms/step
# Epoch 32/100
# 443/443 - 19s - loss: 0.1945 - accuracy: 0.8131 - val_loss: 0.1936 - val_accuracy: 0.8160 - 19s/epoch - 42ms/step
# Epoch 33/100
# 443/443 - 19s - loss: 0.1939 - accuracy: 0.8122 - val_loss: 0.1945 - val_accuracy: 0.8185 - 19s/epoch - 42ms/step
# Epoch 34/100
# 443/443 - 19s - loss: 0.1924 - accuracy: 0.8186 - val_loss: 0.1971 - val_accuracy: 0.8025 - 19s/epoch - 42ms/step
# Epoch 35/100
# 443/443 - 19s - loss: 0.1922 - accuracy: 0.8164 - val_loss: 0.1946 - val_accuracy: 0.8104 - 19s/epoch - 42ms/step
# Epoch 36/100
# 443/443 - 19s - loss: 0.1922 - accuracy: 0.8196 - val_loss: 0.1992 - val_accuracy: 0.7957 - 19s/epoch - 42ms/step
# Epoch 37/100
# 443/443 - 19s - loss: 0.1910 - accuracy: 0.8204 - val_loss: 0.1947 - val_accuracy: 0.8160 - 19s/epoch - 42ms/step
# Epoch 38/100
# 443/443 - 19s - loss: 0.1905 - accuracy: 0.8246 - val_loss: 0.1996 - val_accuracy: 0.7971 - 19s/epoch - 42ms/step
# Epoch 39/100
# 443/443 - 19s - loss: 0.1900 - accuracy: 0.8227 - val_loss: 0.1946 - val_accuracy: 0.8087 - 19s/epoch - 42ms/step
# Epoch 40/100
# 443/443 - 19s - loss: 0.1903 - accuracy: 0.8260 - val_loss: 0.1975 - val_accuracy: 0.8061 - 19s/epoch - 43ms/step
# Epoch 41/100
# 443/443 - 19s - loss: 0.1891 - accuracy: 0.8250 - val_loss: 0.1945 - val_accuracy: 0.8143 - 19s/epoch - 42ms/step
# Epoch 42/100
# 443/443 - 20s - loss: 0.1886 - accuracy: 0.8265 - val_loss: 0.1931 - val_accuracy: 0.8205 - 20s/epoch - 46ms/step
# Epoch 43/100
# 443/443 - 19s - loss: 0.1882 - accuracy: 0.8296 - val_loss: 0.1921 - val_accuracy: 0.8174 - 19s/epoch - 42ms/step
# Epoch 44/100
# 443/443 - 19s - loss: 0.1880 - accuracy: 0.8272 - val_loss: 0.1921 - val_accuracy: 0.8219 - 19s/epoch - 43ms/step
# Epoch 45/100
# 443/443 - 19s - loss: 0.1874 - accuracy: 0.8343 - val_loss: 0.1913 - val_accuracy: 0.8284 - 19s/epoch - 43ms/step
# Epoch 46/100
# 443/443 - 20s - loss: 0.1870 - accuracy: 0.8335 - val_loss: 0.1898 - val_accuracy: 0.8304 - 20s/epoch - 46ms/step
# Epoch 47/100
# 443/443 - 20s - loss: 0.1863 - accuracy: 0.8368 - val_loss: 0.1917 - val_accuracy: 0.8163 - 20s/epoch - 45ms/step
# Epoch 48/100
# 443/443 - 19s - loss: 0.1862 - accuracy: 0.8346 - val_loss: 0.1900 - val_accuracy: 0.8270 - 19s/epoch - 44ms/step
# Epoch 49/100
# 443/443 - 19s - loss: 0.1857 - accuracy: 0.8356 - val_loss: 0.1899 - val_accuracy: 0.8278 - 19s/epoch - 42ms/step
# Epoch 50/100
# 443/443 - 21s - loss: 0.1855 - accuracy: 0.8369 - val_loss: 0.1895 - val_accuracy: 0.8295 - 21s/epoch - 47ms/step
# Epoch 51/100
# 443/443 - 22s - loss: 0.1850 - accuracy: 0.8407 - val_loss: 0.1926 - val_accuracy: 0.8115 - 22s/epoch - 49ms/step
# Epoch 52/100
# 443/443 - 22s - loss: 0.1843 - accuracy: 0.8406 - val_loss: 0.1906 - val_accuracy: 0.8233 - 22s/epoch - 49ms/step
# Epoch 53/100
# 443/443 - 20s - loss: 0.1844 - accuracy: 0.8400 - val_loss: 0.1909 - val_accuracy: 0.8219 - 20s/epoch - 45ms/step
# Epoch 54/100
# 443/443 - 20s - loss: 0.1841 - accuracy: 0.8404 - val_loss: 0.1914 - val_accuracy: 0.8197 - 20s/epoch - 45ms/step
# Epoch 55/100
# 443/443 - 20s - loss: 0.1833 - accuracy: 0.8441 - val_loss: 0.1888 - val_accuracy: 0.8298 - 20s/epoch - 44ms/step
# Epoch 56/100
# 443/443 - 19s - loss: 0.1829 - accuracy: 0.8431 - val_loss: 0.1924 - val_accuracy: 0.8126 - 19s/epoch - 44ms/step
# Epoch 57/100
# 443/443 - 19s - loss: 0.1827 - accuracy: 0.8435 - val_loss: 0.1925 - val_accuracy: 0.8140 - 19s/epoch - 42ms/step
# Epoch 58/100
# 443/443 - 19s - loss: 0.1827 - accuracy: 0.8460 - val_loss: 0.1890 - val_accuracy: 0.8318 - 19s/epoch - 42ms/step
# Epoch 59/100
# 443/443 - 20s - loss: 0.1822 - accuracy: 0.8471 - val_loss: 0.1907 - val_accuracy: 0.8219 - 20s/epoch - 45ms/step
# Epoch 60/100
# 443/443 - 20s - loss: 0.1815 - accuracy: 0.8499 - val_loss: 0.1873 - val_accuracy: 0.8360 - 20s/epoch - 44ms/step
# Epoch 61/100
# 443/443 - 20s - loss: 0.1820 - accuracy: 0.8506 - val_loss: 0.1873 - val_accuracy: 0.8371 - 20s/epoch - 46ms/step
# Epoch 62/100
# 443/443 - 19s - loss: 0.1813 - accuracy: 0.8466 - val_loss: 0.1897 - val_accuracy: 0.8250 - 19s/epoch - 44ms/step
# Epoch 63/100
# 443/443 - 20s - loss: 0.1815 - accuracy: 0.8487 - val_loss: 0.1871 - val_accuracy: 0.8284 - 20s/epoch - 44ms/step
# Epoch 64/100
# 443/443 - 19s - loss: 0.1808 - accuracy: 0.8523 - val_loss: 0.1898 - val_accuracy: 0.8194 - 19s/epoch - 42ms/step
# Epoch 65/100
# 443/443 - 19s - loss: 0.1808 - accuracy: 0.8498 - val_loss: 0.1906 - val_accuracy: 0.8230 - 19s/epoch - 42ms/step
# Epoch 66/100
# 443/443 - 19s - loss: 0.1805 - accuracy: 0.8508 - val_loss: 0.1879 - val_accuracy: 0.8338 - 19s/epoch - 43ms/step
# Epoch 67/100
# 443/443 - 19s - loss: 0.1798 - accuracy: 0.8511 - val_loss: 0.1901 - val_accuracy: 0.8225 - 19s/epoch - 43ms/step
# Epoch 68/100
# 443/443 - 19s - loss: 0.1799 - accuracy: 0.8517 - val_loss: 0.1897 - val_accuracy: 0.8287 - 19s/epoch - 44ms/step
# Epoch 69/100
# 443/443 - 19s - loss: 0.1794 - accuracy: 0.8556 - val_loss: 0.1921 - val_accuracy: 0.8233 - 19s/epoch - 44ms/step
# Epoch 70/100
# 443/443 - 19s - loss: 0.1795 - accuracy: 0.8553 - val_loss: 0.1896 - val_accuracy: 0.8245 - 19s/epoch - 43ms/step
# Epoch 71/100
# 443/443 - 19s - loss: 0.1791 - accuracy: 0.8554 - val_loss: 0.1878 - val_accuracy: 0.8304 - 19s/epoch - 44ms/step
# Epoch 72/100
# 443/443 - 19s - loss: 0.1787 - accuracy: 0.8530 - val_loss: 0.1876 - val_accuracy: 0.8321 - 19s/epoch - 42ms/step
# Epoch 73/100
# 443/443 - 20s - loss: 0.1786 - accuracy: 0.8574 - val_loss: 0.1852 - val_accuracy: 0.8383 - 20s/epoch - 46ms/step
# Epoch 74/100
# 443/443 - 19s - loss: 0.1785 - accuracy: 0.8551 - val_loss: 0.1924 - val_accuracy: 0.8185 - 19s/epoch - 43ms/step
# Epoch 75/100
# 443/443 - 21s - loss: 0.1778 - accuracy: 0.8600 - val_loss: 0.1872 - val_accuracy: 0.8338 - 21s/epoch - 47ms/step
# Epoch 76/100
# 443/443 - 19s - loss: 0.1775 - accuracy: 0.8588 - val_loss: 0.1885 - val_accuracy: 0.8270 - 19s/epoch - 42ms/step
# Epoch 77/100
# 443/443 - 20s - loss: 0.1773 - accuracy: 0.8607 - val_loss: 0.1883 - val_accuracy: 0.8371 - 20s/epoch - 45ms/step
# Epoch 78/100
# 443/443 - 20s - loss: 0.1778 - accuracy: 0.8558 - val_loss: 0.1860 - val_accuracy: 0.8380 - 20s/epoch - 44ms/step
# Epoch 79/100
# 443/443 - 19s - loss: 0.1773 - accuracy: 0.8602 - val_loss: 0.1864 - val_accuracy: 0.8369 - 19s/epoch - 43ms/step
# Epoch 80/100
# 443/443 - 19s - loss: 0.1767 - accuracy: 0.8585 - val_loss: 0.1881 - val_accuracy: 0.8290 - 19s/epoch - 43ms/step
# Epoch 81/100
# 443/443 - 20s - loss: 0.1768 - accuracy: 0.8615 - val_loss: 0.1875 - val_accuracy: 0.8318 - 20s/epoch - 46ms/step
# Epoch 82/100
# 443/443 - 19s - loss: 0.1771 - accuracy: 0.8624 - val_loss: 0.1957 - val_accuracy: 0.8002 - 19s/epoch - 42ms/step
# Epoch 83/100
# 443/443 - 18s - loss: 0.1764 - accuracy: 0.8621 - val_loss: 0.1905 - val_accuracy: 0.8197 - 18s/epoch - 42ms/step
# Epoch 84/100
# 443/443 - 18s - loss: 0.1760 - accuracy: 0.8615 - val_loss: 0.1910 - val_accuracy: 0.8157 - 18s/epoch - 41ms/step
# Epoch 85/100
# 443/443 - 19s - loss: 0.1760 - accuracy: 0.8645 - val_loss: 0.1856 - val_accuracy: 0.8428 - 19s/epoch - 43ms/step
# Epoch 86/100
# 443/443 - 20s - loss: 0.1760 - accuracy: 0.8625 - val_loss: 0.1863 - val_accuracy: 0.8307 - 20s/epoch - 45ms/step
# Epoch 87/100
# 443/443 - 19s - loss: 0.1754 - accuracy: 0.8642 - val_loss: 0.1882 - val_accuracy: 0.8211 - 19s/epoch - 44ms/step
# Epoch 88/100
# 443/443 - 19s - loss: 0.1752 - accuracy: 0.8639 - val_loss: 0.1914 - val_accuracy: 0.8123 - 19s/epoch - 42ms/step
# Epoch 89/100
# 443/443 - 19s - loss: 0.1754 - accuracy: 0.8663 - val_loss: 0.1875 - val_accuracy: 0.8284 - 19s/epoch - 42ms/step
# Epoch 90/100
# 443/443 - 19s - loss: 0.1751 - accuracy: 0.8663 - val_loss: 0.1851 - val_accuracy: 0.8498 - 19s/epoch - 42ms/step
# Epoch 91/100
# 443/443 - 19s - loss: 0.1744 - accuracy: 0.8692 - val_loss: 0.1870 - val_accuracy: 0.8371 - 19s/epoch - 43ms/step
# Epoch 92/100
# 443/443 - 19s - loss: 0.1743 - accuracy: 0.8691 - val_loss: 0.1851 - val_accuracy: 0.8354 - 19s/epoch - 43ms/step
# Epoch 93/100
# 443/443 - 19s - loss: 0.1745 - accuracy: 0.8674 - val_loss: 0.1890 - val_accuracy: 0.8253 - 19s/epoch - 43ms/step
# Epoch 94/100
# 443/443 - 20s - loss: 0.1739 - accuracy: 0.8676 - val_loss: 0.1866 - val_accuracy: 0.8343 - 20s/epoch - 46ms/step
# Epoch 95/100
# 443/443 - 20s - loss: 0.1748 - accuracy: 0.8670 - val_loss: 0.1854 - val_accuracy: 0.8377 - 20s/epoch - 45ms/step
# Epoch 96/100
# 443/443 - 21s - loss: 0.1738 - accuracy: 0.8710 - val_loss: 0.1859 - val_accuracy: 0.8453 - 21s/epoch - 47ms/step
# Epoch 97/100
# 443/443 - 20s - loss: 0.1736 - accuracy: 0.8737 - val_loss: 0.1864 - val_accuracy: 0.8357 - 20s/epoch - 46ms/step
# Epoch 98/100
# 443/443 - 20s - loss: 0.1739 - accuracy: 0.8698 - val_loss: 0.1869 - val_accuracy: 0.8276 - 20s/epoch - 45ms/step
# Epoch 99/100
# 443/443 - 20s - loss: 0.1731 - accuracy: 0.8724 - val_loss: 0.1876 - val_accuracy: 0.8276 - 20s/epoch - 45ms/step
# Epoch 100/100
# 443/443 - 20s - loss: 0.1732 - accuracy: 0.8726 - val_loss: 0.1859 - val_accuracy: 0.8394 - 20s/epoch - 45ms/step
# 56/56 [==============================] - 1s 12ms/step - loss: 0.1859 - accuracy: 0.8326
# Модель и весы сохранены.

# %%
'''def test():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagood = data_good(x_train)
    show_images(datagood, x_train, y_train)
    datagen = data_augmentation(x_train)
    show_augmented_images(datagen, x_train, y_train)

    epochs = 2
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))'''
# Out:
# 'def test():\n    fer_classes = [\'neutral\', \'happiness\', \'surprise\', \'sadness\', \'anger\', \'disgust\', \'fear\', \'contempt\']\n\n    X, y = preprocess_data()\n    X, y = clean_data_and_normalize(X, y)\n    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)\n    datagood = data_good(x_train)\n    show_images(datagood, x_train, y_train)\n    datagen = data_augmentation(x_train)\n    show_augmented_images(datagen, x_train, y_train)\n\n    epochs = 2\n    batch_size = 64\n\n    print("X_train shape: " + str(x_train.shape))\n    print("Y_train shape: " + str(y_train.shape))\n    print("X_test shape: " + str(x_test.shape))\n    print("Y_test shape: " + str(y_test.shape))\n    print("X_val shape: " + str(x_val.shape))\n    print("Y_val shape: " + str(y_val.shape))'

# %%
#test()
