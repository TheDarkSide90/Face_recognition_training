# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pydot
import visualkeras
from keras.optimizers import Adam
from keras.models import Sequential, model_from_json
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import model_selection
from math import ceil
from PIL import ImageFont
from collections import defaultdict

import os
os.chdir('F:\Другое\PythonFiles\Facial-emotion-recognition-master')

print(os.getcwd())

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# f:\Другое\PythonFiles\Facial-emotion-recognition-master
# 1 Physical GPUs, 1 Logical GPUs

# %%
def preprocess_data():
    data = pd.read_csv('fer2013.csv')
    labels = pd.read_csv('fer2013new.csv')

    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    n_samples = len(data)
    w = 48
    h = 48

    y = np.array(labels[orig_class_names])
    X = np.zeros((n_samples, w, h, 1))
    for i in range(n_samples):
        X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((h, w, 1))

    return X, y

# %%
def clean_data_and_normalize(X, y):
    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

  
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('unknown')
    X = X[mask]
    y = y[mask]

  
    y = y[:, :-2] * 0.1

  
    y[:, 0] += y[:, 7]
    y = y[:, :7]

   
    X = X / 255.0

    return X, y

# %%
def split_data(X, y):
    test_size = ceil(len(X) * 0.1)

  
    x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x_train, y_train, test_size=test_size,
                                                                      random_state=42)
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def data_good(x_train):
    datagood = ImageDataGenerator()
    datagood.fit(x_train)
    return datagood

# %%
def data_augmentation(x_train):
    shift = 0.1
    datagen = ImageDataGenerator(
        rotation_range=20,
        horizontal_flip=True,
        height_shift_range=shift,
        width_shift_range=shift)
    datagen.fit(x_train)
    return datagen

# %%
def show_images(datagood, x_train, y_train):
    it = datagood.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def show_augmented_images(datagen, x_train, y_train):
    it = datagen.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def define_model(input_shape=(48, 48, 1), classes=7):
  

    model = tf.keras.models.Sequential()

  
    model.add(Conv2D(32, kernel_size=(1, 1), input_shape=input_shape, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

   
    model.add(Conv2D(64, (5, 5), strides=(1, 1), activation='relu', padding='same'))
    model.add(Conv2D(64, (2, 2), strides=(2, 2), activation='relu'))
    

  
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

   
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

  
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

    model.add(Conv2D(512, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(512, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))


    model.add(Flatten())

 
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.2))
    
    model.add(Dense(classes, activation='softmax'))

    return model

# %%
def plot_acc_loss(history):
  
    plt.plot(history.history['accuracy'], label='Тренировочный набор')
    plt.plot(history.history['val_accuracy'], label='Валидационный набор')
    plt.xlabel('Количество эпох')
    plt.ylabel('Точность')
    plt.ylim([0, 1.0])
    plt.legend(loc='upper left')
    plt.show()

  
    plt.plot(history.history['loss'], label='Отклонение тр. набора')
    plt.plot(history.history['val_loss'], label='Отклонение влд. набора')
    plt.xlabel('Количество эпох')
    plt.ylabel('Отклонение')
    # plt.ylim([0, 3.5])
    plt.legend(loc='upper right')
    plt.show()

# %%
def save_model_and_weights(model, test_acc):
  
    test_acc = int(test_acc * 10000)
    model_json = model.to_json()
    with open('models\\model' + str(test_acc) + '.json', 'w') as json_file:
        json_file.write(model_json)
   
    model.save_weights('models\\model' + str(test_acc) + '.h5')
    color_map = defaultdict(dict)
    color_map[Flatten]['fill'] = 'black'
    color_map[Dense]['fill'] = 'green'
    font = ImageFont.truetype("arial.ttf", 28)
    visualkeras.layered_view(model, legend=True, font=font, to_file='output.png')
    print('Модель и весы сохранены.')

# %%
def load_model_and_weights(model_path, weights_path):
   
    json_file = open(model_path, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)

  
    model.load_weights(weights_path)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    print('Модель и весы загружены.')

# %%
def run_model():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagen = data_augmentation(x_train)

    epochs = 100
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))


  
    model = define_model(input_shape=x_train[0].shape, classes=len(fer_classes))
    model.summary()

    tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

  
    visualkeras.layered_view(model, legend=True)
    visualkeras.layered_view(model, legend=True, to_file='output.png')

    model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
                        steps_per_epoch=len(x_train) // batch_size,
                        validation_data=(x_val, y_val), verbose=2)
    test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=batch_size)

    plot_acc_loss(history)
    save_model_and_weights(model, test_acc)

# %%
run_model()
# Out:
# X_train shape: (28390, 48, 48, 1)
# Y_train shape: (28390, 7)
# X_test shape: (3549, 48, 48, 1)
# Y_test shape: (3549, 7)
# X_val shape: (3549, 48, 48, 1)
# Y_val shape: (3549, 7)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        64
#
#  batch_normalization (BatchN  (None, 48, 48, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_1 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 48, 48, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_2 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_3 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 48, 48, 32)        0
#
#  dropout (Dropout)           (None, 48, 48, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  activation_4 (Activation)   (None, 48, 48, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 64)        36928
#
#  batch_normalization_5 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  activation_5 (Activation)   (None, 48, 48, 64)        0
#
#  dropout_1 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 48, 48, 64)        102464
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 64)        16448
#
#  conv2d_8 (Conv2D)           (None, 22, 22, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 22, 22, 128)      512
#  hNormalization)
#
#  activation_6 (Activation)   (None, 22, 22, 128)       0
#
#  conv2d_9 (Conv2D)           (None, 20, 20, 128)       147584
#
#  batch_normalization_7 (Batc  (None, 20, 20, 128)      512
#  hNormalization)
#
#  activation_7 (Activation)   (None, 20, 20, 128)       0
#
#  dropout_2 (Dropout)         (None, 20, 20, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 18, 18, 128)       147584
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 128)        0
#  )
#
#  conv2d_12 (Conv2D)          (None, 6, 6, 256)         295168
#
#  batch_normalization_8 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  activation_8 (Activation)   (None, 6, 6, 256)         0
#
#  conv2d_13 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_9 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 256)         0
#
#  dropout_3 (Dropout)         (None, 4, 4, 256)         0
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  batch_normalization_10 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_10 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_11 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_11 (Activation)  (None, 4, 4, 512)         0
#
#  dropout_4 (Dropout)         (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1024)              8389632
#
#  dropout_5 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 13,524,391
# Trainable params: 13,520,295
# Non-trainable params: 4,096
# _________________________________________________________________
# C:\Users\nikit\AppData\Roaming\Python\Python310\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# 443/443 - 48s - loss: 0.3581 - accuracy: 0.3661 - val_loss: 0.3978 - val_accuracy: 0.3801 - 48s/epoch - 109ms/step
# Epoch 2/100
# 443/443 - 36s - loss: 0.3328 - accuracy: 0.4570 - val_loss: 0.3506 - val_accuracy: 0.4494 - 36s/epoch - 82ms/step
# Epoch 3/100
# 443/443 - 34s - loss: 0.3103 - accuracy: 0.5314 - val_loss: 0.2905 - val_accuracy: 0.5869 - 34s/epoch - 76ms/step
# Epoch 4/100
# 443/443 - 34s - loss: 0.2936 - accuracy: 0.5761 - val_loss: 0.2943 - val_accuracy: 0.6058 - 34s/epoch - 77ms/step
# Epoch 5/100
# 443/443 - 34s - loss: 0.2793 - accuracy: 0.6112 - val_loss: 0.2569 - val_accuracy: 0.6650 - 34s/epoch - 76ms/step
# Epoch 6/100
# 443/443 - 35s - loss: 0.2651 - accuracy: 0.6393 - val_loss: 0.2574 - val_accuracy: 0.6627 - 35s/epoch - 80ms/step
# Epoch 7/100
# 443/443 - 35s - loss: 0.2559 - accuracy: 0.6629 - val_loss: 0.2449 - val_accuracy: 0.6934 - 35s/epoch - 80ms/step
# Epoch 8/100
# 443/443 - 35s - loss: 0.2478 - accuracy: 0.6843 - val_loss: 0.2473 - val_accuracy: 0.7194 - 35s/epoch - 78ms/step
# Epoch 9/100
# 443/443 - 34s - loss: 0.2424 - accuracy: 0.6981 - val_loss: 0.2350 - val_accuracy: 0.7303 - 34s/epoch - 77ms/step
# Epoch 10/100
# 443/443 - 34s - loss: 0.2376 - accuracy: 0.7084 - val_loss: 0.2448 - val_accuracy: 0.7092 - 34s/epoch - 78ms/step
# Epoch 11/100
# 443/443 - 34s - loss: 0.2329 - accuracy: 0.7180 - val_loss: 0.2277 - val_accuracy: 0.7312 - 34s/epoch - 76ms/step
# Epoch 12/100
# 443/443 - 33s - loss: 0.2293 - accuracy: 0.7282 - val_loss: 0.2246 - val_accuracy: 0.7571 - 33s/epoch - 75ms/step
# Epoch 13/100
# 443/443 - 33s - loss: 0.2258 - accuracy: 0.7373 - val_loss: 0.2248 - val_accuracy: 0.7453 - 33s/epoch - 75ms/step
# Epoch 14/100
# 443/443 - 33s - loss: 0.2226 - accuracy: 0.7410 - val_loss: 0.2138 - val_accuracy: 0.7687 - 33s/epoch - 75ms/step
# Epoch 15/100
# 443/443 - 34s - loss: 0.2205 - accuracy: 0.7498 - val_loss: 0.2118 - val_accuracy: 0.7661 - 34s/epoch - 77ms/step
# Epoch 16/100
# 443/443 - 33s - loss: 0.2185 - accuracy: 0.7546 - val_loss: 0.2326 - val_accuracy: 0.7272 - 33s/epoch - 75ms/step
# Epoch 17/100
# 443/443 - 33s - loss: 0.2155 - accuracy: 0.7605 - val_loss: 0.2125 - val_accuracy: 0.7774 - 33s/epoch - 75ms/step
# Epoch 18/100
# 443/443 - 33s - loss: 0.2135 - accuracy: 0.7669 - val_loss: 0.2087 - val_accuracy: 0.7819 - 33s/epoch - 75ms/step
# Epoch 19/100
# 443/443 - 34s - loss: 0.2122 - accuracy: 0.7705 - val_loss: 0.2196 - val_accuracy: 0.7763 - 34s/epoch - 77ms/step
# Epoch 20/100
# 443/443 - 33s - loss: 0.2099 - accuracy: 0.7753 - val_loss: 0.2068 - val_accuracy: 0.7813 - 33s/epoch - 75ms/step
# Epoch 21/100
# 443/443 - 33s - loss: 0.2086 - accuracy: 0.7813 - val_loss: 0.2036 - val_accuracy: 0.7864 - 33s/epoch - 75ms/step
# Epoch 22/100
# 443/443 - 33s - loss: 0.2070 - accuracy: 0.7832 - val_loss: 0.2082 - val_accuracy: 0.7912 - 33s/epoch - 75ms/step
# Epoch 23/100
# 443/443 - 33s - loss: 0.2061 - accuracy: 0.7833 - val_loss: 0.2059 - val_accuracy: 0.7878 - 33s/epoch - 75ms/step
# Epoch 24/100
# 443/443 - 33s - loss: 0.2048 - accuracy: 0.7867 - val_loss: 0.1999 - val_accuracy: 0.8030 - 33s/epoch - 75ms/step
# Epoch 25/100
# 443/443 - 33s - loss: 0.2035 - accuracy: 0.7883 - val_loss: 0.2014 - val_accuracy: 0.7898 - 33s/epoch - 75ms/step
# Epoch 26/100
# 443/443 - 33s - loss: 0.2020 - accuracy: 0.7940 - val_loss: 0.1971 - val_accuracy: 0.8101 - 33s/epoch - 75ms/step
# Epoch 27/100
# 443/443 - 33s - loss: 0.2009 - accuracy: 0.7960 - val_loss: 0.1997 - val_accuracy: 0.8129 - 33s/epoch - 75ms/step
# Epoch 28/100
# 443/443 - 35s - loss: 0.2001 - accuracy: 0.7988 - val_loss: 0.1994 - val_accuracy: 0.7929 - 35s/epoch - 78ms/step
# Epoch 29/100
# 443/443 - 34s - loss: 0.1988 - accuracy: 0.8009 - val_loss: 0.2002 - val_accuracy: 0.8064 - 34s/epoch - 78ms/step
# Epoch 30/100
# 443/443 - 35s - loss: 0.1988 - accuracy: 0.8072 - val_loss: 0.1963 - val_accuracy: 0.8073 - 35s/epoch - 78ms/step
# Epoch 31/100
# 443/443 - 34s - loss: 0.1974 - accuracy: 0.8038 - val_loss: 0.1978 - val_accuracy: 0.8045 - 34s/epoch - 77ms/step
# Epoch 32/100
# 443/443 - 34s - loss: 0.1969 - accuracy: 0.8081 - val_loss: 0.1961 - val_accuracy: 0.8090 - 34s/epoch - 78ms/step
# Epoch 70/100
# 443/443 - 34s - loss: 0.1790 - accuracy: 0.8571 - val_loss: 0.1890 - val_accuracy: 0.8354 - 34s/epoch - 77ms/step
# Epoch 71/100
# 443/443 - 36s - loss: 0.1785 - accuracy: 0.8596 - val_loss: 0.1890 - val_accuracy: 0.8267 - 36s/epoch - 82ms/step
# Epoch 72/100
# 443/443 - 37s - loss: 0.1788 - accuracy: 0.8583 - val_loss: 0.1885 - val_accuracy: 0.8256 - 37s/epoch - 83ms/step
# Epoch 73/100
# 443/443 - 35s - loss: 0.1783 - accuracy: 0.8591 - val_loss: 0.1894 - val_accuracy: 0.8360 - 35s/epoch - 78ms/step
# Epoch 74/100
# 443/443 - 36s - loss: 0.1780 - accuracy: 0.8607 - val_loss: 0.1859 - val_accuracy: 0.8405 - 36s/epoch - 82ms/step
# Epoch 75/100
# 443/443 - 35s - loss: 0.1779 - accuracy: 0.8610 - val_loss: 0.1860 - val_accuracy: 0.8329 - 35s/epoch - 78ms/step
# Epoch 76/100
# 443/443 - 35s - loss: 0.1773 - accuracy: 0.8642 - val_loss: 0.1864 - val_accuracy: 0.8354 - 35s/epoch - 79ms/step
# Epoch 77/100
# 443/443 - 34s - loss: 0.1771 - accuracy: 0.8637 - val_loss: 0.1900 - val_accuracy: 0.8247 - 34s/epoch - 76ms/step
# Epoch 78/100
# 443/443 - 34s - loss: 0.1768 - accuracy: 0.8632 - val_loss: 0.1868 - val_accuracy: 0.8346 - 34s/epoch - 76ms/step
# Epoch 79/100
# 443/443 - 34s - loss: 0.1766 - accuracy: 0.8640 - val_loss: 0.1866 - val_accuracy: 0.8439 - 34s/epoch - 77ms/step
# Epoch 80/100
# 443/443 - 34s - loss: 0.1764 - accuracy: 0.8640 - val_loss: 0.1886 - val_accuracy: 0.8264 - 34s/epoch - 76ms/step
# Epoch 81/100
# 443/443 - 34s - loss: 0.1762 - accuracy: 0.8672 - val_loss: 0.1889 - val_accuracy: 0.8276 - 34s/epoch - 77ms/step
# Epoch 82/100
# 443/443 - 35s - loss: 0.1759 - accuracy: 0.8655 - val_loss: 0.1890 - val_accuracy: 0.8199 - 35s/epoch - 79ms/step
# Epoch 83/100
# 443/443 - 34s - loss: 0.1758 - accuracy: 0.8656 - val_loss: 0.1912 - val_accuracy: 0.8073 - 34s/epoch - 76ms/step
# Epoch 84/100
# 443/443 - 34s - loss: 0.1753 - accuracy: 0.8703 - val_loss: 0.1873 - val_accuracy: 0.8312 - 34s/epoch - 76ms/step
# Epoch 85/100
# 443/443 - 34s - loss: 0.1754 - accuracy: 0.8691 - val_loss: 0.1853 - val_accuracy: 0.8462 - 34s/epoch - 77ms/step
# Epoch 86/100
# 443/443 - 34s - loss: 0.1747 - accuracy: 0.8686 - val_loss: 0.1857 - val_accuracy: 0.8388 - 34s/epoch - 76ms/step
# Epoch 87/100
# 443/443 - 35s - loss: 0.1749 - accuracy: 0.8688 - val_loss: 0.1861 - val_accuracy: 0.8425 - 35s/epoch - 78ms/step
# Epoch 88/100
# 443/443 - 37s - loss: 0.1743 - accuracy: 0.8702 - val_loss: 0.1871 - val_accuracy: 0.8383 - 37s/epoch - 85ms/step
# Epoch 89/100
# 443/443 - 34s - loss: 0.1744 - accuracy: 0.8708 - val_loss: 0.1860 - val_accuracy: 0.8414 - 34s/epoch - 78ms/step
# Epoch 90/100
# 443/443 - 36s - loss: 0.1739 - accuracy: 0.8737 - val_loss: 0.1852 - val_accuracy: 0.8394 - 36s/epoch - 81ms/step
# Epoch 91/100
# 443/443 - 38s - loss: 0.1737 - accuracy: 0.8728 - val_loss: 0.1887 - val_accuracy: 0.8273 - 38s/epoch - 85ms/step
# Epoch 92/100
# 443/443 - 36s - loss: 0.1737 - accuracy: 0.8735 - val_loss: 0.1851 - val_accuracy: 0.8422 - 36s/epoch - 82ms/step
# Epoch 93/100
# 443/443 - 38s - loss: 0.1732 - accuracy: 0.8748 - val_loss: 0.1861 - val_accuracy: 0.8408 - 38s/epoch - 85ms/step
# Epoch 94/100
# 443/443 - 37s - loss: 0.1731 - accuracy: 0.8728 - val_loss: 0.1878 - val_accuracy: 0.8411 - 37s/epoch - 84ms/step
# Epoch 95/100
# 443/443 - 37s - loss: 0.1730 - accuracy: 0.8743 - val_loss: 0.1886 - val_accuracy: 0.8338 - 37s/epoch - 83ms/step
# Epoch 96/100
# 443/443 - 37s - loss: 0.1721 - accuracy: 0.8786 - val_loss: 0.1905 - val_accuracy: 0.8433 - 37s/epoch - 84ms/step
# Epoch 97/100
# 443/443 - 37s - loss: 0.1725 - accuracy: 0.8741 - val_loss: 0.1857 - val_accuracy: 0.8411 - 37s/epoch - 83ms/step
# Epoch 98/100
# 443/443 - 37s - loss: 0.1726 - accuracy: 0.8740 - val_loss: 0.1907 - val_accuracy: 0.8202 - 37s/epoch - 84ms/step
# Epoch 99/100
# 443/443 - 38s - loss: 0.1719 - accuracy: 0.8758 - val_loss: 0.1885 - val_accuracy: 0.8284 - 38s/epoch - 86ms/step
# Epoch 100/100
# 443/443 - 38s - loss: 0.1720 - accuracy: 0.8769 - val_loss: 0.1855 - val_accuracy: 0.8402 - 38s/epoch - 87ms/step
# 56/56 [==============================] - 1s 19ms/step - loss: 0.1856 - accuracy: 0.8383
# Модель и весы сохранены.

# %%
'''def test():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagood = data_good(x_train)
    show_images(datagood, x_train, y_train)
    datagen = data_augmentation(x_train)
    show_augmented_images(datagen, x_train, y_train)

    epochs = 2
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))'''
# Out:
# 'def test():\n    fer_classes = [\'neutral\', \'happiness\', \'surprise\', \'sadness\', \'anger\', \'disgust\', \'fear\', \'contempt\']\n\n    X, y = preprocess_data()\n    X, y = clean_data_and_normalize(X, y)\n    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)\n    datagood = data_good(x_train)\n    show_images(datagood, x_train, y_train)\n    datagen = data_augmentation(x_train)\n    show_augmented_images(datagen, x_train, y_train)\n\n    epochs = 2\n    batch_size = 64\n\n    print("X_train shape: " + str(x_train.shape))\n    print("Y_train shape: " + str(y_train.shape))\n    print("X_test shape: " + str(x_test.shape))\n    print("Y_test shape: " + str(y_test.shape))\n    print("X_val shape: " + str(x_val.shape))\n    print("Y_val shape: " + str(y_val.shape))'

# %%
#test()
