# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pydot
import visualkeras
from keras.optimizers import Adam
from keras.models import Sequential, model_from_json
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import model_selection
from math import ceil
from PIL import ImageFont
from collections import defaultdict

import os
os.chdir('F:\Другое\PythonFiles\Facial-emotion-recognition-master')

print(os.getcwd())

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# f:\Другое\PythonFiles\Facial-emotion-recognition-master
# 1 Physical GPUs, 1 Logical GPUs

# %%
def preprocess_data():
    data = pd.read_csv('fer2013.csv')
    labels = pd.read_csv('fer2013new.csv')

    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    n_samples = len(data)
    w = 48
    h = 48

    y = np.array(labels[orig_class_names])
    X = np.zeros((n_samples, w, h, 1))
    for i in range(n_samples):
        X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((h, w, 1))

    return X, y

# %%
def clean_data_and_normalize(X, y):
    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

   
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('unknown')
    X = X[mask]
    y = y[mask]

  
    y = y[:, :-2] * 0.1

 
    y[:, 0] += y[:, 7]
    y = y[:, :7]

   
    X = X / 255.0

    return X, y

# %%
def split_data(X, y):
    test_size = ceil(len(X) * 0.1)

   
    x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x_train, y_train, test_size=test_size,
                                                                      random_state=42)
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def data_good(x_train):
    datagood = ImageDataGenerator()
    datagood.fit(x_train)
    return datagood

# %%
def data_augmentation(x_train):
    shift = 0.1
    datagen = ImageDataGenerator(
        rotation_range=20,
        horizontal_flip=True,
        height_shift_range=shift,
        width_shift_range=shift)
    datagen.fit(x_train)
    return datagen

# %%
def show_images(datagood, x_train, y_train):
    it = datagood.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def show_augmented_images(datagen, x_train, y_train):
    it = datagen.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def define_model(input_shape=(48, 48, 1), classes=7):
  

    model = tf.keras.models.Sequential()

   
    model.add(Conv2D(64, kernel_size=(3, 3), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(64, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.5))

  
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

   
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

   
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

   
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

    model.add(Flatten())

   
    model.add(Dense(512, activation='relu'))
    
    model.add(Dense(classes, activation='softmax'))

    return model

# %%
def plot_acc_loss(history):
   
    plt.plot(history.history['accuracy'], label='Тренировочный набор')
    plt.plot(history.history['val_accuracy'], label='Валидационный набор')
    plt.xlabel('Количество эпох')
    plt.ylabel('Точность')
    plt.ylim([0, 1.0])
    plt.legend(loc='upper left')
    plt.show()

   
    plt.plot(history.history['loss'], label='Отклонение тр. набора')
    plt.plot(history.history['val_loss'], label='Отклонение влд. набора')
    plt.xlabel('Количество эпох')
    plt.ylabel('Отклонение')
    # plt.ylim([0, 3.5])
    plt.legend(loc='upper right')
    plt.show()

# %%
def save_model_and_weights(model, test_acc):
   
    test_acc = int(test_acc * 10000)
    model_json = model.to_json()
    with open('models\\model' + str(test_acc) + '.json', 'w') as json_file:
        json_file.write(model_json)
   
    model.save_weights('models\\model' + str(test_acc) + '.h5')
    color_map = defaultdict(dict)
    color_map[Flatten]['fill'] = 'black'
    color_map[Dense]['fill'] = 'green'
    font = ImageFont.truetype("arial.ttf", 28)
    visualkeras.layered_view(model, legend=True, font=font, to_file='output.png')
    print('Модель и весы сохранены.')

# %%
def load_model_and_weights(model_path, weights_path):
  
    json_file = open(model_path, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)

   
    model.load_weights(weights_path)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    print('Модель и весы загружены.')

# %%
def run_model():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagen = data_augmentation(x_train)

    epochs = 100
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))


   
    model = define_model(input_shape=x_train[0].shape, classes=len(fer_classes))
    model.summary()

    tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

  
    visualkeras.layered_view(model, legend=True)
    visualkeras.layered_view(model, legend=True, to_file='output.png')

    model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
                        steps_per_epoch=len(x_train) // batch_size,
                        validation_data=(x_val, y_val), verbose=2)
    test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=batch_size)

    plot_acc_loss(history)
    save_model_and_weights(model, test_acc)

# %%
run_model()
# Out:
# X_train shape: (28390, 48, 48, 1)
# Y_train shape: (28390, 7)
# X_test shape: (3549, 48, 48, 1)
# Y_test shape: (3549, 7)
# X_val shape: (3549, 48, 48, 1)
# Y_val shape: (3549, 7)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  batch_normalization (BatchN  (None, 46, 46, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 46, 46, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 44, 44, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 44, 44, 64)        0
#
#  dropout (Dropout)           (None, 44, 44, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 42, 42, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 40, 40, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 20, 20, 64)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 18, 18, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 18, 18, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 18, 18, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 128)       147584
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 4, 4, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 2,045,255
# Trainable params: 2,043,463
# Non-trainable params: 1,792
# _________________________________________________________________
# C:\Users\nikit\AppData\Roaming\Python\Python310\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# 443/443 - 29s - loss: 0.3397 - accuracy: 0.4413 - val_loss: 0.3593 - val_accuracy: 0.3852 - 29s/epoch - 66ms/step
# Epoch 2/100
# 443/443 - 19s - loss: 0.3032 - accuracy: 0.5485 - val_loss: 0.2805 - val_accuracy: 0.6047 - 19s/epoch - 42ms/step
# Epoch 3/100
# 443/443 - 18s - loss: 0.2796 - accuracy: 0.6062 - val_loss: 0.2662 - val_accuracy: 0.6509 - 18s/epoch - 40ms/step
# Epoch 4/100
# 443/443 - 18s - loss: 0.2647 - accuracy: 0.6372 - val_loss: 0.2519 - val_accuracy: 0.6785 - 18s/epoch - 40ms/step
# Epoch 5/100
# 443/443 - 18s - loss: 0.2538 - accuracy: 0.6652 - val_loss: 0.2458 - val_accuracy: 0.6878 - 18s/epoch - 40ms/step
# Epoch 6/100
# 443/443 - 19s - loss: 0.2454 - accuracy: 0.6842 - val_loss: 0.2400 - val_accuracy: 0.6932 - 19s/epoch - 42ms/step
# Epoch 7/100
# 443/443 - 18s - loss: 0.2395 - accuracy: 0.6994 - val_loss: 0.2410 - val_accuracy: 0.6985 - 18s/epoch - 40ms/step
# Epoch 8/100
# 443/443 - 18s - loss: 0.2341 - accuracy: 0.7134 - val_loss: 0.2241 - val_accuracy: 0.7419 - 18s/epoch - 40ms/step
# Epoch 9/100
# 443/443 - 18s - loss: 0.2293 - accuracy: 0.7238 - val_loss: 0.2583 - val_accuracy: 0.6430 - 18s/epoch - 40ms/step
# Epoch 10/100
# 443/443 - 18s - loss: 0.2253 - accuracy: 0.7355 - val_loss: 0.2167 - val_accuracy: 0.7571 - 18s/epoch - 40ms/step
# Epoch 11/100
# 443/443 - 18s - loss: 0.2223 - accuracy: 0.7393 - val_loss: 0.2239 - val_accuracy: 0.7230 - 18s/epoch - 40ms/step
# Epoch 12/100
# 443/443 - 18s - loss: 0.2190 - accuracy: 0.7472 - val_loss: 0.2140 - val_accuracy: 0.7661 - 18s/epoch - 40ms/step
# Epoch 13/100
# 443/443 - 18s - loss: 0.2171 - accuracy: 0.7550 - val_loss: 0.2107 - val_accuracy: 0.7706 - 18s/epoch - 40ms/step
# Epoch 14/100
# 443/443 - 18s - loss: 0.2138 - accuracy: 0.7608 - val_loss: 0.2123 - val_accuracy: 0.7757 - 18s/epoch - 40ms/step
# Epoch 15/100
# 443/443 - 18s - loss: 0.2124 - accuracy: 0.7652 - val_loss: 0.2073 - val_accuracy: 0.7898 - 18s/epoch - 40ms/step
# Epoch 16/100
# 443/443 - 18s - loss: 0.2105 - accuracy: 0.7689 - val_loss: 0.2086 - val_accuracy: 0.7850 - 18s/epoch - 41ms/step
# Epoch 17/100
# 443/443 - 18s - loss: 0.2084 - accuracy: 0.7752 - val_loss: 0.2126 - val_accuracy: 0.7687 - 18s/epoch - 40ms/step
# Epoch 18/100
# 443/443 - 18s - loss: 0.2072 - accuracy: 0.7789 - val_loss: 0.2041 - val_accuracy: 0.7949 - 18s/epoch - 40ms/step
# Epoch 19/100
# 443/443 - 19s - loss: 0.2055 - accuracy: 0.7863 - val_loss: 0.2014 - val_accuracy: 0.7884 - 19s/epoch - 43ms/step
# Epoch 20/100
# 443/443 - 18s - loss: 0.2038 - accuracy: 0.7886 - val_loss: 0.2029 - val_accuracy: 0.7937 - 18s/epoch - 40ms/step
# Epoch 21/100
# 443/443 - 18s - loss: 0.2027 - accuracy: 0.7913 - val_loss: 0.2037 - val_accuracy: 0.7974 - 18s/epoch - 40ms/step
# Epoch 22/100
# 443/443 - 18s - loss: 0.2021 - accuracy: 0.7916 - val_loss: 0.1988 - val_accuracy: 0.8098 - 18s/epoch - 40ms/step
# Epoch 23/100
# 443/443 - 18s - loss: 0.2010 - accuracy: 0.7946 - val_loss: 0.1993 - val_accuracy: 0.7923 - 18s/epoch - 40ms/step
# Epoch 24/100
# 443/443 - 18s - loss: 0.1995 - accuracy: 0.7985 - val_loss: 0.1971 - val_accuracy: 0.8115 - 18s/epoch - 40ms/step
# Epoch 25/100
# 443/443 - 18s - loss: 0.1989 - accuracy: 0.7997 - val_loss: 0.2003 - val_accuracy: 0.7971 - 18s/epoch - 40ms/step
# Epoch 26/100
# 443/443 - 18s - loss: 0.1976 - accuracy: 0.8055 - val_loss: 0.1984 - val_accuracy: 0.8036 - 18s/epoch - 40ms/step
# Epoch 27/100
# 443/443 - 18s - loss: 0.1975 - accuracy: 0.8050 - val_loss: 0.2016 - val_accuracy: 0.7991 - 18s/epoch - 40ms/step
# Epoch 28/100
# 443/443 - 18s - loss: 0.1959 - accuracy: 0.8067 - val_loss: 0.2018 - val_accuracy: 0.7946 - 18s/epoch - 40ms/step
# Epoch 29/100
# 443/443 - 18s - loss: 0.1955 - accuracy: 0.8096 - val_loss: 0.1970 - val_accuracy: 0.8045 - 18s/epoch - 40ms/step
# Epoch 30/100
# 443/443 - 18s - loss: 0.1940 - accuracy: 0.8142 - val_loss: 0.1959 - val_accuracy: 0.8078 - 18s/epoch - 41ms/step
# Epoch 31/100
# 443/443 - 19s - loss: 0.1933 - accuracy: 0.8153 - val_loss: 0.1969 - val_accuracy: 0.8107 - 19s/epoch - 43ms/step
# Epoch 32/100
# 443/443 - 19s - loss: 0.1931 - accuracy: 0.8131 - val_loss: 0.2051 - val_accuracy: 0.7980 - 19s/epoch - 42ms/step
# Epoch 33/100
# 443/443 - 19s - loss: 0.1927 - accuracy: 0.8155 - val_loss: 0.2011 - val_accuracy: 0.7985 - 19s/epoch - 42ms/step
# Epoch 34/100
# 443/443 - 19s - loss: 0.1913 - accuracy: 0.8208 - val_loss: 0.1963 - val_accuracy: 0.8154 - 19s/epoch - 42ms/step
# Epoch 35/100
# 443/443 - 19s - loss: 0.1909 - accuracy: 0.8204 - val_loss: 0.1936 - val_accuracy: 0.8208 - 19s/epoch - 43ms/step
# Epoch 36/100
# 443/443 - 19s - loss: 0.1904 - accuracy: 0.8215 - val_loss: 0.1954 - val_accuracy: 0.8132 - 19s/epoch - 42ms/step
# Epoch 37/100
# 443/443 - 19s - loss: 0.1899 - accuracy: 0.8254 - val_loss: 0.1922 - val_accuracy: 0.8205 - 19s/epoch - 42ms/step
# Epoch 38/100
# 443/443 - 19s - loss: 0.1890 - accuracy: 0.8250 - val_loss: 0.1918 - val_accuracy: 0.8202 - 19s/epoch - 42ms/step
# Epoch 39/100
# 443/443 - 19s - loss: 0.1892 - accuracy: 0.8262 - val_loss: 0.1924 - val_accuracy: 0.8247 - 19s/epoch - 42ms/step
# Epoch 40/100
# 443/443 - 19s - loss: 0.1884 - accuracy: 0.8309 - val_loss: 0.1970 - val_accuracy: 0.8036 - 19s/epoch - 42ms/step
# Epoch 41/100
# 443/443 - 19s - loss: 0.1877 - accuracy: 0.8318 - val_loss: 0.1916 - val_accuracy: 0.8290 - 19s/epoch - 42ms/step
# Epoch 42/100
# 443/443 - 20s - loss: 0.1874 - accuracy: 0.8314 - val_loss: 0.1906 - val_accuracy: 0.8233 - 20s/epoch - 45ms/step
# Epoch 43/100
# 443/443 - 20s - loss: 0.1871 - accuracy: 0.8317 - val_loss: 0.1925 - val_accuracy: 0.8225 - 20s/epoch - 45ms/step
# Epoch 44/100
# 443/443 - 20s - loss: 0.1867 - accuracy: 0.8321 - val_loss: 0.1934 - val_accuracy: 0.8098 - 20s/epoch - 45ms/step
# Epoch 45/100
# 443/443 - 19s - loss: 0.1861 - accuracy: 0.8342 - val_loss: 0.1954 - val_accuracy: 0.8146 - 19s/epoch - 42ms/step
# Epoch 46/100
# 443/443 - 19s - loss: 0.1863 - accuracy: 0.8332 - val_loss: 0.1926 - val_accuracy: 0.8199 - 19s/epoch - 42ms/step
# Epoch 47/100
# 443/443 - 19s - loss: 0.1852 - accuracy: 0.8370 - val_loss: 0.1904 - val_accuracy: 0.8253 - 19s/epoch - 42ms/step
# Epoch 48/100
# 443/443 - 19s - loss: 0.1845 - accuracy: 0.8411 - val_loss: 0.1956 - val_accuracy: 0.8118 - 19s/epoch - 43ms/step
# Epoch 49/100
# 443/443 - 19s - loss: 0.1844 - accuracy: 0.8418 - val_loss: 0.1935 - val_accuracy: 0.8180 - 19s/epoch - 42ms/step
# Epoch 50/100
# 443/443 - 19s - loss: 0.1841 - accuracy: 0.8400 - val_loss: 0.1960 - val_accuracy: 0.8095 - 19s/epoch - 43ms/step
# Epoch 51/100
# 443/443 - 18s - loss: 0.1837 - accuracy: 0.8431 - val_loss: 0.1921 - val_accuracy: 0.8171 - 18s/epoch - 41ms/step
# Epoch 52/100
# 443/443 - 18s - loss: 0.1831 - accuracy: 0.8433 - val_loss: 0.1904 - val_accuracy: 0.8329 - 18s/epoch - 40ms/step
# Epoch 53/100
# 443/443 - 18s - loss: 0.1827 - accuracy: 0.8445 - val_loss: 0.1978 - val_accuracy: 0.7844 - 18s/epoch - 40ms/step
# Epoch 54/100
# 443/443 - 18s - loss: 0.1828 - accuracy: 0.8429 - val_loss: 0.1918 - val_accuracy: 0.8166 - 18s/epoch - 40ms/step
# Epoch 55/100
# 443/443 - 18s - loss: 0.1825 - accuracy: 0.8445 - val_loss: 0.1902 - val_accuracy: 0.8270 - 18s/epoch - 40ms/step
# Epoch 56/100
# 443/443 - 18s - loss: 0.1822 - accuracy: 0.8435 - val_loss: 0.1903 - val_accuracy: 0.8287 - 18s/epoch - 40ms/step
# Epoch 57/100
# 443/443 - 18s - loss: 0.1817 - accuracy: 0.8485 - val_loss: 0.1903 - val_accuracy: 0.8261 - 18s/epoch - 40ms/step
# Epoch 58/100
# 443/443 - 18s - loss: 0.1812 - accuracy: 0.8448 - val_loss: 0.1898 - val_accuracy: 0.8335 - 18s/epoch - 40ms/step
# Epoch 59/100
# 443/443 - 18s - loss: 0.1807 - accuracy: 0.8509 - val_loss: 0.1878 - val_accuracy: 0.8371 - 18s/epoch - 40ms/step
# Epoch 60/100
# 443/443 - 18s - loss: 0.1804 - accuracy: 0.8519 - val_loss: 0.1916 - val_accuracy: 0.8245 - 18s/epoch - 40ms/step
# Epoch 61/100
# 443/443 - 18s - loss: 0.1800 - accuracy: 0.8508 - val_loss: 0.1932 - val_accuracy: 0.8121 - 18s/epoch - 40ms/step
# Epoch 62/100
# 443/443 - 18s - loss: 0.1806 - accuracy: 0.8507 - val_loss: 0.2037 - val_accuracy: 0.7847 - 18s/epoch - 40ms/step
# Epoch 63/100
# 443/443 - 20s - loss: 0.1804 - accuracy: 0.8536 - val_loss: 0.1943 - val_accuracy: 0.8205 - 20s/epoch - 45ms/step
# Epoch 64/100
# 443/443 - 18s - loss: 0.1797 - accuracy: 0.8523 - val_loss: 0.1915 - val_accuracy: 0.8298 - 18s/epoch - 41ms/step
# Epoch 65/100
# 443/443 - 18s - loss: 0.1791 - accuracy: 0.8552 - val_loss: 0.1894 - val_accuracy: 0.8343 - 18s/epoch - 41ms/step
# Epoch 66/100
# 443/443 - 18s - loss: 0.1790 - accuracy: 0.8554 - val_loss: 0.1909 - val_accuracy: 0.8219 - 18s/epoch - 41ms/step
# Epoch 67/100
# 443/443 - 19s - loss: 0.1788 - accuracy: 0.8571 - val_loss: 0.1939 - val_accuracy: 0.8171 - 19s/epoch - 42ms/step
# Epoch 68/100
# 443/443 - 18s - loss: 0.1783 - accuracy: 0.8552 - val_loss: 0.1917 - val_accuracy: 0.8292 - 18s/epoch - 41ms/step
# Epoch 69/100
# 443/443 - 18s - loss: 0.1778 - accuracy: 0.8573 - val_loss: 0.1905 - val_accuracy: 0.8369 - 18s/epoch - 41ms/step
# Epoch 70/100
# 443/443 - 18s - loss: 0.1778 - accuracy: 0.8595 - val_loss: 0.1882 - val_accuracy: 0.8369 - 18s/epoch - 41ms/step
# Epoch 71/100
# 443/443 - 18s - loss: 0.1778 - accuracy: 0.8598 - val_loss: 0.1885 - val_accuracy: 0.8318 - 18s/epoch - 41ms/step
# Epoch 72/100
# 443/443 - 18s - loss: 0.1775 - accuracy: 0.8597 - val_loss: 0.1928 - val_accuracy: 0.8225 - 18s/epoch - 41ms/step
# Epoch 73/100
# 443/443 - 18s - loss: 0.1774 - accuracy: 0.8598 - val_loss: 0.1878 - val_accuracy: 0.8366 - 18s/epoch - 41ms/step
# Epoch 74/100
# 443/443 - 18s - loss: 0.1769 - accuracy: 0.8610 - val_loss: 0.1923 - val_accuracy: 0.8230 - 18s/epoch - 41ms/step
# Epoch 75/100
# 443/443 - 18s - loss: 0.1765 - accuracy: 0.8624 - val_loss: 0.1894 - val_accuracy: 0.8295 - 18s/epoch - 41ms/step
# Epoch 76/100
# 443/443 - 18s - loss: 0.1766 - accuracy: 0.8651 - val_loss: 0.1889 - val_accuracy: 0.8323 - 18s/epoch - 41ms/step
# Epoch 77/100
# 443/443 - 18s - loss: 0.1759 - accuracy: 0.8636 - val_loss: 0.1870 - val_accuracy: 0.8352 - 18s/epoch - 41ms/step
# Epoch 78/100
# 443/443 - 18s - loss: 0.1759 - accuracy: 0.8622 - val_loss: 0.1877 - val_accuracy: 0.8338 - 18s/epoch - 41ms/step
# Epoch 79/100
# 443/443 - 18s - loss: 0.1758 - accuracy: 0.8651 - val_loss: 0.1906 - val_accuracy: 0.8236 - 18s/epoch - 41ms/step
# Epoch 80/100
# 443/443 - 18s - loss: 0.1756 - accuracy: 0.8666 - val_loss: 0.1884 - val_accuracy: 0.8400 - 18s/epoch - 41ms/step
# Epoch 81/100
# 443/443 - 18s - loss: 0.1753 - accuracy: 0.8657 - val_loss: 0.1864 - val_accuracy: 0.8470 - 18s/epoch - 41ms/step
# Epoch 82/100
# 443/443 - 18s - loss: 0.1751 - accuracy: 0.8679 - val_loss: 0.1894 - val_accuracy: 0.8253 - 18s/epoch - 42ms/step
# Epoch 83/100
# 443/443 - 18s - loss: 0.1751 - accuracy: 0.8656 - val_loss: 0.1880 - val_accuracy: 0.8369 - 18s/epoch - 41ms/step
# Epoch 84/100
# 443/443 - 18s - loss: 0.1745 - accuracy: 0.8667 - val_loss: 0.1883 - val_accuracy: 0.8352 - 18s/epoch - 41ms/step
# Epoch 85/100
# 443/443 - 18s - loss: 0.1748 - accuracy: 0.8656 - val_loss: 0.1877 - val_accuracy: 0.8354 - 18s/epoch - 41ms/step
# Epoch 86/100
# 443/443 - 18s - loss: 0.1748 - accuracy: 0.8685 - val_loss: 0.1918 - val_accuracy: 0.8228 - 18s/epoch - 41ms/step
# Epoch 87/100
# 443/443 - 18s - loss: 0.1740 - accuracy: 0.8713 - val_loss: 0.1883 - val_accuracy: 0.8346 - 18s/epoch - 41ms/step
# Epoch 88/100
# 443/443 - 18s - loss: 0.1741 - accuracy: 0.8691 - val_loss: 0.1917 - val_accuracy: 0.8236 - 18s/epoch - 41ms/step
# Epoch 89/100
# 443/443 - 18s - loss: 0.1736 - accuracy: 0.8712 - val_loss: 0.1887 - val_accuracy: 0.8326 - 18s/epoch - 41ms/step
# Epoch 90/100
# 443/443 - 18s - loss: 0.1735 - accuracy: 0.8722 - val_loss: 0.1863 - val_accuracy: 0.8442 - 18s/epoch - 41ms/step
# Epoch 91/100
# 443/443 - 18s - loss: 0.1735 - accuracy: 0.8736 - val_loss: 0.1897 - val_accuracy: 0.8276 - 18s/epoch - 42ms/step
# Epoch 92/100
# 443/443 - 18s - loss: 0.1729 - accuracy: 0.8726 - val_loss: 0.1876 - val_accuracy: 0.8450 - 18s/epoch - 41ms/step
# Epoch 93/100
# 443/443 - 18s - loss: 0.1730 - accuracy: 0.8745 - val_loss: 0.1875 - val_accuracy: 0.8354 - 18s/epoch - 41ms/step
# Epoch 94/100
# 443/443 - 18s - loss: 0.1728 - accuracy: 0.8730 - val_loss: 0.1887 - val_accuracy: 0.8304 - 18s/epoch - 41ms/step
# Epoch 95/100
# 443/443 - 18s - loss: 0.1728 - accuracy: 0.8718 - val_loss: 0.1886 - val_accuracy: 0.8349 - 18s/epoch - 41ms/step
# Epoch 96/100
# 443/443 - 18s - loss: 0.1724 - accuracy: 0.8744 - val_loss: 0.1890 - val_accuracy: 0.8414 - 18s/epoch - 41ms/step
# Epoch 97/100
# 443/443 - 20s - loss: 0.1724 - accuracy: 0.8750 - val_loss: 0.1873 - val_accuracy: 0.8377 - 20s/epoch - 45ms/step
# Epoch 98/100
# 443/443 - 22s - loss: 0.1724 - accuracy: 0.8739 - val_loss: 0.1884 - val_accuracy: 0.8326 - 22s/epoch - 49ms/step
# Epoch 99/100
# 443/443 - 19s - loss: 0.1721 - accuracy: 0.8778 - val_loss: 0.1880 - val_accuracy: 0.8261 - 19s/epoch - 43ms/step
# Epoch 100/100
# 443/443 - 19s - loss: 0.1716 - accuracy: 0.8761 - val_loss: 0.1866 - val_accuracy: 0.8405 - 19s/epoch - 43ms/step
# 56/56 [==============================] - 1s 12ms/step - loss: 0.1863 - accuracy: 0.8301
# Модель и весы сохранены.

# %%
'''def test():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagood = data_good(x_train)
    show_images(datagood, x_train, y_train)
    datagen = data_augmentation(x_train)
    show_augmented_images(datagen, x_train, y_train)

    epochs = 2
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))'''
# Out:
# 'def test():\n    fer_classes = [\'neutral\', \'happiness\', \'surprise\', \'sadness\', \'anger\', \'disgust\', \'fear\', \'contempt\']\n\n    X, y = preprocess_data()\n    X, y = clean_data_and_normalize(X, y)\n    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)\n    datagood = data_good(x_train)\n    show_images(datagood, x_train, y_train)\n    datagen = data_augmentation(x_train)\n    show_augmented_images(datagen, x_train, y_train)\n\n    epochs = 2\n    batch_size = 64\n\n    print("X_train shape: " + str(x_train.shape))\n    print("Y_train shape: " + str(y_train.shape))\n    print("X_test shape: " + str(x_test.shape))\n    print("Y_test shape: " + str(y_test.shape))\n    print("X_val shape: " + str(x_val.shape))\n    print("Y_val shape: " + str(y_val.shape))'

# %%
#test()
