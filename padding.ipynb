# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pydot
import visualkeras
from keras.optimizers import Adam
from keras.models import Sequential, model_from_json
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import model_selection
from math import ceil
from PIL import ImageFont
from collections import defaultdict

import os
os.chdir('F:\Другое\PythonFiles\Facial-emotion-recognition-master')

print(os.getcwd())

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# f:\Другое\PythonFiles\Facial-emotion-recognition-master
# 1 Physical GPUs, 1 Logical GPUs

# %%
def preprocess_data():
    data = pd.read_csv('fer2013.csv')
    labels = pd.read_csv('fer2013new.csv')

    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    n_samples = len(data)
    w = 48
    h = 48

    y = np.array(labels[orig_class_names])
    X = np.zeros((n_samples, w, h, 1))
    for i in range(n_samples):
        X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((h, w, 1))

    return X, y

# %%
def clean_data_and_normalize(X, y):
    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('unknown')
    X = X[mask]
    y = y[mask]

   
    y = y[:, :-2] * 0.1

   
    y[:, 0] += y[:, 7]
    y = y[:, :7]

  
    X = X / 255.0

    return X, y

# %%
def split_data(X, y):
    test_size = ceil(len(X) * 0.1)

  
    x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x_train, y_train, test_size=test_size,
                                                                      random_state=42)
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def data_good(x_train):
    datagood = ImageDataGenerator()
    datagood.fit(x_train)
    return datagood

# %%
def data_augmentation(x_train):
    shift = 0.1
    datagen = ImageDataGenerator(
        rotation_range=20,
        horizontal_flip=True,
        height_shift_range=shift,
        width_shift_range=shift)
    datagen.fit(x_train)
    return datagen

# %%
def show_images(datagood, x_train, y_train):
    it = datagood.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def show_augmented_images(datagen, x_train, y_train):
    it = datagen.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def define_model(input_shape=(48, 48, 1), classes=7):
   

    model = tf.keras.models.Sequential()

   
    model.add(Conv2D(32, kernel_size=(1, 1), input_shape=input_shape, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.25))

 
    model.add(Conv2D(64, (5, 5), strides=(1, 1), activation='relu', padding='same'))
    model.add(Conv2D(64, (2, 2), strides=(2, 2), activation='relu'))
    

   
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

  
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

  
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

    model.add(Conv2D(512, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(512, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))


    model.add(Flatten())

  
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.2))
    
    model.add(Dense(classes, activation='softmax'))

    return model

# %%
def plot_acc_loss(history):
   
    plt.plot(history.history['accuracy'], label='Тренировочный набор')
    plt.plot(history.history['val_accuracy'], label='Валидационный набор')
    plt.xlabel('Количество эпох')
    plt.ylabel('Точность')
    plt.ylim([0, 1.0])
    plt.legend(loc='upper left')
    plt.show()

  
    plt.plot(history.history['loss'], label='Отклонение тр. набора')
    plt.plot(history.history['val_loss'], label='Отклонение влд. набора')
    plt.xlabel('Количество эпох')
    plt.ylabel('Отклонение')
    # plt.ylim([0, 3.5])
    plt.legend(loc='upper right')
    plt.show()

# %%
def save_model_and_weights(model, test_acc):
  
    test_acc = int(test_acc * 10000)
    model_json = model.to_json()
    with open('models\\model' + str(test_acc) + '.json', 'w') as json_file:
        json_file.write(model_json)
   
    model.save_weights('models\\model' + str(test_acc) + '.h5')
    color_map = defaultdict(dict)
    color_map[Flatten]['fill'] = 'black'
    color_map[Dense]['fill'] = 'green'
    font = ImageFont.truetype("arial.ttf", 28)
    visualkeras.layered_view(model, legend=True, font=font, to_file='output.png')
    print('Модель и весы сохранены.')

# %%
def load_model_and_weights(model_path, weights_path):
   
    json_file = open(model_path, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)

   
    model.load_weights(weights_path)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    print('Модель и весы загружены.')

# %%
def run_model():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagen = data_augmentation(x_train)

    epochs = 100
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))


   
    model = define_model(input_shape=x_train[0].shape, classes=len(fer_classes))
    model.summary()

    tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

   
    visualkeras.layered_view(model, legend=True)
    visualkeras.layered_view(model, legend=True, to_file='output.png')

    model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
                        steps_per_epoch=len(x_train) // batch_size,
                        validation_data=(x_val, y_val), verbose=2)
    test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=batch_size)

    plot_acc_loss(history)
    save_model_and_weights(model, test_acc)

# %%
run_model()
# Out:
# X_train shape: (28390, 48, 48, 1)
# Y_train shape: (28390, 7)
# X_test shape: (3549, 48, 48, 1)
# Y_test shape: (3549, 7)
# X_val shape: (3549, 48, 48, 1)
# Y_val shape: (3549, 7)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        64
#
#  batch_normalization (BatchN  (None, 48, 48, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_1 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 48, 48, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_2 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_3 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 48, 48, 32)        0
#
#  dropout (Dropout)           (None, 48, 48, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  activation_4 (Activation)   (None, 48, 48, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 64)        36928
#
#  batch_normalization_5 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  activation_5 (Activation)   (None, 48, 48, 64)        0
#
#  dropout_1 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 48, 48, 64)        102464
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 64)        16448
#
#  conv2d_8 (Conv2D)           (None, 22, 22, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 22, 22, 128)      512
#  hNormalization)
#
#  activation_6 (Activation)   (None, 22, 22, 128)       0
#
#  conv2d_9 (Conv2D)           (None, 20, 20, 128)       147584
#
#  batch_normalization_7 (Batc  (None, 20, 20, 128)      512
#  hNormalization)
#
#  activation_7 (Activation)   (None, 20, 20, 128)       0
#
#  dropout_2 (Dropout)         (None, 20, 20, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 18, 18, 128)       147584
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 128)        0
#  )
#
#  conv2d_12 (Conv2D)          (None, 6, 6, 256)         295168
#
#  batch_normalization_8 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  activation_8 (Activation)   (None, 6, 6, 256)         0
#
#  conv2d_13 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_9 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 256)         0
#
#  dropout_3 (Dropout)         (None, 4, 4, 256)         0
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  batch_normalization_10 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_10 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_11 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_11 (Activation)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1024)              8389632
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 13,524,391
# Trainable params: 13,520,295
# Non-trainable params: 4,096
# _________________________________________________________________
# C:\Users\nikit\AppData\Roaming\Python\Python310\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# 443/443 - 46s - loss: 0.3559 - accuracy: 0.3668 - val_loss: 0.3637 - val_accuracy: 0.4029 - 46s/epoch - 104ms/step
# Epoch 2/100
# 443/443 - 37s - loss: 0.3349 - accuracy: 0.4478 - val_loss: 0.3395 - val_accuracy: 0.4782 - 37s/epoch - 85ms/step
# Epoch 3/100
# 443/443 - 36s - loss: 0.3176 - accuracy: 0.5095 - val_loss: 0.3072 - val_accuracy: 0.5587 - 36s/epoch - 82ms/step
# Epoch 4/100
# 443/443 - 35s - loss: 0.3007 - accuracy: 0.5549 - val_loss: 0.2821 - val_accuracy: 0.6162 - 35s/epoch - 80ms/step
# Epoch 5/100
# 443/443 - 35s - loss: 0.2856 - accuracy: 0.5914 - val_loss: 0.2763 - val_accuracy: 0.6210 - 35s/epoch - 80ms/step
# Epoch 6/100
# 443/443 - 35s - loss: 0.2734 - accuracy: 0.6258 - val_loss: 0.2809 - val_accuracy: 0.6357 - 35s/epoch - 79ms/step
# Epoch 7/100
# 443/443 - 36s - loss: 0.2618 - accuracy: 0.6509 - val_loss: 0.2432 - val_accuracy: 0.6985 - 36s/epoch - 81ms/step
# Epoch 8/100
# 443/443 - 35s - loss: 0.2544 - accuracy: 0.6654 - val_loss: 0.2376 - val_accuracy: 0.7070 - 35s/epoch - 79ms/step
# Epoch 9/100
# 443/443 - 35s - loss: 0.2476 - accuracy: 0.6842 - val_loss: 0.2418 - val_accuracy: 0.7120 - 35s/epoch - 79ms/step
# Epoch 10/100
# 443/443 - 35s - loss: 0.2422 - accuracy: 0.6948 - val_loss: 0.2275 - val_accuracy: 0.7306 - 35s/epoch - 79ms/step
# Epoch 11/100
# 443/443 - 35s - loss: 0.2366 - accuracy: 0.7085 - val_loss: 0.2299 - val_accuracy: 0.7337 - 35s/epoch - 79ms/step
# Epoch 12/100
# 443/443 - 37s - loss: 0.2327 - accuracy: 0.7202 - val_loss: 0.2233 - val_accuracy: 0.7363 - 37s/epoch - 83ms/step
# Epoch 13/100
# 443/443 - 35s - loss: 0.2292 - accuracy: 0.7253 - val_loss: 0.2291 - val_accuracy: 0.7354 - 35s/epoch - 80ms/step
# Epoch 14/100
# 443/443 - 35s - loss: 0.2261 - accuracy: 0.7340 - val_loss: 0.2115 - val_accuracy: 0.7636 - 35s/epoch - 79ms/step
# Epoch 15/100
# 443/443 - 35s - loss: 0.2233 - accuracy: 0.7400 - val_loss: 0.2141 - val_accuracy: 0.7611 - 35s/epoch - 79ms/step
# Epoch 16/100
# 443/443 - 37s - loss: 0.2209 - accuracy: 0.7489 - val_loss: 0.2177 - val_accuracy: 0.7602 - 37s/epoch - 84ms/step
# Epoch 17/100
# 443/443 - 36s - loss: 0.2183 - accuracy: 0.7552 - val_loss: 0.2211 - val_accuracy: 0.7551 - 36s/epoch - 82ms/step
# Epoch 18/100
# 443/443 - 35s - loss: 0.2169 - accuracy: 0.7593 - val_loss: 0.2130 - val_accuracy: 0.7816 - 35s/epoch - 79ms/step
# Epoch 19/100
# 443/443 - 35s - loss: 0.2141 - accuracy: 0.7651 - val_loss: 0.2060 - val_accuracy: 0.7890 - 35s/epoch - 79ms/step
# Epoch 20/100
# 443/443 - 36s - loss: 0.2124 - accuracy: 0.7670 - val_loss: 0.2135 - val_accuracy: 0.7720 - 36s/epoch - 81ms/step
# Epoch 21/100
# 443/443 - 37s - loss: 0.2116 - accuracy: 0.7711 - val_loss: 0.2110 - val_accuracy: 0.7839 - 37s/epoch - 83ms/step
# Epoch 22/100
# 443/443 - 37s - loss: 0.2094 - accuracy: 0.7772 - val_loss: 0.2093 - val_accuracy: 0.7689 - 37s/epoch - 84ms/step
# Epoch 23/100
# 443/443 - 37s - loss: 0.2081 - accuracy: 0.7784 - val_loss: 0.2091 - val_accuracy: 0.7743 - 37s/epoch - 84ms/step
# Epoch 24/100
# 443/443 - 37s - loss: 0.2064 - accuracy: 0.7832 - val_loss: 0.2002 - val_accuracy: 0.7940 - 37s/epoch - 84ms/step
# Epoch 25/100
# 443/443 - 36s - loss: 0.2051 - accuracy: 0.7873 - val_loss: 0.1999 - val_accuracy: 0.8028 - 36s/epoch - 82ms/step
# Epoch 26/100
# 443/443 - 35s - loss: 0.2043 - accuracy: 0.7881 - val_loss: 0.2018 - val_accuracy: 0.7836 - 35s/epoch - 79ms/step
# Epoch 27/100
# 443/443 - 35s - loss: 0.2028 - accuracy: 0.7934 - val_loss: 0.1975 - val_accuracy: 0.8022 - 35s/epoch - 79ms/step
# Epoch 28/100
# 443/443 - 35s - loss: 0.2021 - accuracy: 0.7952 - val_loss: 0.2002 - val_accuracy: 0.7988 - 35s/epoch - 79ms/step
# Epoch 29/100
# 443/443 - 35s - loss: 0.2012 - accuracy: 0.7962 - val_loss: 0.1984 - val_accuracy: 0.7940 - 35s/epoch - 79ms/step
# Epoch 30/100
# 443/443 - 35s - loss: 0.2001 - accuracy: 0.8007 - val_loss: 0.1966 - val_accuracy: 0.8059 - 35s/epoch - 80ms/step
# Epoch 31/100
# 443/443 - 35s - loss: 0.1997 - accuracy: 0.8019 - val_loss: 0.2029 - val_accuracy: 0.7980 - 35s/epoch - 79ms/step
# Epoch 32/100
# 443/443 - 36s - loss: 0.1978 - accuracy: 0.8061 - val_loss: 0.1961 - val_accuracy: 0.8160 - 36s/epoch - 81ms/step
# Epoch 33/100
# 443/443 - 35s - loss: 0.1975 - accuracy: 0.8067 - val_loss: 0.1974 - val_accuracy: 0.8140 - 35s/epoch - 79ms/step
# Epoch 34/100
# 443/443 - 35s - loss: 0.1968 - accuracy: 0.8099 - val_loss: 0.1959 - val_accuracy: 0.8078 - 35s/epoch - 79ms/step
# Epoch 35/100
# 443/443 - 35s - loss: 0.1965 - accuracy: 0.8077 - val_loss: 0.1932 - val_accuracy: 0.8087 - 35s/epoch - 79ms/step
# Epoch 36/100
# 443/443 - 36s - loss: 0.1950 - accuracy: 0.8121 - val_loss: 0.1959 - val_accuracy: 0.8045 - 36s/epoch - 82ms/step
# Epoch 37/100
# 443/443 - 39s - loss: 0.1945 - accuracy: 0.8132 - val_loss: 0.1943 - val_accuracy: 0.8104 - 39s/epoch - 87ms/step
# Epoch 38/100
# 443/443 - 37s - loss: 0.1935 - accuracy: 0.8197 - val_loss: 0.1930 - val_accuracy: 0.8132 - 37s/epoch - 84ms/step
# Epoch 39/100
# 443/443 - 36s - loss: 0.1936 - accuracy: 0.8183 - val_loss: 0.1991 - val_accuracy: 0.8011 - 36s/epoch - 80ms/step
# Epoch 40/100
# 443/443 - 35s - loss: 0.1925 - accuracy: 0.8199 - val_loss: 0.1921 - val_accuracy: 0.8261 - 35s/epoch - 79ms/step
# Epoch 41/100
# 443/443 - 35s - loss: 0.1921 - accuracy: 0.8211 - val_loss: 0.1936 - val_accuracy: 0.8152 - 35s/epoch - 79ms/step
# Epoch 42/100
# 443/443 - 35s - loss: 0.1915 - accuracy: 0.8224 - val_loss: 0.1946 - val_accuracy: 0.8107 - 35s/epoch - 78ms/step
# Epoch 43/100
# 443/443 - 35s - loss: 0.1911 - accuracy: 0.8238 - val_loss: 0.1896 - val_accuracy: 0.8236 - 35s/epoch - 79ms/step
# Epoch 44/100
# 443/443 - 35s - loss: 0.1901 - accuracy: 0.8262 - val_loss: 0.1935 - val_accuracy: 0.8109 - 35s/epoch - 79ms/step
# Epoch 45/100
# 443/443 - 36s - loss: 0.1895 - accuracy: 0.8284 - val_loss: 0.1921 - val_accuracy: 0.8191 - 36s/epoch - 81ms/step
# Epoch 46/100
# 443/443 - 36s - loss: 0.1896 - accuracy: 0.8265 - val_loss: 0.1980 - val_accuracy: 0.8022 - 36s/epoch - 82ms/step
# Epoch 47/100
# 443/443 - 36s - loss: 0.1887 - accuracy: 0.8299 - val_loss: 0.1920 - val_accuracy: 0.8230 - 36s/epoch - 81ms/step
# Epoch 48/100
# 443/443 - 39s - loss: 0.1882 - accuracy: 0.8331 - val_loss: 0.1909 - val_accuracy: 0.8199 - 39s/epoch - 88ms/step
# Epoch 49/100
# 443/443 - 36s - loss: 0.1880 - accuracy: 0.8347 - val_loss: 0.1882 - val_accuracy: 0.8276 - 36s/epoch - 82ms/step
# Epoch 50/100
# 443/443 - 36s - loss: 0.1875 - accuracy: 0.8343 - val_loss: 0.1911 - val_accuracy: 0.8166 - 36s/epoch - 81ms/step
# Epoch 51/100
# 443/443 - 35s - loss: 0.1867 - accuracy: 0.8366 - val_loss: 0.1916 - val_accuracy: 0.8168 - 35s/epoch - 79ms/step
# Epoch 52/100
# 443/443 - 35s - loss: 0.1863 - accuracy: 0.8380 - val_loss: 0.1910 - val_accuracy: 0.8107 - 35s/epoch - 79ms/step
# Epoch 53/100
# 443/443 - 35s - loss: 0.1859 - accuracy: 0.8380 - val_loss: 0.1955 - val_accuracy: 0.8183 - 35s/epoch - 79ms/step
# Epoch 54/100
# 443/443 - 35s - loss: 0.1853 - accuracy: 0.8398 - val_loss: 0.1899 - val_accuracy: 0.8256 - 35s/epoch - 79ms/step
# Epoch 55/100
# 443/443 - 35s - loss: 0.1853 - accuracy: 0.8378 - val_loss: 0.1913 - val_accuracy: 0.8191 - 35s/epoch - 80ms/step
# Epoch 56/100
# 443/443 - 37s - loss: 0.1850 - accuracy: 0.8428 - val_loss: 0.1916 - val_accuracy: 0.8307 - 37s/epoch - 84ms/step
# Epoch 57/100
# 443/443 - 39s - loss: 0.1845 - accuracy: 0.8434 - val_loss: 0.1912 - val_accuracy: 0.8129 - 39s/epoch - 87ms/step
# Epoch 58/100
# 443/443 - 38s - loss: 0.1837 - accuracy: 0.8445 - val_loss: 0.1919 - val_accuracy: 0.8199 - 38s/epoch - 86ms/step
# Epoch 59/100
# 443/443 - 38s - loss: 0.1836 - accuracy: 0.8435 - val_loss: 0.1894 - val_accuracy: 0.8273 - 38s/epoch - 86ms/step
# Epoch 60/100
# 443/443 - 37s - loss: 0.1836 - accuracy: 0.8440 - val_loss: 0.1876 - val_accuracy: 0.8340 - 37s/epoch - 84ms/step
# Epoch 61/100
# 443/443 - 37s - loss: 0.1829 - accuracy: 0.8473 - val_loss: 0.1878 - val_accuracy: 0.8377 - 37s/epoch - 83ms/step
# Epoch 62/100
# 443/443 - 37s - loss: 0.1823 - accuracy: 0.8473 - val_loss: 0.1893 - val_accuracy: 0.8360 - 37s/epoch - 84ms/step
# Epoch 63/100
# 443/443 - 37s - loss: 0.1821 - accuracy: 0.8463 - val_loss: 0.1903 - val_accuracy: 0.8264 - 37s/epoch - 84ms/step
# Epoch 64/100
# 443/443 - 35s - loss: 0.1819 - accuracy: 0.8482 - val_loss: 0.1869 - val_accuracy: 0.8321 - 35s/epoch - 79ms/step
# Epoch 65/100
# 443/443 - 35s - loss: 0.1819 - accuracy: 0.8500 - val_loss: 0.1884 - val_accuracy: 0.8256 - 35s/epoch - 79ms/step
# Epoch 66/100
# 443/443 - 38s - loss: 0.1809 - accuracy: 0.8525 - val_loss: 0.1864 - val_accuracy: 0.8332 - 38s/epoch - 87ms/step
# Epoch 67/100
# 443/443 - 36s - loss: 0.1805 - accuracy: 0.8550 - val_loss: 0.1888 - val_accuracy: 0.8343 - 36s/epoch - 82ms/step
# Epoch 68/100
# 443/443 - 37s - loss: 0.1810 - accuracy: 0.8509 - val_loss: 0.1879 - val_accuracy: 0.8312 - 37s/epoch - 83ms/step
# Epoch 69/100
# 443/443 - 35s - loss: 0.1802 - accuracy: 0.8544 - val_loss: 0.1895 - val_accuracy: 0.8247 - 35s/epoch - 79ms/step
# Epoch 70/100
# 443/443 - 36s - loss: 0.1798 - accuracy: 0.8545 - val_loss: 0.1869 - val_accuracy: 0.8360 - 36s/epoch - 81ms/step
# Epoch 71/100
# 443/443 - 35s - loss: 0.1795 - accuracy: 0.8581 - val_loss: 0.1883 - val_accuracy: 0.8202 - 35s/epoch - 79ms/step
# Epoch 72/100
# 443/443 - 35s - loss: 0.1795 - accuracy: 0.8587 - val_loss: 0.1872 - val_accuracy: 0.8290 - 35s/epoch - 80ms/step
# Epoch 73/100
# 443/443 - 35s - loss: 0.1790 - accuracy: 0.8599 - val_loss: 0.1873 - val_accuracy: 0.8309 - 35s/epoch - 80ms/step
# Epoch 74/100
# 443/443 - 35s - loss: 0.1787 - accuracy: 0.8594 - val_loss: 0.1866 - val_accuracy: 0.8315 - 35s/epoch - 79ms/step
# Epoch 75/100
# 443/443 - 35s - loss: 0.1781 - accuracy: 0.8594 - val_loss: 0.1879 - val_accuracy: 0.8332 - 35s/epoch - 79ms/step
# Epoch 76/100
# 443/443 - 35s - loss: 0.1779 - accuracy: 0.8608 - val_loss: 0.1873 - val_accuracy: 0.8363 - 35s/epoch - 79ms/step
# Epoch 77/100
# 443/443 - 35s - loss: 0.1776 - accuracy: 0.8614 - val_loss: 0.1884 - val_accuracy: 0.8419 - 35s/epoch - 79ms/step
# Epoch 78/100
# 443/443 - 35s - loss: 0.1774 - accuracy: 0.8607 - val_loss: 0.1895 - val_accuracy: 0.8194 - 35s/epoch - 79ms/step
# Epoch 79/100
# 443/443 - 35s - loss: 0.1770 - accuracy: 0.8655 - val_loss: 0.1882 - val_accuracy: 0.8236 - 35s/epoch - 80ms/step
# Epoch 80/100
# 443/443 - 35s - loss: 0.1773 - accuracy: 0.8643 - val_loss: 0.1885 - val_accuracy: 0.8267 - 35s/epoch - 80ms/step
# Epoch 81/100
# 443/443 - 35s - loss: 0.1765 - accuracy: 0.8648 - val_loss: 0.1870 - val_accuracy: 0.8295 - 35s/epoch - 79ms/step
# Epoch 82/100
# 443/443 - 35s - loss: 0.1765 - accuracy: 0.8665 - val_loss: 0.1885 - val_accuracy: 0.8247 - 35s/epoch - 79ms/step
# Epoch 83/100
# 443/443 - 35s - loss: 0.1764 - accuracy: 0.8646 - val_loss: 0.1866 - val_accuracy: 0.8366 - 35s/epoch - 79ms/step
# Epoch 84/100
# 443/443 - 36s - loss: 0.1758 - accuracy: 0.8663 - val_loss: 0.1865 - val_accuracy: 0.8304 - 36s/epoch - 81ms/step
# Epoch 85/100
# 443/443 - 35s - loss: 0.1758 - accuracy: 0.8671 - val_loss: 0.1856 - val_accuracy: 0.8405 - 35s/epoch - 79ms/step
# Epoch 86/100
# 443/443 - 35s - loss: 0.1753 - accuracy: 0.8707 - val_loss: 0.1872 - val_accuracy: 0.8340 - 35s/epoch - 80ms/step
# Epoch 87/100
# 443/443 - 35s - loss: 0.1753 - accuracy: 0.8686 - val_loss: 0.1859 - val_accuracy: 0.8405 - 35s/epoch - 79ms/step
# Epoch 88/100
# 443/443 - 35s - loss: 0.1747 - accuracy: 0.8697 - val_loss: 0.1855 - val_accuracy: 0.8377 - 35s/epoch - 80ms/step
# Epoch 89/100
# 443/443 - 35s - loss: 0.1747 - accuracy: 0.8728 - val_loss: 0.1862 - val_accuracy: 0.8312 - 35s/epoch - 79ms/step
# Epoch 90/100
# 443/443 - 35s - loss: 0.1745 - accuracy: 0.8703 - val_loss: 0.1859 - val_accuracy: 0.8349 - 35s/epoch - 79ms/step
# Epoch 91/100
# 443/443 - 35s - loss: 0.1743 - accuracy: 0.8704 - val_loss: 0.1889 - val_accuracy: 0.8160 - 35s/epoch - 79ms/step
# Epoch 92/100
# 443/443 - 35s - loss: 0.1740 - accuracy: 0.8719 - val_loss: 0.1859 - val_accuracy: 0.8419 - 35s/epoch - 80ms/step
# Epoch 93/100
# 443/443 - 35s - loss: 0.1741 - accuracy: 0.8723 - val_loss: 0.1862 - val_accuracy: 0.8447 - 35s/epoch - 79ms/step
# Epoch 94/100
# 443/443 - 35s - loss: 0.1738 - accuracy: 0.8723 - val_loss: 0.1869 - val_accuracy: 0.8383 - 35s/epoch - 79ms/step
# Epoch 95/100
# 443/443 - 37s - loss: 0.1739 - accuracy: 0.8723 - val_loss: 0.1867 - val_accuracy: 0.8411 - 37s/epoch - 82ms/step
# Epoch 96/100
# 443/443 - 35s - loss: 0.1738 - accuracy: 0.8724 - val_loss: 0.1869 - val_accuracy: 0.8397 - 35s/epoch - 79ms/step
# Epoch 97/100
# 443/443 - 38s - loss: 0.1727 - accuracy: 0.8747 - val_loss: 0.1869 - val_accuracy: 0.8377 - 38s/epoch - 86ms/step
# Epoch 98/100
# 443/443 - 37s - loss: 0.1728 - accuracy: 0.8751 - val_loss: 0.1847 - val_accuracy: 0.8428 - 37s/epoch - 84ms/step
# Epoch 99/100
# 443/443 - 35s - loss: 0.1728 - accuracy: 0.8751 - val_loss: 0.1855 - val_accuracy: 0.8416 - 35s/epoch - 80ms/step
# Epoch 100/100
# 443/443 - 36s - loss: 0.1726 - accuracy: 0.8773 - val_loss: 0.1866 - val_accuracy: 0.8315 - 36s/epoch - 82ms/step
# 56/56 [==============================] - 1s 21ms/step - loss: 0.1876 - accuracy: 0.8264
# Модель и весы сохранены.

# %%
'''def test():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagood = data_good(x_train)
    show_images(datagood, x_train, y_train)
    datagen = data_augmentation(x_train)
    show_augmented_images(datagen, x_train, y_train)

    epochs = 2
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))'''
# Out:
# 'def test():\n    fer_classes = [\'neutral\', \'happiness\', \'surprise\', \'sadness\', \'anger\', \'disgust\', \'fear\', \'contempt\']\n\n    X, y = preprocess_data()\n    X, y = clean_data_and_normalize(X, y)\n    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)\n    datagood = data_good(x_train)\n    show_images(datagood, x_train, y_train)\n    datagen = data_augmentation(x_train)\n    show_augmented_images(datagen, x_train, y_train)\n\n    epochs = 2\n    batch_size = 64\n\n    print("X_train shape: " + str(x_train.shape))\n    print("Y_train shape: " + str(y_train.shape))\n    print("X_test shape: " + str(x_test.shape))\n    print("Y_test shape: " + str(y_test.shape))\n    print("X_val shape: " + str(x_val.shape))\n    print("Y_val shape: " + str(y_val.shape))'

# %%
#test()
