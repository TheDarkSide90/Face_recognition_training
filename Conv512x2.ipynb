# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pydot
import visualkeras
from keras.optimizers import Adam
from keras.models import Sequential, model_from_json
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import model_selection
from math import ceil
from PIL import ImageFont
from collections import defaultdict

import os
os.chdir('F:\Другое\PythonFiles\Facial-emotion-recognition-master')

print(os.getcwd())

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# f:\Другое\PythonFiles\Facial-emotion-recognition-master
# 1 Physical GPUs, 1 Logical GPUs

# %%
def preprocess_data():
    data = pd.read_csv('fer2013.csv')
    labels = pd.read_csv('fer2013new.csv')

    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    n_samples = len(data)
    w = 48
    h = 48

    y = np.array(labels[orig_class_names])
    X = np.zeros((n_samples, w, h, 1))
    for i in range(n_samples):
        X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((h, w, 1))

    return X, y

# %%
def clean_data_and_normalize(X, y):
    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

  
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('unknown')
    X = X[mask]
    y = y[mask]

 
    y = y[:, :-2] * 0.1

   
    y[:, 0] += y[:, 7]
    y = y[:, :7]

  
    X = X / 255.0

    return X, y

# %%
def split_data(X, y):
    test_size = ceil(len(X) * 0.1)

    
    x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x_train, y_train, test_size=test_size,
                                                                      random_state=42)
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def data_good(x_train):
    datagood = ImageDataGenerator()
    datagood.fit(x_train)
    return datagood

# %%
def data_augmentation(x_train):
    shift = 0.1
    datagen = ImageDataGenerator(
        rotation_range=20,
        horizontal_flip=True,
        height_shift_range=shift,
        width_shift_range=shift)
    datagen.fit(x_train)
    return datagen

# %%
def show_images(datagood, x_train, y_train):
    it = datagood.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def show_augmented_images(datagen, x_train, y_train):
    it = datagen.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def define_model(input_shape=(48, 48, 1), classes=7):
   

    model = tf.keras.models.Sequential()

   
    model.add(Conv2D(32, kernel_size=(1, 1), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, kernel_size=(5, 5)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(64, kernel_size=(5, 5)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.5))

  
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

   
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

   
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

    model.add(Conv2D(512, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(512, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))


    model.add(Flatten())

  
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.2))
    
    model.add(Dense(classes, activation='softmax'))

    return model

# %%
def plot_acc_loss(history):
   
    plt.plot(history.history['accuracy'], label='Тренировочный набор')
    plt.plot(history.history['val_accuracy'], label='Валидационный набор')
    plt.xlabel('Количество эпох')
    plt.ylabel('Точность')
    plt.ylim([0, 1.0])
    plt.legend(loc='upper left')
    plt.show()

  
    plt.plot(history.history['loss'], label='Отклонение тр. набора')
    plt.plot(history.history['val_loss'], label='Отклонение влд. набора')
    plt.xlabel('Количество эпох')
    plt.ylabel('Отклонение')
    # plt.ylim([0, 3.5])
    plt.legend(loc='upper right')
    plt.show()

# %%
def save_model_and_weights(model, test_acc):
   
    test_acc = int(test_acc * 10000)
    model_json = model.to_json()
    with open('models\\model' + str(test_acc) + '.json', 'w') as json_file:
        json_file.write(model_json)
    
    model.save_weights('models\\model' + str(test_acc) + '.h5')
    color_map = defaultdict(dict)
    color_map[Flatten]['fill'] = 'black'
    color_map[Dense]['fill'] = 'green'
    font = ImageFont.truetype("arial.ttf", 28)
    visualkeras.layered_view(model, legend=True, font=font, to_file='output.png')
    print('Модель и весы сохранены.')

# %%
def load_model_and_weights(model_path, weights_path):
    
    json_file = open(model_path, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)

  
    model.load_weights(weights_path)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    print('Модель и весы загружены.')

# %%
def run_model():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagen = data_augmentation(x_train)

    epochs = 100
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))


   
    model = define_model(input_shape=x_train[0].shape, classes=len(fer_classes))
    model.summary()

    tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

   
    visualkeras.layered_view(model, legend=True)
    visualkeras.layered_view(model, legend=True, to_file='output.png')

    model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
                        steps_per_epoch=len(x_train) // batch_size,
                        validation_data=(x_val, y_val), verbose=2)
    test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=batch_size)

    plot_acc_loss(history)
    save_model_and_weights(model, test_acc)

# %%
run_model()
# Out:
# X_train shape: (28390, 48, 48, 1)
# Y_train shape: (28390, 7)
# X_test shape: (3549, 48, 48, 1)
# Y_test shape: (3549, 7)
# X_val shape: (3549, 48, 48, 1)
# Y_val shape: (3549, 7)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        64
#
#  batch_normalization (BatchN  (None, 48, 48, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_1 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 48, 48, 32)        0
#
#  dropout (Dropout)           (None, 48, 48, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 44, 44, 64)        51264
#
#  batch_normalization_2 (Batc  (None, 44, 44, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 44, 44, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 40, 40, 64)        102464
#
#  batch_normalization_3 (Batc  (None, 40, 40, 64)       256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 40, 40, 64)        0
#
#  dropout_1 (Dropout)         (None, 40, 40, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 38, 38, 64)        36928
#
#  conv2d_5 (Conv2D)           (None, 36, 36, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 18, 18, 64)       0
#  )
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 128)       73856
#
#  batch_normalization_4 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_4 (Activation)   (None, 16, 16, 128)       0
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 128)       147584
#
#  batch_normalization_5 (Batc  (None, 14, 14, 128)      512
#  hNormalization)
#
#  activation_5 (Activation)   (None, 14, 14, 128)       0
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 128)       147584
#
#  conv2d_9 (Conv2D)           (None, 10, 10, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 3, 3, 256)         295168
#
#  batch_normalization_6 (Batc  (None, 3, 3, 256)        1024
#  hNormalization)
#
#  activation_6 (Activation)   (None, 3, 3, 256)         0
#
#  conv2d_11 (Conv2D)          (None, 1, 1, 256)         590080
#
#  batch_normalization_7 (Batc  (None, 1, 1, 256)        1024
#  hNormalization)
#
#  activation_7 (Activation)   (None, 1, 1, 256)         0
#
#  dropout_2 (Dropout)         (None, 1, 1, 256)         0
#
#  conv2d_12 (Conv2D)          (None, 1, 1, 512)         1180160
#
#  batch_normalization_8 (Batc  (None, 1, 1, 512)        2048
#  hNormalization)
#
#  activation_8 (Activation)   (None, 1, 1, 512)         0
#
#  conv2d_13 (Conv2D)          (None, 1, 1, 512)         2359808
#
#  batch_normalization_9 (Batc  (None, 1, 1, 512)        2048
#  hNormalization)
#
#  activation_9 (Activation)   (None, 1, 1, 512)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 1024)              525312
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 5,710,951
# Trainable params: 5,706,983
# Non-trainable params: 3,968
# _________________________________________________________________
# Epoch 1/100
# C:\Users\nikit\AppData\Roaming\Python\Python310\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 443/443 - 39s - loss: 0.3564 - accuracy: 0.3606 - val_loss: 0.3522 - val_accuracy: 0.3533 - 39s/epoch - 89ms/step
# Epoch 2/100
# 443/443 - 29s - loss: 0.3428 - accuracy: 0.4049 - val_loss: 0.3283 - val_accuracy: 0.4660 - 29s/epoch - 66ms/step
# Epoch 3/100
# 443/443 - 30s - loss: 0.3288 - accuracy: 0.4640 - val_loss: 0.3314 - val_accuracy: 0.4711 - 30s/epoch - 69ms/step
# Epoch 4/100
# 443/443 - 29s - loss: 0.3125 - accuracy: 0.5244 - val_loss: 0.3489 - val_accuracy: 0.4570 - 29s/epoch - 66ms/step
# Epoch 5/100
# 443/443 - 28s - loss: 0.3009 - accuracy: 0.5575 - val_loss: 0.3006 - val_accuracy: 0.5616 - 28s/epoch - 64ms/step
# Epoch 6/100
# 443/443 - 32s - loss: 0.2925 - accuracy: 0.5753 - val_loss: 0.2859 - val_accuracy: 0.5993 - 32s/epoch - 71ms/step
# Epoch 7/100
# 443/443 - 31s - loss: 0.2820 - accuracy: 0.5974 - val_loss: 0.2916 - val_accuracy: 0.5830 - 31s/epoch - 70ms/step
# Epoch 8/100
# 443/443 - 30s - loss: 0.2732 - accuracy: 0.6222 - val_loss: 0.2760 - val_accuracy: 0.6334 - 30s/epoch - 68ms/step
# Epoch 9/100
# 443/443 - 31s - loss: 0.2650 - accuracy: 0.6394 - val_loss: 0.2624 - val_accuracy: 0.6816 - 31s/epoch - 69ms/step
# Epoch 10/100
# 443/443 - 30s - loss: 0.2596 - accuracy: 0.6516 - val_loss: 0.2543 - val_accuracy: 0.6703 - 30s/epoch - 67ms/step
# Epoch 11/100
# 443/443 - 29s - loss: 0.2542 - accuracy: 0.6657 - val_loss: 0.2397 - val_accuracy: 0.7084 - 29s/epoch - 66ms/step
# Epoch 12/100
# 443/443 - 31s - loss: 0.2503 - accuracy: 0.6741 - val_loss: 0.2332 - val_accuracy: 0.7196 - 31s/epoch - 69ms/step
# Epoch 13/100
# 443/443 - 29s - loss: 0.2463 - accuracy: 0.6864 - val_loss: 0.2344 - val_accuracy: 0.6923 - 29s/epoch - 66ms/step
# Epoch 14/100
# 443/443 - 30s - loss: 0.2418 - accuracy: 0.6902 - val_loss: 0.2281 - val_accuracy: 0.7295 - 30s/epoch - 69ms/step
# Epoch 15/100
# 443/443 - 31s - loss: 0.2401 - accuracy: 0.6980 - val_loss: 0.2220 - val_accuracy: 0.7520 - 31s/epoch - 70ms/step
# Epoch 16/100
# 443/443 - 29s - loss: 0.2358 - accuracy: 0.7070 - val_loss: 0.2217 - val_accuracy: 0.7413 - 29s/epoch - 66ms/step
# Epoch 17/100
# 443/443 - 30s - loss: 0.2339 - accuracy: 0.7134 - val_loss: 0.2192 - val_accuracy: 0.7442 - 30s/epoch - 68ms/step
# Epoch 18/100
# 443/443 - 30s - loss: 0.2309 - accuracy: 0.7246 - val_loss: 0.2254 - val_accuracy: 0.7351 - 30s/epoch - 67ms/step
# Epoch 19/100
# 443/443 - 33s - loss: 0.2293 - accuracy: 0.7237 - val_loss: 0.2213 - val_accuracy: 0.7301 - 33s/epoch - 73ms/step
# Epoch 20/100
# 443/443 - 32s - loss: 0.2273 - accuracy: 0.7313 - val_loss: 0.2149 - val_accuracy: 0.7664 - 32s/epoch - 71ms/step
# Epoch 21/100
# 443/443 - 30s - loss: 0.2244 - accuracy: 0.7354 - val_loss: 0.2218 - val_accuracy: 0.7515 - 30s/epoch - 68ms/step
# Epoch 22/100
# 443/443 - 29s - loss: 0.2239 - accuracy: 0.7382 - val_loss: 0.2110 - val_accuracy: 0.7630 - 29s/epoch - 65ms/step
# Epoch 23/100
# 443/443 - 30s - loss: 0.2219 - accuracy: 0.7416 - val_loss: 0.2131 - val_accuracy: 0.7599 - 30s/epoch - 68ms/step
# Epoch 24/100
# 443/443 - 29s - loss: 0.2205 - accuracy: 0.7476 - val_loss: 0.2090 - val_accuracy: 0.7636 - 29s/epoch - 65ms/step
# Epoch 25/100
# 443/443 - 31s - loss: 0.2183 - accuracy: 0.7509 - val_loss: 0.2119 - val_accuracy: 0.7715 - 31s/epoch - 69ms/step
# Epoch 26/100
# 443/443 - 29s - loss: 0.2180 - accuracy: 0.7520 - val_loss: 0.2106 - val_accuracy: 0.7726 - 29s/epoch - 66ms/step
# Epoch 27/100
# 443/443 - 29s - loss: 0.2164 - accuracy: 0.7543 - val_loss: 0.2086 - val_accuracy: 0.7740 - 29s/epoch - 65ms/step
# Epoch 28/100
# 443/443 - 29s - loss: 0.2157 - accuracy: 0.7602 - val_loss: 0.2076 - val_accuracy: 0.7788 - 29s/epoch - 65ms/step
# Epoch 29/100
# 443/443 - 31s - loss: 0.2144 - accuracy: 0.7617 - val_loss: 0.2049 - val_accuracy: 0.7898 - 31s/epoch - 70ms/step
# Epoch 30/100
# 443/443 - 32s - loss: 0.2135 - accuracy: 0.7656 - val_loss: 0.2060 - val_accuracy: 0.7937 - 32s/epoch - 73ms/step
# Epoch 31/100
# 443/443 - 31s - loss: 0.2134 - accuracy: 0.7640 - val_loss: 0.2038 - val_accuracy: 0.7890 - 31s/epoch - 69ms/step
# Epoch 32/100
# 443/443 - 31s - loss: 0.2115 - accuracy: 0.7695 - val_loss: 0.2090 - val_accuracy: 0.7836 - 31s/epoch - 70ms/step
# Epoch 33/100
# 443/443 - 30s - loss: 0.2103 - accuracy: 0.7708 - val_loss: 0.2047 - val_accuracy: 0.7949 - 30s/epoch - 67ms/step
# Epoch 34/100
# 443/443 - 29s - loss: 0.2099 - accuracy: 0.7734 - val_loss: 0.2134 - val_accuracy: 0.7450 - 29s/epoch - 66ms/step
# Epoch 35/100
# 443/443 - 29s - loss: 0.2092 - accuracy: 0.7740 - val_loss: 0.2067 - val_accuracy: 0.7816 - 29s/epoch - 66ms/step
# Epoch 36/100
# 443/443 - 29s - loss: 0.2082 - accuracy: 0.7783 - val_loss: 0.2021 - val_accuracy: 0.7997 - 29s/epoch - 66ms/step
# Epoch 37/100
# 443/443 - 33s - loss: 0.2072 - accuracy: 0.7775 - val_loss: 0.2068 - val_accuracy: 0.7898 - 33s/epoch - 75ms/step
# Epoch 38/100
# 443/443 - 31s - loss: 0.2069 - accuracy: 0.7800 - val_loss: 0.2001 - val_accuracy: 0.7940 - 31s/epoch - 70ms/step
# Epoch 39/100
# 443/443 - 30s - loss: 0.2060 - accuracy: 0.7839 - val_loss: 0.1998 - val_accuracy: 0.7983 - 30s/epoch - 67ms/step
# Epoch 40/100
# 443/443 - 30s - loss: 0.2066 - accuracy: 0.7836 - val_loss: 0.1976 - val_accuracy: 0.8101 - 30s/epoch - 69ms/step
# Epoch 41/100
# 443/443 - 30s - loss: 0.2052 - accuracy: 0.7844 - val_loss: 0.2072 - val_accuracy: 0.7729 - 30s/epoch - 67ms/step
# Epoch 42/100
# 443/443 - 31s - loss: 0.2038 - accuracy: 0.7880 - val_loss: 0.1998 - val_accuracy: 0.8073 - 31s/epoch - 69ms/step
# Epoch 43/100
# 443/443 - 31s - loss: 0.2027 - accuracy: 0.7925 - val_loss: 0.2032 - val_accuracy: 0.7968 - 31s/epoch - 70ms/step
# Epoch 44/100
# 443/443 - 30s - loss: 0.2033 - accuracy: 0.7899 - val_loss: 0.1982 - val_accuracy: 0.8092 - 30s/epoch - 68ms/step
# Epoch 45/100
# 443/443 - 30s - loss: 0.2022 - accuracy: 0.7913 - val_loss: 0.2017 - val_accuracy: 0.8101 - 30s/epoch - 68ms/step
# Epoch 46/100
# 443/443 - 29s - loss: 0.2025 - accuracy: 0.7907 - val_loss: 0.1971 - val_accuracy: 0.7929 - 29s/epoch - 66ms/step
# Epoch 47/100
# 443/443 - 30s - loss: 0.2016 - accuracy: 0.7935 - val_loss: 0.1983 - val_accuracy: 0.8067 - 30s/epoch - 69ms/step
# Epoch 48/100
# 443/443 - 31s - loss: 0.2014 - accuracy: 0.7920 - val_loss: 0.1977 - val_accuracy: 0.8104 - 31s/epoch - 69ms/step
# Epoch 49/100
# 443/443 - 32s - loss: 0.2007 - accuracy: 0.7968 - val_loss: 0.1953 - val_accuracy: 0.8129 - 32s/epoch - 71ms/step
# Epoch 50/100
# 443/443 - 30s - loss: 0.1996 - accuracy: 0.7977 - val_loss: 0.1994 - val_accuracy: 0.8005 - 30s/epoch - 68ms/step
# Epoch 51/100
# Epoch 90/100
# 443/443 - 29s - loss: 0.1870 - accuracy: 0.8326 - val_loss: 0.1925 - val_accuracy: 0.8174 - 29s/epoch - 66ms/step
# Epoch 91/100
# 443/443 - 29s - loss: 0.1874 - accuracy: 0.8311 - val_loss: 0.1918 - val_accuracy: 0.8219 - 29s/epoch - 66ms/step
# Epoch 92/100
# 443/443 - 29s - loss: 0.1876 - accuracy: 0.8285 - val_loss: 0.1909 - val_accuracy: 0.8236 - 29s/epoch - 66ms/step
# Epoch 93/100
# 443/443 - 29s - loss: 0.1867 - accuracy: 0.8314 - val_loss: 0.1944 - val_accuracy: 0.8143 - 29s/epoch - 66ms/step
# Epoch 94/100
# 443/443 - 29s - loss: 0.1868 - accuracy: 0.8366 - val_loss: 0.1904 - val_accuracy: 0.8270 - 29s/epoch - 66ms/step
# Epoch 95/100
# 443/443 - 29s - loss: 0.1867 - accuracy: 0.8329 - val_loss: 0.1914 - val_accuracy: 0.8154 - 29s/epoch - 66ms/step
# Epoch 96/100
# 443/443 - 29s - loss: 0.1870 - accuracy: 0.8347 - val_loss: 0.1918 - val_accuracy: 0.8197 - 29s/epoch - 66ms/step
# Epoch 97/100
# 443/443 - 29s - loss: 0.1863 - accuracy: 0.8372 - val_loss: 0.1911 - val_accuracy: 0.8197 - 29s/epoch - 66ms/step
# Epoch 98/100
# 443/443 - 29s - loss: 0.1865 - accuracy: 0.8345 - val_loss: 0.1914 - val_accuracy: 0.8261 - 29s/epoch - 66ms/step
# Epoch 99/100
# 443/443 - 29s - loss: 0.1859 - accuracy: 0.8358 - val_loss: 0.1933 - val_accuracy: 0.8188 - 29s/epoch - 66ms/step
# Epoch 100/100
# 443/443 - 29s - loss: 0.1855 - accuracy: 0.8352 - val_loss: 0.1914 - val_accuracy: 0.8166 - 29s/epoch - 66ms/step
# 56/56 [==============================] - 1s 22ms/step - loss: 0.1914 - accuracy: 0.8016
# Модель и весы сохранены.

# %%
'''def test():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagood = data_good(x_train)
    show_images(datagood, x_train, y_train)
    datagen = data_augmentation(x_train)
    show_augmented_images(datagen, x_train, y_train)

    epochs = 2
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))'''
# Out:
# 'def test():\n    fer_classes = [\'neutral\', \'happiness\', \'surprise\', \'sadness\', \'anger\', \'disgust\', \'fear\', \'contempt\']\n\n    X, y = preprocess_data()\n    X, y = clean_data_and_normalize(X, y)\n    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)\n    datagood = data_good(x_train)\n    show_images(datagood, x_train, y_train)\n    datagen = data_augmentation(x_train)\n    show_augmented_images(datagen, x_train, y_train)\n\n    epochs = 2\n    batch_size = 64\n\n    print("X_train shape: " + str(x_train.shape))\n    print("Y_train shape: " + str(y_train.shape))\n    print("X_test shape: " + str(x_test.shape))\n    print("Y_test shape: " + str(y_test.shape))\n    print("X_val shape: " + str(x_val.shape))\n    print("Y_val shape: " + str(y_val.shape))'

# %%
#test()
