# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pydot
import visualkeras
from keras.optimizers import Adam
from keras.models import Sequential, model_from_json
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import model_selection
from math import ceil
from PIL import ImageFont
from collections import defaultdict

import os
os.chdir('F:\Другое\PythonFiles\Facial-emotion-recognition-master')

print(os.getcwd())

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# f:\Другое\PythonFiles\Facial-emotion-recognition-master
# 1 Physical GPUs, 1 Logical GPUs

# %%
def preprocess_data():
    data = pd.read_csv('fer2013.csv')
    labels = pd.read_csv('fer2013new.csv')

    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    n_samples = len(data)
    w = 48
    h = 48

    y = np.array(labels[orig_class_names])
    X = np.zeros((n_samples, w, h, 1))
    for i in range(n_samples):
        X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((h, w, 1))

    return X, y

# %%
def clean_data_and_normalize(X, y):
    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('unknown')
    X = X[mask]
    y = y[mask]

    
    y = y[:, :-2] * 0.1

    
    y[:, 0] += y[:, 7]
    y = y[:, :7]

    
    X = X / 255.0

    return X, y

# %%
def split_data(X, y):
    test_size = ceil(len(X) * 0.1)

    
    x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x_train, y_train, test_size=test_size,
                                                                      random_state=42)
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def data_good(x_train):
    datagood = ImageDataGenerator()
    datagood.fit(x_train)
    return datagood

# %%
def data_augmentation(x_train):
    shift = 0.1
    datagen = ImageDataGenerator(
        rotation_range=20,
        horizontal_flip=True,
        height_shift_range=shift,
        width_shift_range=shift)
    datagen.fit(x_train)
    return datagen

# %%
def show_images(datagood, x_train, y_train):
    it = datagood.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def show_augmented_images(datagen, x_train, y_train):
    it = datagen.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def define_model(input_shape=(48, 48, 1), classes=7):
    

    model = tf.keras.models.Sequential()

    
    model.add(Conv2D(64, kernel_size=(3, 3), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(64, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.5))

    
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

    
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

    model.add(Flatten())

    
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.2))
    

    model.add(Dense(classes, activation='softmax'))

    return model

# %%
def plot_acc_loss(history):
    
    plt.plot(history.history['accuracy'], label='Тренировочный набор')
    plt.plot(history.history['val_accuracy'], label='Валидационный набор')
    plt.xlabel('Количество эпох')
    plt.ylabel('Точность')
    plt.ylim([0, 1.0])
    plt.legend(loc='upper left')
    plt.show()

    
    plt.plot(history.history['loss'], label='Отклонение тр. набора')
    plt.plot(history.history['val_loss'], label='Отклонение влд. набора')
    plt.xlabel('Количество эпох')
    plt.ylabel('Отклонение')
    # plt.ylim([0, 3.5])
    plt.legend(loc='upper right')
    plt.show()

# %%
def save_model_and_weights(model, test_acc):
    
    test_acc = int(test_acc * 10000)
    model_json = model.to_json()
    with open('models\\model' + str(test_acc) + '.json', 'w') as json_file:
        json_file.write(model_json)
    
    model.save_weights('models\\model' + str(test_acc) + '.h5')
    color_map = defaultdict(dict)
    color_map[Flatten]['fill'] = 'black'
    color_map[Dense]['fill'] = 'green'
    font = ImageFont.truetype("arial.ttf", 28)
    visualkeras.layered_view(model, legend=True, font=font, to_file='output.png')
    print('Модель и весы сохранены.')

# %%
def load_model_and_weights(model_path, weights_path):
    
    json_file = open(model_path, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)

    
    model.load_weights(weights_path)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    print('Модель и весы загружены.')

# %%
def run_model():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagen = data_augmentation(x_train)

    epochs = 100
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))


    
    model = define_model(input_shape=x_train[0].shape, classes=len(fer_classes))
    model.summary()

    tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

   
    visualkeras.layered_view(model, legend=True)
    visualkeras.layered_view(model, legend=True, to_file='output.png')

    model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
                        steps_per_epoch=len(x_train) // batch_size,
                        validation_data=(x_val, y_val), verbose=2)
    test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=batch_size)

    plot_acc_loss(history)
    save_model_and_weights(model, test_acc)

# %%
run_model()
# Out:
# X_train shape: (28390, 48, 48, 1)
# Y_train shape: (28390, 7)
# X_test shape: (3549, 48, 48, 1)
# Y_test shape: (3549, 7)
# X_val shape: (3549, 48, 48, 1)
# Y_val shape: (3549, 7)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  batch_normalization (BatchN  (None, 46, 46, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 46, 46, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 44, 44, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 44, 44, 64)        0
#
#  dropout (Dropout)           (None, 44, 44, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 42, 42, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 40, 40, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 20, 20, 64)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 18, 18, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 18, 18, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 18, 18, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 128)       147584
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 4, 4, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 1024)              1049600
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 2,573,639
# Trainable params: 2,571,847
# Non-trainable params: 1,792
# _________________________________________________________________
# C:\Users\nikit\AppData\Roaming\Python\Python310\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# 443/443 - 33s - loss: 0.3514 - accuracy: 0.4036 - val_loss: 0.3606 - val_accuracy: 0.3815 - 33s/epoch - 75ms/step
# Epoch 2/100
# 443/443 - 19s - loss: 0.3123 - accuracy: 0.5262 - val_loss: 0.2921 - val_accuracy: 0.5920 - 19s/epoch - 43ms/step
# Epoch 3/100
# 443/443 - 19s - loss: 0.2852 - accuracy: 0.5949 - val_loss: 0.2628 - val_accuracy: 0.6481 - 19s/epoch - 43ms/step
# Epoch 4/100
# 443/443 - 19s - loss: 0.2678 - accuracy: 0.6296 - val_loss: 0.2488 - val_accuracy: 0.6917 - 19s/epoch - 43ms/step
# Epoch 5/100
# 443/443 - 19s - loss: 0.2563 - accuracy: 0.6586 - val_loss: 0.2539 - val_accuracy: 0.6782 - 19s/epoch - 44ms/step
# Epoch 6/100
# 443/443 - 19s - loss: 0.2471 - accuracy: 0.6800 - val_loss: 0.2385 - val_accuracy: 0.6968 - 19s/epoch - 44ms/step
# Epoch 7/100
# 443/443 - 20s - loss: 0.2409 - accuracy: 0.6977 - val_loss: 0.2466 - val_accuracy: 0.7132 - 20s/epoch - 44ms/step
# Epoch 8/100
# 443/443 - 20s - loss: 0.2352 - accuracy: 0.7099 - val_loss: 0.2395 - val_accuracy: 0.7261 - 20s/epoch - 45ms/step
# Epoch 9/100
# 443/443 - 21s - loss: 0.2312 - accuracy: 0.7172 - val_loss: 0.2266 - val_accuracy: 0.7351 - 21s/epoch - 48ms/step
# Epoch 10/100
# 443/443 - 20s - loss: 0.2268 - accuracy: 0.7294 - val_loss: 0.2210 - val_accuracy: 0.7526 - 20s/epoch - 45ms/step
# Epoch 11/100
# 443/443 - 19s - loss: 0.2234 - accuracy: 0.7390 - val_loss: 0.2194 - val_accuracy: 0.7520 - 19s/epoch - 43ms/step
# Epoch 12/100
# 443/443 - 20s - loss: 0.2197 - accuracy: 0.7467 - val_loss: 0.2234 - val_accuracy: 0.7509 - 20s/epoch - 45ms/step
# Epoch 13/100
# 443/443 - 19s - loss: 0.2180 - accuracy: 0.7516 - val_loss: 0.2116 - val_accuracy: 0.7771 - 19s/epoch - 43ms/step
# Epoch 14/100
# 443/443 - 18s - loss: 0.2158 - accuracy: 0.7549 - val_loss: 0.2356 - val_accuracy: 0.7351 - 18s/epoch - 42ms/step
# Epoch 15/100
# 443/443 - 18s - loss: 0.2135 - accuracy: 0.7630 - val_loss: 0.2052 - val_accuracy: 0.7957 - 18s/epoch - 42ms/step
# Epoch 16/100
# 443/443 - 18s - loss: 0.2117 - accuracy: 0.7676 - val_loss: 0.2084 - val_accuracy: 0.7842 - 18s/epoch - 42ms/step
# Epoch 35/100
# 443/443 - 19s - loss: 0.1919 - accuracy: 0.8183 - val_loss: 0.1992 - val_accuracy: 0.7926 - 19s/epoch - 42ms/step
# Epoch 36/100
# 443/443 - 20s - loss: 0.1913 - accuracy: 0.8214 - val_loss: 0.1952 - val_accuracy: 0.8092 - 20s/epoch - 45ms/step
# Epoch 37/100
# 443/443 - 19s - loss: 0.1906 - accuracy: 0.8237 - val_loss: 0.1992 - val_accuracy: 0.7971 - 19s/epoch - 42ms/step
# Epoch 38/100
# 443/443 - 18s - loss: 0.1900 - accuracy: 0.8249 - val_loss: 0.1924 - val_accuracy: 0.8202 - 18s/epoch - 41ms/step
# Epoch 39/100
# 443/443 - 18s - loss: 0.1898 - accuracy: 0.8232 - val_loss: 0.1945 - val_accuracy: 0.8121 - 18s/epoch - 40ms/step
# Epoch 40/100
# 443/443 - 19s - loss: 0.1891 - accuracy: 0.8260 - val_loss: 0.1970 - val_accuracy: 0.7999 - 19s/epoch - 42ms/step
# Epoch 41/100
# 443/443 - 18s - loss: 0.1887 - accuracy: 0.8276 - val_loss: 0.1918 - val_accuracy: 0.8295 - 18s/epoch - 42ms/step
# Epoch 42/100
# 443/443 - 18s - loss: 0.1884 - accuracy: 0.8305 - val_loss: 0.1941 - val_accuracy: 0.8061 - 18s/epoch - 42ms/step
# Epoch 43/100
# 443/443 - 18s - loss: 0.1876 - accuracy: 0.8298 - val_loss: 0.1926 - val_accuracy: 0.8239 - 18s/epoch - 40ms/step
# Epoch 44/100
# 443/443 - 18s - loss: 0.1874 - accuracy: 0.8331 - val_loss: 0.1908 - val_accuracy: 0.8177 - 18s/epoch - 41ms/step
# Epoch 45/100
# 443/443 - 18s - loss: 0.1863 - accuracy: 0.8338 - val_loss: 0.1919 - val_accuracy: 0.8135 - 18s/epoch - 42ms/step
# Epoch 46/100
# 443/443 - 18s - loss: 0.1859 - accuracy: 0.8371 - val_loss: 0.1922 - val_accuracy: 0.8194 - 18s/epoch - 41ms/step
# Epoch 47/100
# 443/443 - 21s - loss: 0.1863 - accuracy: 0.8363 - val_loss: 0.1913 - val_accuracy: 0.8264 - 21s/epoch - 46ms/step
# Epoch 48/100
# 443/443 - 19s - loss: 0.1855 - accuracy: 0.8389 - val_loss: 0.1900 - val_accuracy: 0.8287 - 19s/epoch - 44ms/step
# Epoch 49/100
# 443/443 - 19s - loss: 0.1852 - accuracy: 0.8380 - val_loss: 0.1953 - val_accuracy: 0.8090 - 19s/epoch - 44ms/step
# Epoch 50/100
# 443/443 - 20s - loss: 0.1846 - accuracy: 0.8386 - val_loss: 0.1911 - val_accuracy: 0.8064 - 20s/epoch - 44ms/step
# Epoch 51/100
# 443/443 - 20s - loss: 0.1844 - accuracy: 0.8425 - val_loss: 0.1897 - val_accuracy: 0.8357 - 20s/epoch - 45ms/step
# Epoch 52/100
# 443/443 - 20s - loss: 0.1838 - accuracy: 0.8422 - val_loss: 0.1906 - val_accuracy: 0.8278 - 20s/epoch - 46ms/step
# Epoch 71/100
# 443/443 - 22s - loss: 0.1785 - accuracy: 0.8556 - val_loss: 0.1916 - val_accuracy: 0.8211 - 22s/epoch - 49ms/step
# Epoch 72/100
# 443/443 - 21s - loss: 0.1781 - accuracy: 0.8591 - val_loss: 0.1874 - val_accuracy: 0.8295 - 21s/epoch - 48ms/step
# Epoch 73/100
# 443/443 - 19s - loss: 0.1780 - accuracy: 0.8579 - val_loss: 0.1896 - val_accuracy: 0.8267 - 19s/epoch - 44ms/step
# Epoch 74/100
# 443/443 - 19s - loss: 0.1774 - accuracy: 0.8616 - val_loss: 0.1916 - val_accuracy: 0.8168 - 19s/epoch - 43ms/step
# Epoch 75/100
# 443/443 - 19s - loss: 0.1778 - accuracy: 0.8572 - val_loss: 0.1942 - val_accuracy: 0.8107 - 19s/epoch - 43ms/step
# Epoch 76/100
# 443/443 - 20s - loss: 0.1776 - accuracy: 0.8609 - val_loss: 0.1918 - val_accuracy: 0.8273 - 20s/epoch - 45ms/step
# Epoch 77/100
# 443/443 - 20s - loss: 0.1771 - accuracy: 0.8605 - val_loss: 0.1874 - val_accuracy: 0.8363 - 20s/epoch - 45ms/step
# Epoch 78/100
# 443/443 - 18s - loss: 0.1762 - accuracy: 0.8654 - val_loss: 0.1909 - val_accuracy: 0.8307 - 18s/epoch - 42ms/step
# Epoch 79/100
# 443/443 - 19s - loss: 0.1764 - accuracy: 0.8640 - val_loss: 0.1889 - val_accuracy: 0.8298 - 19s/epoch - 43ms/step
# Epoch 80/100
# 443/443 - 19s - loss: 0.1763 - accuracy: 0.8648 - val_loss: 0.1898 - val_accuracy: 0.8343 - 19s/epoch - 42ms/step
# Epoch 81/100
# 443/443 - 19s - loss: 0.1762 - accuracy: 0.8648 - val_loss: 0.1907 - val_accuracy: 0.8183 - 19s/epoch - 42ms/step
# Epoch 82/100
# 443/443 - 19s - loss: 0.1755 - accuracy: 0.8660 - val_loss: 0.1887 - val_accuracy: 0.8360 - 19s/epoch - 42ms/step
# Epoch 83/100
# 443/443 - 20s - loss: 0.1755 - accuracy: 0.8661 - val_loss: 0.1895 - val_accuracy: 0.8374 - 20s/epoch - 45ms/step
# Epoch 84/100
# 443/443 - 18s - loss: 0.1755 - accuracy: 0.8669 - val_loss: 0.1882 - val_accuracy: 0.8295 - 18s/epoch - 41ms/step
# Epoch 85/100
# 443/443 - 18s - loss: 0.1752 - accuracy: 0.8675 - val_loss: 0.1885 - val_accuracy: 0.8374 - 18s/epoch - 42ms/step
# Epoch 86/100
# 443/443 - 18s - loss: 0.1754 - accuracy: 0.8657 - val_loss: 0.1891 - val_accuracy: 0.8261 - 18s/epoch - 41ms/step
# Epoch 87/100
# 443/443 - 18s - loss: 0.1754 - accuracy: 0.8678 - val_loss: 0.1892 - val_accuracy: 0.8245 - 18s/epoch - 41ms/step
# Epoch 88/100
# 443/443 - 18s - loss: 0.1752 - accuracy: 0.8679 - val_loss: 0.1868 - val_accuracy: 0.8329 - 18s/epoch - 41ms/step
# Epoch 89/100
# 443/443 - 18s - loss: 0.1748 - accuracy: 0.8693 - val_loss: 0.1879 - val_accuracy: 0.8416 - 18s/epoch - 41ms/step
# Epoch 90/100
# 443/443 - 19s - loss: 0.1746 - accuracy: 0.8694 - val_loss: 0.1869 - val_accuracy: 0.8340 - 19s/epoch - 42ms/step
# Epoch 91/100
# 443/443 - 19s - loss: 0.1739 - accuracy: 0.8700 - val_loss: 0.1889 - val_accuracy: 0.8326 - 19s/epoch - 42ms/step
# Epoch 92/100
# 443/443 - 19s - loss: 0.1742 - accuracy: 0.8703 - val_loss: 0.1869 - val_accuracy: 0.8397 - 19s/epoch - 43ms/step
# Epoch 93/100
# 443/443 - 19s - loss: 0.1740 - accuracy: 0.8728 - val_loss: 0.1875 - val_accuracy: 0.8374 - 19s/epoch - 44ms/step
# Epoch 94/100
# 443/443 - 18s - loss: 0.1735 - accuracy: 0.8738 - val_loss: 0.1873 - val_accuracy: 0.8400 - 18s/epoch - 41ms/step
# Epoch 95/100
# 443/443 - 19s - loss: 0.1735 - accuracy: 0.8702 - val_loss: 0.1905 - val_accuracy: 0.8259 - 19s/epoch - 42ms/step
# Epoch 96/100
# 443/443 - 18s - loss: 0.1731 - accuracy: 0.8730 - val_loss: 0.1875 - val_accuracy: 0.8391 - 18s/epoch - 40ms/step
# Epoch 97/100
# 443/443 - 19s - loss: 0.1728 - accuracy: 0.8743 - val_loss: 0.1903 - val_accuracy: 0.8433 - 19s/epoch - 42ms/step
# Epoch 98/100
# 443/443 - 18s - loss: 0.1727 - accuracy: 0.8748 - val_loss: 0.1880 - val_accuracy: 0.8332 - 18s/epoch - 41ms/step
# Epoch 99/100
# 443/443 - 18s - loss: 0.1729 - accuracy: 0.8728 - val_loss: 0.1896 - val_accuracy: 0.8250 - 18s/epoch - 42ms/step
# Epoch 100/100
# 443/443 - 18s - loss: 0.1727 - accuracy: 0.8741 - val_loss: 0.1904 - val_accuracy: 0.8366 - 18s/epoch - 42ms/step
# 56/56 [==============================] - 1s 11ms/step - loss: 0.1878 - accuracy: 0.8292
# Модель и весы сохранены.

# %%
'''def test():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagood = data_good(x_train)
    show_images(datagood, x_train, y_train)
    datagen = data_augmentation(x_train)
    show_augmented_images(datagen, x_train, y_train)

    epochs = 2
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))'''
# Out:
# 'def test():\n    fer_classes = [\'neutral\', \'happiness\', \'surprise\', \'sadness\', \'anger\', \'disgust\', \'fear\', \'contempt\']\n\n    X, y = preprocess_data()\n    X, y = clean_data_and_normalize(X, y)\n    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)\n    datagood = data_good(x_train)\n    show_images(datagood, x_train, y_train)\n    datagen = data_augmentation(x_train)\n    show_augmented_images(datagen, x_train, y_train)\n\n    epochs = 2\n    batch_size = 64\n\n    print("X_train shape: " + str(x_train.shape))\n    print("Y_train shape: " + str(y_train.shape))\n    print("X_test shape: " + str(x_test.shape))\n    print("Y_test shape: " + str(y_test.shape))\n    print("X_val shape: " + str(x_val.shape))\n    print("Y_val shape: " + str(y_val.shape))'

# %%
#test()
