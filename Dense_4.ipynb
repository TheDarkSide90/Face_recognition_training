# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pydot
import visualkeras
from keras.optimizers import Adam
from keras.models import Sequential, model_from_json
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import model_selection
from math import ceil
from PIL import ImageFont
from collections import defaultdict

import os
os.chdir('F:\Другое\PythonFiles\Facial-emotion-recognition-master')

print(os.getcwd())

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# f:\Другое\PythonFiles\Facial-emotion-recognition-master
# 1 Physical GPUs, 1 Logical GPUs

# %%
def preprocess_data():
    data = pd.read_csv('fer2013.csv')
    labels = pd.read_csv('fer2013new.csv')

    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    n_samples = len(data)
    w = 48
    h = 48

    y = np.array(labels[orig_class_names])
    X = np.zeros((n_samples, w, h, 1))
    for i in range(n_samples):
        X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((h, w, 1))

    return X, y

# %%
def clean_data_and_normalize(X, y):
    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

   
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('unknown')
    X = X[mask]
    y = y[mask]

  
    y = y[:, :-2] * 0.1

  
    y[:, 0] += y[:, 7]
    y = y[:, :7]

   
    X = X / 255.0

    return X, y

# %%
def split_data(X, y):
    test_size = ceil(len(X) * 0.1)

  
    x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x_train, y_train, test_size=test_size,
                                                                      random_state=42)
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def data_good(x_train):
    datagood = ImageDataGenerator()
    datagood.fit(x_train)
    return datagood

# %%
def data_augmentation(x_train):
    shift = 0.1
    datagen = ImageDataGenerator(
        rotation_range=20,
        horizontal_flip=True,
        height_shift_range=shift,
        width_shift_range=shift)
    datagen.fit(x_train)
    return datagen

# %%
def show_images(datagood, x_train, y_train):
    it = datagood.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def show_augmented_images(datagen, x_train, y_train):
    it = datagen.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def define_model(input_shape=(48, 48, 1), classes=7):
 
    model = tf.keras.models.Sequential()

   
    model.add(Conv2D(32, kernel_size=(1, 1), input_shape=input_shape, padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(32, kernel_size=(1, 1), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

   
    model.add(Conv2D(64, (5, 5), strides=(1, 1), activation='relu', padding='same'))
    model.add(Conv2D(64, (2, 2), strides=(2, 2), activation='relu'))
    

  
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

  
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

   
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))

    model.add(Conv2D(512, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(512, kernel_size=(3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.2))


    model.add(Flatten())

  
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1024, activation='relu'))
    model.add(Dropout(0.2))
    
    model.add(Dense(classes, activation='softmax'))

    return model

# %%
def plot_acc_loss(history):
   
    plt.plot(history.history['accuracy'], label='Тренировочный набор')
    plt.plot(history.history['val_accuracy'], label='Валидационный набор')
    plt.xlabel('Количество эпох')
    plt.ylabel('Точность')
    plt.ylim([0, 1.0])
    plt.legend(loc='upper left')
    plt.show()

  
    plt.plot(history.history['loss'], label='Отклонение тр. набора')
    plt.plot(history.history['val_loss'], label='Отклонение влд. набора')
    plt.xlabel('Количество эпох')
    plt.ylabel('Отклонение')
    # plt.ylim([0, 3.5])
    plt.legend(loc='upper right')
    plt.show()

# %%
def save_model_and_weights(model, test_acc):
  
    test_acc = int(test_acc * 10000)
    model_json = model.to_json()
    with open('models\\model' + str(test_acc) + '.json', 'w') as json_file:
        json_file.write(model_json)
 
    model.save_weights('models\\model' + str(test_acc) + '.h5')
    color_map = defaultdict(dict)
    color_map[Flatten]['fill'] = 'black'
    color_map[Dense]['fill'] = 'green'
    font = ImageFont.truetype("arial.ttf", 28)
    visualkeras.layered_view(model, legend=True, font=font, to_file='output.png')
    print('Модель и весы сохранены.')

# %%
def load_model_and_weights(model_path, weights_path):
   
    json_file = open(model_path, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)

   
    model.load_weights(weights_path)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    print('Модель и весы загружены.')

# %%
def run_model():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagen = data_augmentation(x_train)

    epochs = 100
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))


  
    model = define_model(input_shape=x_train[0].shape, classes=len(fer_classes))
    model.summary()

    tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

   
    visualkeras.layered_view(model, legend=True)
    visualkeras.layered_view(model, legend=True, to_file='output.png')

    model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
                        steps_per_epoch=len(x_train) // batch_size,
                        validation_data=(x_val, y_val), verbose=2)
    test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=batch_size)

    plot_acc_loss(history)
    save_model_and_weights(model, test_acc)

# %%
run_model()
# Out:
# X_train shape: (28390, 48, 48, 1)
# Y_train shape: (28390, 7)
# X_test shape: (3549, 48, 48, 1)
# Y_test shape: (3549, 7)
# X_val shape: (3549, 48, 48, 1)
# Y_val shape: (3549, 7)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        64
#
#  batch_normalization (BatchN  (None, 48, 48, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_1 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 48, 48, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_2 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 32)        1056
#
#  batch_normalization_3 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  activation_3 (Activation)   (None, 48, 48, 32)        0
#
#  dropout (Dropout)           (None, 48, 48, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  activation_4 (Activation)   (None, 48, 48, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 48, 48, 64)        36928
#
#  batch_normalization_5 (Batc  (None, 48, 48, 64)       256
#  hNormalization)
#
#  activation_5 (Activation)   (None, 48, 48, 64)        0
#
#  dropout_1 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_6 (Conv2D)           (None, 48, 48, 64)        102464
#
#  conv2d_7 (Conv2D)           (None, 24, 24, 64)        16448
#
#  conv2d_8 (Conv2D)           (None, 22, 22, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 22, 22, 128)      512
#  hNormalization)
#
#  activation_6 (Activation)   (None, 22, 22, 128)       0
#
#  conv2d_9 (Conv2D)           (None, 20, 20, 128)       147584
#
#  batch_normalization_7 (Batc  (None, 20, 20, 128)      512
#  hNormalization)
#
#  activation_7 (Activation)   (None, 20, 20, 128)       0
#
#  dropout_2 (Dropout)         (None, 20, 20, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 18, 18, 128)       147584
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)       147584
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 128)        0
#  )
#
#  conv2d_12 (Conv2D)          (None, 6, 6, 256)         295168
#
#  batch_normalization_8 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  activation_8 (Activation)   (None, 6, 6, 256)         0
#
#  conv2d_13 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_9 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_9 (Activation)   (None, 4, 4, 256)         0
#
#  dropout_3 (Dropout)         (None, 4, 4, 256)         0
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 512)         1180160
#
#  batch_normalization_10 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_10 (Activation)  (None, 4, 4, 512)         0
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  batch_normalization_11 (Bat  (None, 4, 4, 512)        2048
#  chNormalization)
#
#  activation_11 (Activation)  (None, 4, 4, 512)         0
#
#  dropout_4 (Dropout)         (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 1024)              8389632
#
#  dropout_5 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dropout_6 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 14,573,991
# Trainable params: 14,569,895
# Non-trainable params: 4,096
# _________________________________________________________________
# Epoch 1/100
# C:\Users\nikit\AppData\Roaming\Python\Python310\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 443/443 - 44s - loss: 0.3607 - accuracy: 0.3478 - val_loss: 0.3582 - val_accuracy: 0.3894 - 44s/epoch - 99ms/step
# Epoch 2/100
# 443/443 - 34s - loss: 0.3442 - accuracy: 0.4045 - val_loss: 0.3449 - val_accuracy: 0.4210 - 34s/epoch - 76ms/step
# Epoch 3/100
# 443/443 - 34s - loss: 0.3227 - accuracy: 0.5006 - val_loss: 0.3136 - val_accuracy: 0.5475 - 34s/epoch - 76ms/step
# Epoch 4/100
# 443/443 - 34s - loss: 0.3037 - accuracy: 0.5551 - val_loss: 0.2879 - val_accuracy: 0.6190 - 34s/epoch - 76ms/step
# Epoch 5/100
# 443/443 - 34s - loss: 0.2880 - accuracy: 0.5901 - val_loss: 0.2626 - val_accuracy: 0.6585 - 34s/epoch - 76ms/step
# Epoch 6/100
# 443/443 - 34s - loss: 0.2731 - accuracy: 0.6227 - val_loss: 0.2684 - val_accuracy: 0.6441 - 34s/epoch - 76ms/step
# Epoch 7/100
# 443/443 - 34s - loss: 0.2624 - accuracy: 0.6472 - val_loss: 0.2541 - val_accuracy: 0.6681 - 34s/epoch - 76ms/step
# Epoch 8/100
# 443/443 - 34s - loss: 0.2537 - accuracy: 0.6685 - val_loss: 0.2395 - val_accuracy: 0.7070 - 34s/epoch - 76ms/step
# Epoch 9/100
# 443/443 - 34s - loss: 0.2470 - accuracy: 0.6824 - val_loss: 0.2337 - val_accuracy: 0.7087 - 34s/epoch - 76ms/step
# Epoch 10/100
# 443/443 - 34s - loss: 0.2415 - accuracy: 0.6978 - val_loss: 0.2377 - val_accuracy: 0.7208 - 34s/epoch - 76ms/step
# Epoch 11/100
# 443/443 - 34s - loss: 0.2365 - accuracy: 0.7091 - val_loss: 0.2484 - val_accuracy: 0.7182 - 34s/epoch - 76ms/step
# Epoch 12/100
# 443/443 - 34s - loss: 0.2338 - accuracy: 0.7197 - val_loss: 0.2203 - val_accuracy: 0.7456 - 34s/epoch - 76ms/step
# Epoch 13/100
# 443/443 - 34s - loss: 0.2295 - accuracy: 0.7252 - val_loss: 0.2180 - val_accuracy: 0.7529 - 34s/epoch - 76ms/step
# Epoch 14/100
# 443/443 - 34s - loss: 0.2264 - accuracy: 0.7324 - val_loss: 0.2145 - val_accuracy: 0.7650 - 34s/epoch - 76ms/step
# Epoch 15/100
# 443/443 - 34s - loss: 0.2234 - accuracy: 0.7427 - val_loss: 0.2186 - val_accuracy: 0.7453 - 34s/epoch - 76ms/step
# Epoch 16/100
# 443/443 - 34s - loss: 0.2209 - accuracy: 0.7501 - val_loss: 0.2108 - val_accuracy: 0.7720 - 34s/epoch - 76ms/step
# Epoch 17/100
# 443/443 - 34s - loss: 0.2185 - accuracy: 0.7525 - val_loss: 0.2120 - val_accuracy: 0.7723 - 34s/epoch - 76ms/step
# Epoch 18/100
# 443/443 - 34s - loss: 0.2161 - accuracy: 0.7599 - val_loss: 0.2077 - val_accuracy: 0.7847 - 34s/epoch - 76ms/step
# Epoch 19/100
# 443/443 - 34s - loss: 0.2143 - accuracy: 0.7638 - val_loss: 0.2047 - val_accuracy: 0.7918 - 34s/epoch - 77ms/step
# Epoch 20/100
# 443/443 - 34s - loss: 0.2123 - accuracy: 0.7698 - val_loss: 0.2066 - val_accuracy: 0.7844 - 34s/epoch - 77ms/step
# Epoch 21/100
# 443/443 - 34s - loss: 0.2107 - accuracy: 0.7752 - val_loss: 0.2074 - val_accuracy: 0.7808 - 34s/epoch - 77ms/step
# Epoch 22/100
# 443/443 - 34s - loss: 0.2092 - accuracy: 0.7791 - val_loss: 0.2029 - val_accuracy: 0.7839 - 34s/epoch - 77ms/step
# Epoch 23/100
# 443/443 - 34s - loss: 0.2077 - accuracy: 0.7775 - val_loss: 0.2228 - val_accuracy: 0.7599 - 34s/epoch - 77ms/step
# Epoch 24/100
# 443/443 - 34s - loss: 0.2068 - accuracy: 0.7813 - val_loss: 0.2030 - val_accuracy: 0.8036 - 34s/epoch - 77ms/step
# Epoch 25/100
# 443/443 - 34s - loss: 0.2056 - accuracy: 0.7834 - val_loss: 0.2037 - val_accuracy: 0.7988 - 34s/epoch - 77ms/step
# Epoch 26/100
# 443/443 - 34s - loss: 0.2042 - accuracy: 0.7921 - val_loss: 0.2073 - val_accuracy: 0.7718 - 34s/epoch - 77ms/step
# Epoch 27/100
# 443/443 - 34s - loss: 0.2026 - accuracy: 0.7898 - val_loss: 0.2015 - val_accuracy: 0.7963 - 34s/epoch - 77ms/step
# Epoch 28/100
# 443/443 - 34s - loss: 0.2017 - accuracy: 0.7957 - val_loss: 0.1999 - val_accuracy: 0.8014 - 34s/epoch - 77ms/step
# Epoch 29/100
# 443/443 - 34s - loss: 0.2011 - accuracy: 0.7990 - val_loss: 0.2100 - val_accuracy: 0.7599 - 34s/epoch - 77ms/step
# Epoch 30/100
# 443/443 - 34s - loss: 0.2002 - accuracy: 0.8011 - val_loss: 0.1980 - val_accuracy: 0.8076 - 34s/epoch - 77ms/step
# Epoch 31/100
# 443/443 - 34s - loss: 0.1993 - accuracy: 0.8010 - val_loss: 0.2010 - val_accuracy: 0.7977 - 34s/epoch - 77ms/step
# Epoch 32/100
# 443/443 - 34s - loss: 0.1982 - accuracy: 0.8045 - val_loss: 0.2026 - val_accuracy: 0.7895 - 34s/epoch - 77ms/step
# Epoch 33/100
# 443/443 - 34s - loss: 0.1973 - accuracy: 0.8061 - val_loss: 0.1970 - val_accuracy: 0.8095 - 34s/epoch - 77ms/step
# Epoch 34/100
# 443/443 - 34s - loss: 0.1963 - accuracy: 0.8121 - val_loss: 0.1999 - val_accuracy: 0.8014 - 34s/epoch - 77ms/step
# Epoch 35/100
# 443/443 - 34s - loss: 0.1959 - accuracy: 0.8113 - val_loss: 0.1995 - val_accuracy: 0.8061 - 34s/epoch - 77ms/step
# Epoch 36/100
# 443/443 - 34s - loss: 0.1949 - accuracy: 0.8134 - val_loss: 0.2033 - val_accuracy: 0.8002 - 34s/epoch - 77ms/step
# Epoch 37/100
# 443/443 - 34s - loss: 0.1944 - accuracy: 0.8114 - val_loss: 0.2036 - val_accuracy: 0.7853 - 34s/epoch - 77ms/step
# Epoch 38/100
# 443/443 - 34s - loss: 0.1936 - accuracy: 0.8184 - val_loss: 0.1965 - val_accuracy: 0.8109 - 34s/epoch - 77ms/step
# Epoch 39/100
# 443/443 - 34s - loss: 0.1932 - accuracy: 0.8197 - val_loss: 0.1975 - val_accuracy: 0.8028 - 34s/epoch - 77ms/step
# Epoch 40/100
# 443/443 - 34s - loss: 0.1920 - accuracy: 0.8185 - val_loss: 0.1961 - val_accuracy: 0.8084 - 34s/epoch - 77ms/step
# Epoch 41/100
# 443/443 - 34s - loss: 0.1921 - accuracy: 0.8211 - val_loss: 0.1976 - val_accuracy: 0.7988 - 34s/epoch - 77ms/step
# Epoch 42/100
# 443/443 - 34s - loss: 0.1916 - accuracy: 0.8212 - val_loss: 0.1923 - val_accuracy: 0.8233 - 34s/epoch - 77ms/step
# Epoch 43/100
# 443/443 - 34s - loss: 0.1907 - accuracy: 0.8243 - val_loss: 0.1954 - val_accuracy: 0.8081 - 34s/epoch - 77ms/step
# Epoch 44/100
# 443/443 - 34s - loss: 0.1903 - accuracy: 0.8264 - val_loss: 0.1965 - val_accuracy: 0.8016 - 34s/epoch - 77ms/step
# Epoch 45/100
# 443/443 - 34s - loss: 0.1901 - accuracy: 0.8263 - val_loss: 0.2008 - val_accuracy: 0.7839 - 34s/epoch - 77ms/step
# Epoch 46/100
# 443/443 - 34s - loss: 0.1886 - accuracy: 0.8291 - val_loss: 0.1935 - val_accuracy: 0.8214 - 34s/epoch - 77ms/step
# Epoch 47/100
# 443/443 - 34s - loss: 0.1888 - accuracy: 0.8300 - val_loss: 0.1934 - val_accuracy: 0.8059 - 34s/epoch - 77ms/step
# Epoch 48/100
# 443/443 - 34s - loss: 0.1879 - accuracy: 0.8350 - val_loss: 0.1931 - val_accuracy: 0.8160 - 34s/epoch - 77ms/step
# Epoch 49/100
# 443/443 - 34s - loss: 0.1876 - accuracy: 0.8332 - val_loss: 0.1919 - val_accuracy: 0.8202 - 34s/epoch - 77ms/step
# Epoch 50/100
# 443/443 - 34s - loss: 0.1875 - accuracy: 0.8313 - val_loss: 0.1906 - val_accuracy: 0.8247 - 34s/epoch - 77ms/step
# Epoch 51/100
# 443/443 - 34s - loss: 0.1873 - accuracy: 0.8336 - val_loss: 0.1921 - val_accuracy: 0.8183 - 34s/epoch - 77ms/step
# Epoch 52/100
# 443/443 - 34s - loss: 0.1863 - accuracy: 0.8372 - val_loss: 0.1929 - val_accuracy: 0.8253 - 34s/epoch - 77ms/step
# Epoch 53/100
# 443/443 - 34s - loss: 0.1861 - accuracy: 0.8343 - val_loss: 0.1951 - val_accuracy: 0.8092 - 34s/epoch - 77ms/step
# Epoch 54/100
# 443/443 - 34s - loss: 0.1855 - accuracy: 0.8374 - val_loss: 0.1925 - val_accuracy: 0.8228 - 34s/epoch - 77ms/step
# Epoch 55/100
# 443/443 - 34s - loss: 0.1853 - accuracy: 0.8389 - val_loss: 0.1954 - val_accuracy: 0.8036 - 34s/epoch - 77ms/step
# Epoch 56/100
# 443/443 - 34s - loss: 0.1851 - accuracy: 0.8387 - val_loss: 0.1905 - val_accuracy: 0.8214 - 34s/epoch - 77ms/step
# Epoch 57/100
# 443/443 - 34s - loss: 0.1844 - accuracy: 0.8422 - val_loss: 0.1906 - val_accuracy: 0.8202 - 34s/epoch - 77ms/step
# Epoch 58/100
# 443/443 - 34s - loss: 0.1846 - accuracy: 0.8433 - val_loss: 0.1905 - val_accuracy: 0.8219 - 34s/epoch - 77ms/step
# Epoch 59/100
# 443/443 - 34s - loss: 0.1841 - accuracy: 0.8422 - val_loss: 0.1910 - val_accuracy: 0.8154 - 34s/epoch - 77ms/step
# Epoch 60/100
# 443/443 - 34s - loss: 0.1836 - accuracy: 0.8403 - val_loss: 0.1884 - val_accuracy: 0.8298 - 34s/epoch - 77ms/step
# Epoch 61/100
# 443/443 - 34s - loss: 0.1831 - accuracy: 0.8439 - val_loss: 0.1895 - val_accuracy: 0.8290 - 34s/epoch - 77ms/step
# Epoch 62/100
# 443/443 - 34s - loss: 0.1820 - accuracy: 0.8471 - val_loss: 0.1896 - val_accuracy: 0.8197 - 34s/epoch - 77ms/step
# Epoch 63/100
# 443/443 - 34s - loss: 0.1824 - accuracy: 0.8492 - val_loss: 0.1904 - val_accuracy: 0.8214 - 34s/epoch - 77ms/step
# Epoch 64/100
# 443/443 - 34s - loss: 0.1817 - accuracy: 0.8502 - val_loss: 0.1885 - val_accuracy: 0.8278 - 34s/epoch - 77ms/step
# Epoch 65/100
# 443/443 - 34s - loss: 0.1816 - accuracy: 0.8478 - val_loss: 0.1882 - val_accuracy: 0.8264 - 34s/epoch - 77ms/step
# Epoch 66/100
# 443/443 - 34s - loss: 0.1810 - accuracy: 0.8496 - val_loss: 0.1894 - val_accuracy: 0.8264 - 34s/epoch - 77ms/step
# Epoch 67/100
# 443/443 - 34s - loss: 0.1811 - accuracy: 0.8513 - val_loss: 0.1927 - val_accuracy: 0.8154 - 34s/epoch - 77ms/step
# Epoch 68/100
# 443/443 - 34s - loss: 0.1805 - accuracy: 0.8521 - val_loss: 0.1913 - val_accuracy: 0.8247 - 34s/epoch - 77ms/step
# Epoch 69/100
# 443/443 - 34s - loss: 0.1806 - accuracy: 0.8530 - val_loss: 0.1888 - val_accuracy: 0.8326 - 34s/epoch - 77ms/step
# Epoch 70/100
# 443/443 - 34s - loss: 0.1800 - accuracy: 0.8551 - val_loss: 0.1931 - val_accuracy: 0.8109 - 34s/epoch - 77ms/step
# Epoch 71/100
# 443/443 - 34s - loss: 0.1803 - accuracy: 0.8543 - val_loss: 0.1911 - val_accuracy: 0.8208 - 34s/epoch - 77ms/step
# Epoch 72/100
# 443/443 - 34s - loss: 0.1791 - accuracy: 0.8548 - val_loss: 0.1882 - val_accuracy: 0.8284 - 34s/epoch - 77ms/step
# Epoch 73/100
# 443/443 - 34s - loss: 0.1788 - accuracy: 0.8568 - val_loss: 0.1883 - val_accuracy: 0.8329 - 34s/epoch - 77ms/step
# Epoch 74/100
# 443/443 - 34s - loss: 0.1789 - accuracy: 0.8562 - val_loss: 0.1900 - val_accuracy: 0.8256 - 34s/epoch - 77ms/step
# Epoch 75/100
# 443/443 - 34s - loss: 0.1783 - accuracy: 0.8577 - val_loss: 0.1885 - val_accuracy: 0.8242 - 34s/epoch - 77ms/step
# Epoch 76/100
# 443/443 - 34s - loss: 0.1782 - accuracy: 0.8596 - val_loss: 0.1872 - val_accuracy: 0.8369 - 34s/epoch - 77ms/step
# Epoch 77/100
# 443/443 - 34s - loss: 0.1781 - accuracy: 0.8595 - val_loss: 0.1903 - val_accuracy: 0.8270 - 34s/epoch - 77ms/step
# Epoch 78/100
# 443/443 - 34s - loss: 0.1783 - accuracy: 0.8610 - val_loss: 0.1920 - val_accuracy: 0.8267 - 34s/epoch - 77ms/step
# Epoch 79/100
# 443/443 - 34s - loss: 0.1774 - accuracy: 0.8612 - val_loss: 0.1909 - val_accuracy: 0.8208 - 34s/epoch - 77ms/step
# Epoch 80/100
# 443/443 - 34s - loss: 0.1772 - accuracy: 0.8632 - val_loss: 0.1887 - val_accuracy: 0.8264 - 34s/epoch - 77ms/step
# Epoch 81/100
# 443/443 - 34s - loss: 0.1774 - accuracy: 0.8600 - val_loss: 0.1910 - val_accuracy: 0.8208 - 34s/epoch - 77ms/step
# Epoch 82/100
# 443/443 - 34s - loss: 0.1769 - accuracy: 0.8636 - val_loss: 0.1887 - val_accuracy: 0.8250 - 34s/epoch - 77ms/step
# Epoch 83/100
# 443/443 - 34s - loss: 0.1766 - accuracy: 0.8640 - val_loss: 0.1874 - val_accuracy: 0.8276 - 34s/epoch - 77ms/step
# Epoch 84/100
# 443/443 - 34s - loss: 0.1760 - accuracy: 0.8664 - val_loss: 0.1882 - val_accuracy: 0.8250 - 34s/epoch - 77ms/step
# Epoch 85/100
# 443/443 - 34s - loss: 0.1762 - accuracy: 0.8646 - val_loss: 0.1893 - val_accuracy: 0.8261 - 34s/epoch - 77ms/step
# Epoch 86/100
# 443/443 - 34s - loss: 0.1760 - accuracy: 0.8630 - val_loss: 0.1874 - val_accuracy: 0.8315 - 34s/epoch - 77ms/step
# Epoch 87/100
# 443/443 - 34s - loss: 0.1754 - accuracy: 0.8664 - val_loss: 0.1876 - val_accuracy: 0.8290 - 34s/epoch - 77ms/step
# Epoch 88/100
# 443/443 - 34s - loss: 0.1757 - accuracy: 0.8662 - val_loss: 0.1877 - val_accuracy: 0.8307 - 34s/epoch - 77ms/step
# Epoch 89/100
# 443/443 - 34s - loss: 0.1752 - accuracy: 0.8673 - val_loss: 0.1874 - val_accuracy: 0.8267 - 34s/epoch - 77ms/step
# Epoch 90/100
# 443/443 - 34s - loss: 0.1750 - accuracy: 0.8667 - val_loss: 0.1883 - val_accuracy: 0.8329 - 34s/epoch - 77ms/step
# Epoch 91/100
# 443/443 - 34s - loss: 0.1746 - accuracy: 0.8705 - val_loss: 0.1851 - val_accuracy: 0.8453 - 34s/epoch - 77ms/step
# Epoch 92/100
# 443/443 - 34s - loss: 0.1744 - accuracy: 0.8719 - val_loss: 0.1866 - val_accuracy: 0.8338 - 34s/epoch - 77ms/step
# Epoch 93/100
# 443/443 - 34s - loss: 0.1744 - accuracy: 0.8737 - val_loss: 0.1895 - val_accuracy: 0.8264 - 34s/epoch - 77ms/step
# Epoch 94/100
# 443/443 - 34s - loss: 0.1745 - accuracy: 0.8699 - val_loss: 0.1871 - val_accuracy: 0.8366 - 34s/epoch - 77ms/step
# Epoch 95/100
# 443/443 - 34s - loss: 0.1742 - accuracy: 0.8712 - val_loss: 0.1882 - val_accuracy: 0.8377 - 34s/epoch - 77ms/step
# Epoch 96/100
# 443/443 - 34s - loss: 0.1738 - accuracy: 0.8737 - val_loss: 0.1883 - val_accuracy: 0.8411 - 34s/epoch - 77ms/step
# Epoch 97/100
# 443/443 - 34s - loss: 0.1735 - accuracy: 0.8713 - val_loss: 0.1879 - val_accuracy: 0.8225 - 34s/epoch - 77ms/step
# Epoch 98/100
# 443/443 - 34s - loss: 0.1729 - accuracy: 0.8712 - val_loss: 0.1888 - val_accuracy: 0.8273 - 34s/epoch - 77ms/step
# Epoch 99/100
# 443/443 - 34s - loss: 0.1731 - accuracy: 0.8751 - val_loss: 0.1868 - val_accuracy: 0.8329 - 34s/epoch - 77ms/step
# Epoch 100/100
# 443/443 - 34s - loss: 0.1734 - accuracy: 0.8759 - val_loss: 0.1864 - val_accuracy: 0.8371 - 34s/epoch - 77ms/step
# 56/56 [==============================] - 1s 19ms/step - loss: 0.1860 - accuracy: 0.8369
# Модель и весы сохранены.

# %%
'''def test():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagood = data_good(x_train)
    show_images(datagood, x_train, y_train)
    datagen = data_augmentation(x_train)
    show_augmented_images(datagen, x_train, y_train)

    epochs = 2
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))'''
# Out:
# 'def test():\n    fer_classes = [\'neutral\', \'happiness\', \'surprise\', \'sadness\', \'anger\', \'disgust\', \'fear\', \'contempt\']\n\n    X, y = preprocess_data()\n    X, y = clean_data_and_normalize(X, y)\n    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)\n    datagood = data_good(x_train)\n    show_images(datagood, x_train, y_train)\n    datagen = data_augmentation(x_train)\n    show_augmented_images(datagen, x_train, y_train)\n\n    epochs = 2\n    batch_size = 64\n\n    print("X_train shape: " + str(x_train.shape))\n    print("Y_train shape: " + str(y_train.shape))\n    print("X_test shape: " + str(x_test.shape))\n    print("Y_test shape: " + str(y_test.shape))\n    print("X_val shape: " + str(x_val.shape))\n    print("Y_val shape: " + str(y_val.shape))'

# %%
#test()
