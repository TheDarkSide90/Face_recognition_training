# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import pydot
import visualkeras
from keras.optimizers import Adam
from keras.models import Sequential, model_from_json
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from keras.preprocessing.image import ImageDataGenerator
from sklearn import model_selection
from math import ceil
from PIL import ImageFont
from collections import defaultdict

import os
os.chdir('F:\Другое\PythonFiles\Facial-emotion-recognition-master')

print(os.getcwd())

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# f:\Другое\PythonFiles\Facial-emotion-recognition-master
# 1 Physical GPUs, 1 Logical GPUs

# %%
def preprocess_data():
    data = pd.read_csv('fer2013.csv')
    labels = pd.read_csv('fer2013new.csv')

    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

    n_samples = len(data)
    w = 48
    h = 48

    y = np.array(labels[orig_class_names])
    X = np.zeros((n_samples, w, h, 1))
    for i in range(n_samples):
        X[i] = np.fromstring(data['pixels'][i], dtype=int, sep=' ').reshape((h, w, 1))

    return X, y

# %%
def clean_data_and_normalize(X, y):
    orig_class_names = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt',
                        'unknown', 'NF']

   
    y_mask = y.argmax(axis=-1)
    mask = y_mask < orig_class_names.index('unknown')
    X = X[mask]
    y = y[mask]

  
    y = y[:, :-2] * 0.1

   
    y[:, 0] += y[:, 7]
    y = y[:, :7]

  
    X = X / 255.0

    return X, y

# %%
def split_data(X, y):
    test_size = ceil(len(X) * 0.1)

  
    x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=test_size, random_state=42)
    x_train, x_val, y_train, y_val = model_selection.train_test_split(x_train, y_train, test_size=test_size,
                                                                      random_state=42)
    return x_train, y_train, x_val, y_val, x_test, y_test

# %%
def data_good(x_train):
    datagood = ImageDataGenerator()
    datagood.fit(x_train)
    return datagood

# %%
def data_augmentation(x_train):
    shift = 0.1
    datagen = ImageDataGenerator(
        rotation_range=20,
        horizontal_flip=True,
        height_shift_range=shift,
        width_shift_range=shift)
    datagen.fit(x_train)
    return datagen

# %%
def show_images(datagood, x_train, y_train):
    it = datagood.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def show_augmented_images(datagen, x_train, y_train):
    it = datagen.flow(x_train, y_train, batch_size=1)
    plt.figure(figsize=(10, 7))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(it.next()[0][0], cmap='gray')
        #plt.xlabel(class_names[y_train[i]])
    plt.show()

# %%
def define_model(input_shape=(48, 48, 1), classes=7):
   

    model = tf.keras.models.Sequential()

 
    model.add(Conv2D(64, kernel_size=(3, 3), input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(64, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Dropout(0.5))

  
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

   
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(128, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

   
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

  
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))
    model.add(Conv2D(256, kernel_size=(3, 3)))
    model.add(BatchNormalization())
    model.add(Activation(activation='relu'))

    model.add(Flatten())

  
    model.add(Dense(1024, activation='relu'))
    
    model.add(Dense(classes, activation='softmax'))

    return model

# %%
def plot_acc_loss(history):
   
    plt.plot(history.history['accuracy'], label='Тренировочный набор')
    plt.plot(history.history['val_accuracy'], label='Валидационный набор')
    plt.xlabel('Количество эпох')
    plt.ylabel('Точность')
    plt.ylim([0, 1.0])
    plt.legend(loc='upper left')
    plt.show()

  
    plt.plot(history.history['loss'], label='Отклонение тр. набора')
    plt.plot(history.history['val_loss'], label='Отклонение влд. набора')
    plt.xlabel('Количество эпох')
    plt.ylabel('Отклонение')
    # plt.ylim([0, 3.5])
    plt.legend(loc='upper right')
    plt.show()

# %%
def save_model_and_weights(model, test_acc):
  
    test_acc = int(test_acc * 10000)
    model_json = model.to_json()
    with open('models\\model' + str(test_acc) + '.json', 'w') as json_file:
        json_file.write(model_json)
  
    model.save_weights('models\\model' + str(test_acc) + '.h5')
    color_map = defaultdict(dict)
    color_map[Flatten]['fill'] = 'black'
    color_map[Dense]['fill'] = 'green'
    font = ImageFont.truetype("arial.ttf", 28)
    visualkeras.layered_view(model, legend=True, font=font, to_file='output.png')
    print('Модель и весы сохранены.')

# %%
def load_model_and_weights(model_path, weights_path):
  
    json_file = open(model_path, 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    model = model_from_json(loaded_model_json)

  
    model.load_weights(weights_path)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    print('Модель и весы загружены.')

# %%
def run_model():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagen = data_augmentation(x_train)

    epochs = 100
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))


  
    model = define_model(input_shape=x_train[0].shape, classes=len(fer_classes))
    model.summary()

    tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)

   
    visualkeras.layered_view(model, legend=True)
    visualkeras.layered_view(model, legend=True, to_file='output.png')

    model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size), epochs=epochs,
                        steps_per_epoch=len(x_train) // batch_size,
                        validation_data=(x_val, y_val), verbose=2)
    test_loss, test_acc = model.evaluate(x_test, y_test, batch_size=batch_size)

    plot_acc_loss(history)
    save_model_and_weights(model, test_acc)

# %%
run_model()
# Out:
# X_train shape: (28390, 48, 48, 1)
# Y_train shape: (28390, 7)
# X_test shape: (3549, 48, 48, 1)
# Y_test shape: (3549, 7)
# X_val shape: (3549, 48, 48, 1)
# Y_val shape: (3549, 7)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  batch_normalization (BatchN  (None, 46, 46, 64)       256
#  ormalization)
#
#  activation (Activation)     (None, 46, 46, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        36928
#
#  batch_normalization_1 (Batc  (None, 44, 44, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 44, 44, 64)        0
#
#  dropout (Dropout)           (None, 44, 44, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 42, 42, 64)        36928
#
#  conv2d_3 (Conv2D)           (None, 40, 40, 64)        36928
#
#  max_pooling2d (MaxPooling2D  (None, 20, 20, 64)       0
#  )
#
#  conv2d_4 (Conv2D)           (None, 18, 18, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 18, 18, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 18, 18, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 128)       147584
#
#  batch_normalization_3 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 128)       0
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 128)       147584
#
#  conv2d_7 (Conv2D)           (None, 12, 12, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 4, 4, 256)         295168
#
#  batch_normalization_4 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 4, 4, 256)         0
#
#  conv2d_9 (Conv2D)           (None, 2, 2, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 2, 2, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 1024)              1049600
#
#  dense_1 (Dense)             (None, 7)                 7175
#
# =================================================================
# Total params: 2,573,639
# Trainable params: 2,571,847
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/100
# C:\Users\nikit\AppData\Roaming\Python\Python310\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 443/443 - 25s - loss: 0.3394 - accuracy: 0.4383 - val_loss: 0.3790 - val_accuracy: 0.3798 - 25s/epoch - 57ms/step
# Epoch 2/100
# 443/443 - 18s - loss: 0.3008 - accuracy: 0.5504 - val_loss: 0.2917 - val_accuracy: 0.5779 - 18s/epoch - 41ms/step
# Epoch 3/100
# 443/443 - 18s - loss: 0.2790 - accuracy: 0.6059 - val_loss: 0.2686 - val_accuracy: 0.6371 - 18s/epoch - 40ms/step
# Epoch 4/100
# 443/443 - 18s - loss: 0.2632 - accuracy: 0.6410 - val_loss: 0.2460 - val_accuracy: 0.6734 - 18s/epoch - 40ms/step
# Epoch 5/100
# 443/443 - 18s - loss: 0.2525 - accuracy: 0.6683 - val_loss: 0.2443 - val_accuracy: 0.6979 - 18s/epoch - 40ms/step
# Epoch 6/100
# 443/443 - 18s - loss: 0.2452 - accuracy: 0.6847 - val_loss: 0.2500 - val_accuracy: 0.7072 - 18s/epoch - 40ms/step
# Epoch 7/100
# 443/443 - 18s - loss: 0.2376 - accuracy: 0.7055 - val_loss: 0.2432 - val_accuracy: 0.7106 - 18s/epoch - 40ms/step
# Epoch 8/100
# 443/443 - 18s - loss: 0.2329 - accuracy: 0.7121 - val_loss: 0.2251 - val_accuracy: 0.7396 - 18s/epoch - 40ms/step
# Epoch 9/100
# 443/443 - 18s - loss: 0.2279 - accuracy: 0.7283 - val_loss: 0.2247 - val_accuracy: 0.7210 - 18s/epoch - 40ms/step
# Epoch 10/100
# 443/443 - 18s - loss: 0.2236 - accuracy: 0.7401 - val_loss: 0.2306 - val_accuracy: 0.7244 - 18s/epoch - 40ms/step
# Epoch 11/100
# 443/443 - 18s - loss: 0.2204 - accuracy: 0.7421 - val_loss: 0.2172 - val_accuracy: 0.7656 - 18s/epoch - 40ms/step
# Epoch 12/100
# 443/443 - 18s - loss: 0.2171 - accuracy: 0.7551 - val_loss: 0.2151 - val_accuracy: 0.7566 - 18s/epoch - 40ms/step
# Epoch 13/100
# 443/443 - 18s - loss: 0.2152 - accuracy: 0.7603 - val_loss: 0.2160 - val_accuracy: 0.7396 - 18s/epoch - 40ms/step
# Epoch 14/100
# 443/443 - 18s - loss: 0.2130 - accuracy: 0.7641 - val_loss: 0.2136 - val_accuracy: 0.7520 - 18s/epoch - 40ms/step
# Epoch 15/100
# 443/443 - 18s - loss: 0.2107 - accuracy: 0.7665 - val_loss: 0.2225 - val_accuracy: 0.7196 - 18s/epoch - 40ms/step
# Epoch 16/100
# 443/443 - 18s - loss: 0.2088 - accuracy: 0.7766 - val_loss: 0.2084 - val_accuracy: 0.7768 - 18s/epoch - 40ms/step
# Epoch 17/100
# 443/443 - 18s - loss: 0.2068 - accuracy: 0.7789 - val_loss: 0.2178 - val_accuracy: 0.7642 - 18s/epoch - 40ms/step
# Epoch 18/100
# 443/443 - 18s - loss: 0.2061 - accuracy: 0.7816 - val_loss: 0.2035 - val_accuracy: 0.7940 - 18s/epoch - 40ms/step
# Epoch 19/100
# 443/443 - 18s - loss: 0.2039 - accuracy: 0.7877 - val_loss: 0.2013 - val_accuracy: 0.7974 - 18s/epoch - 40ms/step
# Epoch 20/100
# 443/443 - 18s - loss: 0.2029 - accuracy: 0.7880 - val_loss: 0.1990 - val_accuracy: 0.7960 - 18s/epoch - 40ms/step
# Epoch 21/100
# 443/443 - 18s - loss: 0.2014 - accuracy: 0.7918 - val_loss: 0.2013 - val_accuracy: 0.8016 - 18s/epoch - 40ms/step
# Epoch 22/100
# 443/443 - 18s - loss: 0.2005 - accuracy: 0.7964 - val_loss: 0.1986 - val_accuracy: 0.8070 - 18s/epoch - 40ms/step
# Epoch 23/100
# 443/443 - 18s - loss: 0.1994 - accuracy: 0.7996 - val_loss: 0.2023 - val_accuracy: 0.7890 - 18s/epoch - 40ms/step
# Epoch 24/100
# 443/443 - 18s - loss: 0.1979 - accuracy: 0.7997 - val_loss: 0.2039 - val_accuracy: 0.7943 - 18s/epoch - 40ms/step
# Epoch 25/100
# 443/443 - 18s - loss: 0.1973 - accuracy: 0.8035 - val_loss: 0.1987 - val_accuracy: 0.8078 - 18s/epoch - 40ms/step
# Epoch 26/100
# 443/443 - 18s - loss: 0.1965 - accuracy: 0.8044 - val_loss: 0.2067 - val_accuracy: 0.7904 - 18s/epoch - 40ms/step
# Epoch 27/100
# 443/443 - 18s - loss: 0.1961 - accuracy: 0.8065 - val_loss: 0.1997 - val_accuracy: 0.8157 - 18s/epoch - 40ms/step
# Epoch 28/100
# 443/443 - 18s - loss: 0.1950 - accuracy: 0.8092 - val_loss: 0.1976 - val_accuracy: 0.8056 - 18s/epoch - 40ms/step
# Epoch 29/100
# 443/443 - 18s - loss: 0.1938 - accuracy: 0.8097 - val_loss: 0.1954 - val_accuracy: 0.8101 - 18s/epoch - 40ms/step
# Epoch 30/100
# 443/443 - 18s - loss: 0.1934 - accuracy: 0.8165 - val_loss: 0.1987 - val_accuracy: 0.8042 - 18s/epoch - 40ms/step
# Epoch 31/100
# 443/443 - 18s - loss: 0.1928 - accuracy: 0.8185 - val_loss: 0.1942 - val_accuracy: 0.8157 - 18s/epoch - 40ms/step
# Epoch 32/100
# 443/443 - 18s - loss: 0.1920 - accuracy: 0.8196 - val_loss: 0.1969 - val_accuracy: 0.8107 - 18s/epoch - 40ms/step
# Epoch 33/100
# 443/443 - 18s - loss: 0.1913 - accuracy: 0.8209 - val_loss: 0.1980 - val_accuracy: 0.8087 - 18s/epoch - 40ms/step
# Epoch 34/100
# 443/443 - 18s - loss: 0.1909 - accuracy: 0.8207 - val_loss: 0.1951 - val_accuracy: 0.8132 - 18s/epoch - 40ms/step
# Epoch 35/100
# 443/443 - 18s - loss: 0.1903 - accuracy: 0.8229 - val_loss: 0.1950 - val_accuracy: 0.8202 - 18s/epoch - 40ms/step
# Epoch 36/100
# 443/443 - 18s - loss: 0.1897 - accuracy: 0.8264 - val_loss: 0.1934 - val_accuracy: 0.8138 - 18s/epoch - 40ms/step
# Epoch 37/100
# 443/443 - 18s - loss: 0.1888 - accuracy: 0.8273 - val_loss: 0.1961 - val_accuracy: 0.8239 - 18s/epoch - 40ms/step
# Epoch 38/100
# 443/443 - 18s - loss: 0.1890 - accuracy: 0.8278 - val_loss: 0.1978 - val_accuracy: 0.7943 - 18s/epoch - 40ms/step
# Epoch 39/100
# 443/443 - 18s - loss: 0.1877 - accuracy: 0.8313 - val_loss: 0.1949 - val_accuracy: 0.8194 - 18s/epoch - 40ms/step
# Epoch 40/100
# 443/443 - 18s - loss: 0.1873 - accuracy: 0.8355 - val_loss: 0.1924 - val_accuracy: 0.8171 - 18s/epoch - 40ms/step
# Epoch 41/100
# 443/443 - 18s - loss: 0.1866 - accuracy: 0.8334 - val_loss: 0.1934 - val_accuracy: 0.8216 - 18s/epoch - 41ms/step
# Epoch 42/100
# 443/443 - 18s - loss: 0.1867 - accuracy: 0.8311 - val_loss: 0.1967 - val_accuracy: 0.7980 - 18s/epoch - 40ms/step
# Epoch 43/100
# 443/443 - 18s - loss: 0.1861 - accuracy: 0.8328 - val_loss: 0.1919 - val_accuracy: 0.8261 - 18s/epoch - 40ms/step
# Epoch 44/100
# 443/443 - 18s - loss: 0.1853 - accuracy: 0.8378 - val_loss: 0.1976 - val_accuracy: 0.8132 - 18s/epoch - 40ms/step
# Epoch 45/100
# 443/443 - 18s - loss: 0.1853 - accuracy: 0.8377 - val_loss: 0.1922 - val_accuracy: 0.8228 - 18s/epoch - 40ms/step
# Epoch 46/100
# 443/443 - 18s - loss: 0.1848 - accuracy: 0.8368 - val_loss: 0.1921 - val_accuracy: 0.8292 - 18s/epoch - 40ms/step
# Epoch 47/100
# 443/443 - 18s - loss: 0.1843 - accuracy: 0.8376 - val_loss: 0.1920 - val_accuracy: 0.8253 - 18s/epoch - 40ms/step
# Epoch 48/100
# 443/443 - 18s - loss: 0.1839 - accuracy: 0.8419 - val_loss: 0.1928 - val_accuracy: 0.8225 - 18s/epoch - 40ms/step
# Epoch 49/100
# 443/443 - 18s - loss: 0.1835 - accuracy: 0.8402 - val_loss: 0.1919 - val_accuracy: 0.8273 - 18s/epoch - 40ms/step
# Epoch 50/100
# 443/443 - 18s - loss: 0.1829 - accuracy: 0.8453 - val_loss: 0.1920 - val_accuracy: 0.8214 - 18s/epoch - 40ms/step
# Epoch 51/100
# 443/443 - 18s - loss: 0.1825 - accuracy: 0.8437 - val_loss: 0.1935 - val_accuracy: 0.8149 - 18s/epoch - 40ms/step
# Epoch 52/100
# 443/443 - 18s - loss: 0.1826 - accuracy: 0.8438 - val_loss: 0.1901 - val_accuracy: 0.8230 - 18s/epoch - 40ms/step
# Epoch 53/100
# 443/443 - 18s - loss: 0.1820 - accuracy: 0.8459 - val_loss: 0.1902 - val_accuracy: 0.8309 - 18s/epoch - 40ms/step
# Epoch 54/100
# 443/443 - 18s - loss: 0.1819 - accuracy: 0.8470 - val_loss: 0.1900 - val_accuracy: 0.8304 - 18s/epoch - 40ms/step
# Epoch 55/100
# 443/443 - 18s - loss: 0.1817 - accuracy: 0.8479 - val_loss: 0.1887 - val_accuracy: 0.8335 - 18s/epoch - 40ms/step
# Epoch 56/100
# 443/443 - 18s - loss: 0.1810 - accuracy: 0.8507 - val_loss: 0.1894 - val_accuracy: 0.8211 - 18s/epoch - 40ms/step
# Epoch 57/100
# 443/443 - 18s - loss: 0.1805 - accuracy: 0.8517 - val_loss: 0.1902 - val_accuracy: 0.8309 - 18s/epoch - 40ms/step
# Epoch 58/100
# 443/443 - 18s - loss: 0.1809 - accuracy: 0.8480 - val_loss: 0.1902 - val_accuracy: 0.8242 - 18s/epoch - 40ms/step
# Epoch 59/100
# 443/443 - 18s - loss: 0.1803 - accuracy: 0.8520 - val_loss: 0.1954 - val_accuracy: 0.8188 - 18s/epoch - 40ms/step
# Epoch 60/100
# 443/443 - 18s - loss: 0.1802 - accuracy: 0.8526 - val_loss: 0.1912 - val_accuracy: 0.8202 - 18s/epoch - 40ms/step
# Epoch 61/100
# 443/443 - 18s - loss: 0.1796 - accuracy: 0.8516 - val_loss: 0.1916 - val_accuracy: 0.8185 - 18s/epoch - 40ms/step
# Epoch 62/100
# 443/443 - 18s - loss: 0.1792 - accuracy: 0.8546 - val_loss: 0.1891 - val_accuracy: 0.8332 - 18s/epoch - 40ms/step
# Epoch 63/100
# 443/443 - 18s - loss: 0.1791 - accuracy: 0.8536 - val_loss: 0.1913 - val_accuracy: 0.8242 - 18s/epoch - 40ms/step
# Epoch 64/100
# 443/443 - 18s - loss: 0.1785 - accuracy: 0.8559 - val_loss: 0.1900 - val_accuracy: 0.8259 - 18s/epoch - 40ms/step
# Epoch 65/100
# 443/443 - 18s - loss: 0.1782 - accuracy: 0.8568 - val_loss: 0.1909 - val_accuracy: 0.8194 - 18s/epoch - 40ms/step
# Epoch 66/100
# 443/443 - 18s - loss: 0.1782 - accuracy: 0.8555 - val_loss: 0.1888 - val_accuracy: 0.8276 - 18s/epoch - 40ms/step
# Epoch 67/100
# 443/443 - 18s - loss: 0.1780 - accuracy: 0.8591 - val_loss: 0.1905 - val_accuracy: 0.8140 - 18s/epoch - 40ms/step
# Epoch 68/100
# 443/443 - 18s - loss: 0.1775 - accuracy: 0.8616 - val_loss: 0.1885 - val_accuracy: 0.8225 - 18s/epoch - 40ms/step
# Epoch 69/100
# 443/443 - 18s - loss: 0.1769 - accuracy: 0.8607 - val_loss: 0.1925 - val_accuracy: 0.8076 - 18s/epoch - 40ms/step
# Epoch 70/100
# 443/443 - 18s - loss: 0.1774 - accuracy: 0.8570 - val_loss: 0.1892 - val_accuracy: 0.8278 - 18s/epoch - 40ms/step
# Epoch 71/100
# 443/443 - 18s - loss: 0.1767 - accuracy: 0.8609 - val_loss: 0.1886 - val_accuracy: 0.8295 - 18s/epoch - 40ms/step
# Epoch 72/100
# 443/443 - 18s - loss: 0.1766 - accuracy: 0.8597 - val_loss: 0.1900 - val_accuracy: 0.8228 - 18s/epoch - 40ms/step
# Epoch 73/100
# 443/443 - 18s - loss: 0.1767 - accuracy: 0.8613 - val_loss: 0.1885 - val_accuracy: 0.8357 - 18s/epoch - 40ms/step
# Epoch 74/100
# 443/443 - 18s - loss: 0.1760 - accuracy: 0.8627 - val_loss: 0.1903 - val_accuracy: 0.8225 - 18s/epoch - 40ms/step
# Epoch 75/100
# 443/443 - 18s - loss: 0.1760 - accuracy: 0.8650 - val_loss: 0.1886 - val_accuracy: 0.8318 - 18s/epoch - 40ms/step
# Epoch 76/100
# 443/443 - 18s - loss: 0.1757 - accuracy: 0.8641 - val_loss: 0.1897 - val_accuracy: 0.8256 - 18s/epoch - 40ms/step
# Epoch 77/100
# 443/443 - 18s - loss: 0.1754 - accuracy: 0.8645 - val_loss: 0.1897 - val_accuracy: 0.8219 - 18s/epoch - 40ms/step
# Epoch 78/100
# 443/443 - 18s - loss: 0.1746 - accuracy: 0.8680 - val_loss: 0.1885 - val_accuracy: 0.8349 - 18s/epoch - 40ms/step
# Epoch 79/100
# 443/443 - 18s - loss: 0.1747 - accuracy: 0.8682 - val_loss: 0.1870 - val_accuracy: 0.8416 - 18s/epoch - 40ms/step
# Epoch 80/100
# 443/443 - 18s - loss: 0.1746 - accuracy: 0.8684 - val_loss: 0.1884 - val_accuracy: 0.8335 - 18s/epoch - 41ms/step
# Epoch 81/100
# 443/443 - 18s - loss: 0.1747 - accuracy: 0.8684 - val_loss: 0.1879 - val_accuracy: 0.8349 - 18s/epoch - 41ms/step
# Epoch 82/100
# 443/443 - 18s - loss: 0.1747 - accuracy: 0.8673 - val_loss: 0.1920 - val_accuracy: 0.8278 - 18s/epoch - 40ms/step
# Epoch 83/100
# 443/443 - 18s - loss: 0.1743 - accuracy: 0.8663 - val_loss: 0.1895 - val_accuracy: 0.8343 - 18s/epoch - 40ms/step
# Epoch 84/100
# 443/443 - 18s - loss: 0.1738 - accuracy: 0.8692 - val_loss: 0.1882 - val_accuracy: 0.8354 - 18s/epoch - 40ms/step
# Epoch 85/100
# 443/443 - 18s - loss: 0.1737 - accuracy: 0.8719 - val_loss: 0.1921 - val_accuracy: 0.8160 - 18s/epoch - 40ms/step
# Epoch 86/100
# 443/443 - 18s - loss: 0.1735 - accuracy: 0.8722 - val_loss: 0.1895 - val_accuracy: 0.8309 - 18s/epoch - 40ms/step
# Epoch 87/100
# 443/443 - 18s - loss: 0.1736 - accuracy: 0.8680 - val_loss: 0.1888 - val_accuracy: 0.8335 - 18s/epoch - 40ms/step
# Epoch 88/100
# 443/443 - 18s - loss: 0.1732 - accuracy: 0.8692 - val_loss: 0.1905 - val_accuracy: 0.8270 - 18s/epoch - 40ms/step
# Epoch 89/100
# 443/443 - 18s - loss: 0.1726 - accuracy: 0.8729 - val_loss: 0.1886 - val_accuracy: 0.8332 - 18s/epoch - 40ms/step
# Epoch 90/100
# 443/443 - 18s - loss: 0.1728 - accuracy: 0.8729 - val_loss: 0.1891 - val_accuracy: 0.8323 - 18s/epoch - 40ms/step
# Epoch 91/100
# 443/443 - 18s - loss: 0.1724 - accuracy: 0.8736 - val_loss: 0.1888 - val_accuracy: 0.8354 - 18s/epoch - 40ms/step
# Epoch 92/100
# 443/443 - 18s - loss: 0.1726 - accuracy: 0.8757 - val_loss: 0.1874 - val_accuracy: 0.8369 - 18s/epoch - 40ms/step
# Epoch 93/100
# 443/443 - 18s - loss: 0.1718 - accuracy: 0.8762 - val_loss: 0.1886 - val_accuracy: 0.8343 - 18s/epoch - 40ms/step
# Epoch 94/100
# 443/443 - 18s - loss: 0.1721 - accuracy: 0.8757 - val_loss: 0.1870 - val_accuracy: 0.8380 - 18s/epoch - 40ms/step
# Epoch 95/100
# 443/443 - 18s - loss: 0.1719 - accuracy: 0.8769 - val_loss: 0.1879 - val_accuracy: 0.8369 - 18s/epoch - 40ms/step
# Epoch 96/100
# 443/443 - 18s - loss: 0.1715 - accuracy: 0.8784 - val_loss: 0.1888 - val_accuracy: 0.8256 - 18s/epoch - 40ms/step
# Epoch 97/100
# 443/443 - 18s - loss: 0.1717 - accuracy: 0.8779 - val_loss: 0.1881 - val_accuracy: 0.8369 - 18s/epoch - 40ms/step
# Epoch 98/100
# 443/443 - 18s - loss: 0.1710 - accuracy: 0.8788 - val_loss: 0.1888 - val_accuracy: 0.8298 - 18s/epoch - 40ms/step
# Epoch 99/100
# 443/443 - 18s - loss: 0.1711 - accuracy: 0.8787 - val_loss: 0.1889 - val_accuracy: 0.8402 - 18s/epoch - 40ms/step
# Epoch 100/100
# 443/443 - 18s - loss: 0.1709 - accuracy: 0.8786 - val_loss: 0.1879 - val_accuracy: 0.8340 - 18s/epoch - 40ms/step
# 56/56 [==============================] - 1s 11ms/step - loss: 0.1876 - accuracy: 0.8273
# Модель и весы сохранены.

# %%
'''def test():
    fer_classes = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt']

    X, y = preprocess_data()
    X, y = clean_data_and_normalize(X, y)
    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)
    datagood = data_good(x_train)
    show_images(datagood, x_train, y_train)
    datagen = data_augmentation(x_train)
    show_augmented_images(datagen, x_train, y_train)

    epochs = 2
    batch_size = 64

    print("X_train shape: " + str(x_train.shape))
    print("Y_train shape: " + str(y_train.shape))
    print("X_test shape: " + str(x_test.shape))
    print("Y_test shape: " + str(y_test.shape))
    print("X_val shape: " + str(x_val.shape))
    print("Y_val shape: " + str(y_val.shape))'''
# Out:
# 'def test():\n    fer_classes = [\'neutral\', \'happiness\', \'surprise\', \'sadness\', \'anger\', \'disgust\', \'fear\', \'contempt\']\n\n    X, y = preprocess_data()\n    X, y = clean_data_and_normalize(X, y)\n    x_train, y_train, x_val, y_val, x_test, y_test = split_data(X, y)\n    datagood = data_good(x_train)\n    show_images(datagood, x_train, y_train)\n    datagen = data_augmentation(x_train)\n    show_augmented_images(datagen, x_train, y_train)\n\n    epochs = 2\n    batch_size = 64\n\n    print("X_train shape: " + str(x_train.shape))\n    print("Y_train shape: " + str(y_train.shape))\n    print("X_test shape: " + str(x_test.shape))\n    print("Y_test shape: " + str(y_test.shape))\n    print("X_val shape: " + str(x_val.shape))\n    print("Y_val shape: " + str(y_val.shape))'

# %%
#test()
